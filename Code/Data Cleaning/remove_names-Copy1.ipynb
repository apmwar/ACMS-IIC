# %% [markdown]
# ### Importing necessary libraries, packages and functions

# %%
import csv
import pandas as pd
import string
from nltk import corpus
from nltk import word_tokenize
from nltk import pos_tag

# %% [markdown]
# ### Load the tsv file

# %%
title = ["Amazon EC2", "Amazon RDS", "Amazon S3", "Amazon CloudFront", "Amazon VPC", "Amazon SNS",
            "Amazon Elastic Beanstalk", "Amazon Lambda"]

fileloc = "C:\\Users\\Aruna\\Documents\\ACMS-IID\\Scraped Files\\Test Data\\"

text = pd.read_csv(fileloc + title[7] + '_testdata.tsv', delimiter='\t', encoding='utf-8')
text['description']
# Out:
# 0     Deploy multiple end point in Springboot as Lam...
# 1     Can I trigger a second function on response fr...
# 2     Re: Can I trigger a second function on respons...
# 3     Exception thrown when invoking an AWS Lambda f...
# 4     Option to set minimum number of 'warm function...
# 5     Re: Option to set minimum number of 'warm func...
# 6     Re: Option to set minimum number of 'warm func...
# 7     Re: Option to set minimum number of 'warm func...
# 8     Can we check how many concurrent lambda curren...
# 9     Re: Can we check how many concurrent lambda cu...
# 10    Re: Can we check how many concurrent lambda cu...
# 11    Is possible to change lambda timeout container...
# 12    Re: Is possible to change lambda timeout conta...
# 13    Is the permission DetachNetworkInterfaces reas...
# 14    Re: Is the permission DetachNetworkInterfaces ...
# 15    Re: Is the permission DetachNetworkInterfaces ...
# 16    Pass Cognito credentials/identity from API Gat...
# 17    Re: Pass Cognito credentials/identity from API...
# 18    Lambda Layers not supported with SAM/CloudForm...
# 19    Re: Lambda Layers not supported with SAM/Cloud...
# 20    Re: Lambda Layers not supported with SAM/Cloud...
# 21    CodeBuild Error: UNAUTHORIZED_OPERATION_CREATE...
# 22    Re: CodeBuild Error: UNAUTHORIZED_OPERATION_CR...
# 23    Re: CodeBuild Error: UNAUTHORIZED_OPERATION_CR...
# 24    Sending Webpush notification through Lambda\r\...
# 25    Code Storage -  Does it reuse a deployment pac...
# 26    Lambda javascript API missing functions\r\nI a...
# 27    Expired Token\r\nOccasionally,  my lambda call...
# 28    Re: Expired Token\r\nThanks for reporting this...
# 29    Re: Expired Token\r\nAgreed, thanks Jeremy.\r\...
#                             ...
# 61    Re: Mounting EFS file systems\r\n+1 Read only ...
# 62    Re: Mounting EFS file systems\r\nHello,\r\n\r\...
# 63    Re: Mounting EFS file systems\r\n+1\r\nLambda ...
# 64    Re: Mounting EFS file systems\r\n+1 Essential ...
# 65    Re: Mounting EFS file systems\r\n+1\r\nHi,\r\n...
# 66    Re: Mounting EFS file systems\r\n+1! It will b...
# 67    Re: Mounting EFS file systems\r\n+1 !!\r\n\r\n...
# 68    Re: Mounting EFS file systems\r\nUmair\r\n\r\n...
# 69    Re: Mounting EFS file systems\r\n+1\r\n\r\nThi...
# 70    Re: Mounting EFS file systems\r\n+1\r\nIt's gr...
# 71    Re: Mounting EFS file systems\r\n+1 We are usi...
# 72                  Re: Mounting EFS file systems\r\n+1
# 73    Re: Mounting EFS file systems\r\n+1\r\n\r\nLot...
# 74    Re: Mounting EFS file systems\r\nI have anothe...
# 75                  Re: Mounting EFS file systems\r\n+1
# 76    Re: Mounting EFS file systems\r\nYear and a ha...
# 77    Alias dimension not available\r\nAccording to ...
# 78    Re: Alias dimension not available\r\nBump. Thi...
# 79    Re: Alias dimension not available\r\nbump. Is ...
# 80    Re: Alias dimension not available\r\nCan anyon...
# 81           Re: Alias dimension not available\r\nBump.
# 82    Re: Alias dimension not available\r\nTo update...
# 83    Lambda - "Task timed out" on first 3 or 4 invo...
# 84    Lambda using extra libaries\r\nHello,\r\n    I...
# 85    Re: Lambda using extra libaries\r\nHello, \r\n...
# 86    Re: Lambda using extra libaries\r\nHi I have b...
# 87    Re: Lambda using extra libaries\r\nDid you eve...
# 88    Possible to add a Lambda "shut down" callback?...
# 89    Authorizer function not logging to CloudWatch\...
# 90    Re: Authorizer function not logging to CloudWa...
# Name: description, Length: 91, dtype: object

# %% [markdown]
# #### Step 1) Remove the question description and then the extra whitespace

# %%
cleantext = text['description'].tolist()

for i in range(0, len(cleantext)):
    if cleantext[i][0] == 'R' and cleantext[i][1] == 'e' and cleantext[i][2] == ':':
        cleantext[i] = ' '.join(cleantext[i].splitlines()[1:])
    cleantext[i] = ' '.join(cleantext[i].split())

text['description'] = cleantext    
    
text['description']
# Out:
# 0     Deploy multiple end point in Springboot as Lam...
# 1     Can I trigger a second function on response fr...
# 2     Sounds like you might want to provide the exte...
# 3     Exception thrown when invoking an AWS Lambda f...
# 4     Option to set minimum number of 'warm function...
# 5     Hello, Thank you for the feedback. I will forw...
# 6     Now that Microsoft has this feature, I'd reall...
# 7     Hello One can keep your lamdbas warm with this...
# 8     Can we check how many concurrent lambda curren...
# 9     There is currently no API to tell you the real...
# 10    Hi cecilia@AWS, Is there a service or API to d...
# 11    Is possible to change lambda timeout container...
# 12    Hello, Unfortunately, as of now, it is not pos...
# 13    Is the permission DetachNetworkInterfaces reas...
# 14    Hello, AWS Lambda is a managed service, the op...
# 15                                              Thanks!
# 16    Pass Cognito credentials/identity from API Gat...
# 17    Hello, Amazon Cognito user pool returns differ...
# 18    Lambda Layers not supported with SAM/CloudForm...
# 19    I've noticed the same problem with eu-north-1....
# 20    I got a message from someone saying that the s...
# 21    CodeBuild Error: UNAUTHORIZED_OPERATION_CREATE...
# 22    I've hit the same problem - did you have any l...
# 23    You have to grant a few different EC2 permissi...
# 24    Sending Webpush notification through Lambda Hi...
# 25    Code Storage - Does it reuse a deployment pack...
# 26    Lambda javascript API missing functions I am t...
# 27    Expired Token Occasionally, my lambda calls wi...
# 28    Thanks for reporting this issue, Jeremymcjunki...
# 29    Agreed, thanks Jeremy. Bradley -- is there any...
#                             ...
# 61    +1 Read only efs would be enough for our needs...
# 62    Hello, The feature request has been already lo...
# 63    +1 Lambda and EFS together can be very powerfu...
# 64    +1 Essential for access by Lambda to data in E...
# 65    +1 Hi, Any updates on this request ? We will n...
# 66    +1! It will be great with Lambdas working with...
# 67    +1 !! Would really love to migrate existing le...
# 68    Umair Any update on the ETA for this? It's bee...
# 69    +1 This would be very helpful for us, since we...
# 70                                +1 It's great for ML!
# 71    +1 We are using lambda for image and document ...
# 72                                                   +1
# 73    +1 Lots of use cases where this expands the ca...
# 74    I have another use case. I am rendering animat...
# 75                                                   +1
# 76    Year and a half passed and the engineer log is...
# 77    Alias dimension not available According to the...
# 78          Bump. This is in us-west-2, for the record.
# 79    bump. Is anyone else experiencing something si...
# 80    Can anyone from Amazon comment on this? Are th...
# 81                                                Bump.
# 82    To update this, I contacted AWS support, and a...
# 83    Lambda - "Task timed out" on first 3 or 4 invo...
# 84    Lambda using extra libaries Hello, I am trying...
# 85    Hello, Here are guidelines for building packag...
# 86    Hi I have been trying hard to get zbar working...
# 87    Did you ever figure this out, I am also intere...
# 88    Possible to add a Lambda "shut down" callback?...
# 89    Authorizer function not logging to CloudWatch ...
# 90    To answer my own question, the problem was ind...
# Name: description, Length: 91, dtype: object

# %% [markdown]
# #### Step 2) Tokenize the text

# %%
flag = 0
txt = []

for msg in text['description']:
    tokens = word_tokenize(msg)
    txt.append(tokens)
    # print(flag)
    flag = flag + 1

# %% [markdown]
# #### Step 3) Remove (some) common names and proper nouns from text
#
# <i>Note: We are converting the names corpus to uppercase because otherwise checking is case sensitive </i>

# %%
import nltk
nltk.download('names')
nltk.download('words')
# names = corpus.names.words()
words = corpus.words.words()

names = ['JANUARY', 'FEBRUARY', 'MARCH', 'APRIL', 'MAY', 'JUNE', 'JULY', 'AUGUST', 'SEPTEMBER', 'OCTOBER', 'NOVEMBER',
         'DECEMBER', 'JAN', 'FEB', 'MAR', 'APR', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC','MONDAY', 'TUESDAY',
         'WEDNESDAY', 'THURSDAY', 'FRIDAY', 'SATURDAY', 'SUNDAY', 'MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT', 'SUN'
        ]

for name in corpus.names.words():
    names.append(name.upper())
# Out:
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\Aruna\AppData\Roaming\nltk_data...
# [nltk_data]   Package names is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Aruna\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
flag = 0
cleantext = []

for item in txt:
    mylist = []
    pos = pos_tag(item)
    for name, tag in pos:
        if tag == 'NNP' and name.upper() in names:
            # print(name)    
            flag = flag + 1
        else:
            mylist.append(name)
            
    cleantext.append(mylist)
            
flag
# Out:
# 29

# %%
m = len(cleantext)
for i in range(0, m):
    n = len(cleantext[i])
    for j in range(0, n):
        try:
            if len(cleantext[i][j]) < 2:
                del cleantext[i][j]
                n = n - 1
        except:
            j = j - 1

cleantext
# Out:
# [['Deploy',
#   'multiple',
#   'end',
#   'point',
#   'in',
#   'Springboot',
#   'as',
#   'Lambda',
#   'Hi',
#   'I',
#   'want',
#   'to',
#   'clarify',
#   'the',
#   'below',
#   'when',
#   'it',
#   'comes',
#   'to',
#   'deploying',
#   'multiple',
#   'rest',
#   'endpoints',
#   'implemented',
#   'as',
#   'single',
#   'springboot',
#   'application',
#   '1.Can',
#   'we',
#   'expose',
#   'all',
#   'the',
#   'end',
#   'points',
#   'in',
#   'original',
#   'spring',
#   'boot',
#   'by',
#   'writing',
#   'single',
#   'lambda',
#   'function',
#   'and',
#   'update',
#   'all',
#   'the',
#   'paths',
#   'in',
#   'sam.yaml',
#   'Can',
#   'we',
#   'add',
#   'multiple',
#   'paths',
#   'to',
#   'the',
#   'below',
#   'snippet',
#   'under',
#   'single',
#   'lambda',
#   'function',
#   'for',
#   'spring',
#   'boot',
#   'to',
#   'expose',
#   'all',
#   'end',
#   'point',
#   'in',
#   'sam.yaml',
#   'Resources',
#   'PetStoreFunction',
#   'Type',
#   'AWS',
#   ':Serverless',
#   ':Function',
#   'Properties',
#   'Handler',
#   'com.amazonaws.serverless.sample.springboot.StreamLambdaHandler',
#   ':handleRequest',
#   'Runtime',
#   'java8',
#   'CodeUri',
#   'target/serverless-spring-boot-example-1.0-SNAPSHOT-lambda-package.zip',
#   'MemorySize',
#   '1512',
#   'Policies',
#   'AWSLambdaBasicExecutionRole',
#   'Timeout',
#   '60',
#   'Events',
#   'GetResource',
#   'Type',
#   'Api',
#   'Properties',
#   'Path',
#   '/',
#   'proxy+',
#   'Method',
#   'any',
#   'Or',
#   'do',
#   'we',
#   'need',
#   'to',
#   'write',
#   'lambda',
#   'function',
#   'per',
#   'end',
#   'point',
#   'and',
#   'spin',
#   'off',
#   'multiple',
#   'springboot',
#   'containers',
#   'or',
#   'Is',
#   'ther=ir',
#   'any',
#   'way',
#   'to',
#   'share',
#   'single',
#   'spring',
#   'boot',
#   'container',
#   'across',
#   'multiple',
#   'end',
#   'points',
#   'Please',
#   'clarify',
#   'Thanks',
#   'Isuru'],
#  ['Can',
#   'trigger',
#   'second',
#   'function',
#   'on',
#   'response',
#   'from',
#   'an',
#   'external',
#   'HTTP',
#   'service',
#   'Hi',
#   'all',
#   'I',
#   'have',
#   'process',
#   'that',
#   'uses',
#   'black-box',
#   'system',
#   'through',
#   'slow',
#   'HTTP',
#   'requests',
#   'I',
#   'could',
#   'make',
#   'function',
#   'that',
#   'generates',
#   'the',
#   'request',
#   'and',
#   'sends',
#   'it',
#   'to',
#   'the',
#   'server',
#   'but',
#   'idling',
#   'the',
#   'task',
#   'while',
#   'waiting',
#   'for',
#   'the',
#   'response',
#   'would',
#   'be',
#   'great',
#   'waste',
#   'of',
#   'time',
#   'and',
#   'resources',
#   'Instead',
#   'it',
#   'seems',
#   'to',
#   'me',
#   'that',
#   'it',
#   'would',
#   'be',
#   'better',
#   'to',
#   'trigger',
#   'second',
#   'function',
#   'that',
#   'processes',
#   'the',
#   'result',
#   'from',
#   'the',
#   'HTTP',
#   'response',
#   'of',
#   'that',
#   'call',
#   'Then',
#   'no',
#   'function',
#   'would',
#   'be',
#   'alive',
#   'during',
#   'the',
#   'time',
#   'of',
#   'the',
#   'request',
#   '15~60',
#   'seconds',
#   'times',
#   'very',
#   'many',
#   'requests',
#   '.',
#   'Is',
#   'such',
#   'thing',
#   'possible',
#   'with',
#   'AWS',
#   'Lambda',
#   'What',
#   'would',
#   'you',
#   'suggest',
#   'to',
#   'do',
#   'in',
#   'such',
#   'setting',
#   'Edited',
#   'by',
#   'JeroenV',
#   'on',
#   '10',
#   '2019',
#   '1:58',
#   'AM'],
#  ['Sounds',
#   'like',
#   'you',
#   'might',
#   'want',
#   'to',
#   'provide',
#   'the',
#   'external',
#   'service',
#   'with',
#   'callback',
#   'url',
#   'That',
#   'way',
#   'when',
#   'it',
#   "'s",
#   'done',
#   'doing',
#   'whatever',
#   'slow',
#   'processing',
#   'it',
#   "'s",
#   'doing',
#   'it',
#   'can',
#   'send',
#   'the',
#   'results',
#   'to',
#   'that',
#   'url',
#   'which',
#   'can',
#   'invoke',
#   'lambda',
#   'function',
#   'This',
#   'is',
#   'of',
#   'course',
#   'assuming',
#   'the',
#   'external',
#   'service',
#   'has',
#   'that',
#   'capability',
#   'or',
#   'you',
#   'can',
#   'alter',
#   'it',
#   'to',
#   'have',
#   'that',
#   'capability',
#   'There',
#   'is',
#   "n't",
#   'really',
#   'anything',
#   'available',
#   'to',
#   'do',
#   'the',
#   'http',
#   'call',
#   'for',
#   'you',
#   'and',
#   'invoke',
#   'lambda',
#   'with',
#   'the',
#   'results',
#   '...'],
#  ['Exception',
#   'thrown',
#   'when',
#   'invoking',
#   'an',
#   'AWS',
#   'Lambda',
#   'from',
#   'local',
#   'Lambda',
#   'Hi',
#   "'m",
#   'developing',
#   'NodeJS',
#   'Lambda',
#   'function',
#   'in',
#   'VS',
#   'Code',
#   'using',
#   'the',
#   'Serverless',
#   'Framework',
#   'I',
#   "'m",
#   'able',
#   'to',
#   'debug',
#   'it',
#   'locally',
#   'in',
#   'VS',
#   'Code',
#   'but',
#   'have',
#   'encountered',
#   'an',
#   'issue',
#   'when',
#   'try',
#   'to',
#   'invoke',
#   'another',
#   'Lambda',
#   'which',
#   'is',
#   'deployed',
#   'in',
#   'AWS',
#   'from',
#   'within',
#   'the',
#   'local',
#   'Lambda',
#   'I',
#   "'m",
#   'using',
#   'AWS.Lambda.invoke',
#   'as',
#   'shown',
#   'in',
#   'the',
#   'following',
#   'code',
#   'snippet',
#   'var',
#   'AWS',
#   'require',
#   "'aws-sdk",
#   ')',
#   'AWS.config.region',
#   "'eu-west-1",
#   ';',
#   'var',
#   'lambda',
#   'new',
#   'AWS.Lambda',
#   ')',
#   '...',
#   'return',
#   'lambda.invoke',
#   'params',
#   '.promise',
#   ')',
#   'However',
#   'it',
#   'throws',
#   'an',
#   'IncompleteSignatureException',
#   'along',
#   'with',
#   'the',
#   'following',
#   'message',
#   "'/20190411/eu-west-1/lambda/aws4_request",
#   'not',
#   'valid',
#   'key=value',
#   'pair',
#   'missing',
#   'equal-sign',
#   'in',
#   'Authorization',
#   'header',
#   "'AWS4-HMAC-SHA256",
#   'Credential=xxxxx',
#   '/20190411/eu-west-1/lambda/aws4_request',
#   'SignedHeaders=host',
#   'x-amz-content-sha256',
#   'x-amz-date',
#   'x-amz-invocation-type',
#   'x-amz-log-type',
#   'Signature=xxxxxx',
#   'When',
#   'deploy',
#   'the',
#   'calling',
#   'Lambda',
#   'to',
#   'AWS',
#   'the',
#   'invocation',
#   'of',
#   'the',
#   'second',
#   'Lambda',
#   'works',
#   'fine',
#   'so',
#   'there',
#   'must',
#   'be',
#   'something',
#   'additional',
#   'need',
#   'to',
#   'do',
#   'when',
#   'invoking',
#   'it',
#   'locally',
#   'The',
#   'trouble',
#   'is',
#   'I',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'that',
#   'something',
#   'is',
#   'Note',
#   'that',
#   'nowhere',
#   'in',
#   'my',
#   'code',
#   'am',
#   'explicitly',
#   'setting',
#   'Signature',
#   'or',
#   'header',
#   'values',
#   'My',
#   'search',
#   'for',
#   'solution',
#   'has',
#   'returned',
#   'suggestions',
#   'related',
#   'to',
#   'API',
#   'Gateway',
#   'and',
#   'custom',
#   'authorizers',
#   'but',
#   'there',
#   'is',
#   'no',
#   'API',
#   'Gateway',
#   'for',
#   'the',
#   'Lambda',
#   "'m",
#   'trying',
#   'to',
#   'invoke',
#   'Thanks',
#   'Edited',
#   'by',
#   'alanwarren395',
#   'on',
#   '11',
#   '2019',
#   '6:41',
#   'AM',
#   'Edited',
#   'by',
#   'alanwarren395',
#   'on',
#   '11',
#   '2019',
#   '6:43',
#   'AM'],
#  ['Option',
#   'to',
#   'set',
#   'minimum',
#   'number',
#   'of',
#   "'warm",
#   'functions',
#   'A',
#   'nice',
#   'to',
#   'heave',
#   'feature',
#   'would',
#   'be',
#   'an',
#   'option',
#   'on',
#   'the',
#   'lambda',
#   'to',
#   'set',
#   '``',
#   'Keep-Warm',
#   "''",
#   'option',
#   'The',
#   'ability',
#   'to',
#   'set',
#   'minimum',
#   'number',
#   'of',
#   'warmed',
#   'instances',
#   'as',
#   'well',
#   'as',
#   'being',
#   'able',
#   'to',
#   'set',
#   'specific',
#   'schedule',
#   'similar',
#   'to',
#   'cron',
#   'job',
#   'schedule',
#   'all',
#   'in',
#   'exchange',
#   'for',
#   'some',
#   'fee',
#   'This',
#   'would',
#   'help',
#   'developers',
#   'not',
#   'have',
#   'to',
#   'write',
#   'workarounds',
#   'for',
#   'services',
#   'that',
#   'need',
#   'certain',
#   'level',
#   'of',
#   'responsiveness',
#   'during',
#   'cold',
#   'periods',
#   '(',
#   'Think',
#   'people',
#   'doing',
#   'uncommon',
#   'things',
#   'late',
#   'at',
#   'night',
#   '.'],
#  ['Hello',
#   'Thank',
#   'you',
#   'for',
#   'the',
#   'feedback',
#   'I',
#   'will',
#   'forward',
#   'this',
#   'as',
#   'feature',
#   'request',
#   'to',
#   'the',
#   'internal',
#   'team',
#   'However',
#   'we',
#   'will',
#   'not',
#   'be',
#   'able',
#   'to',
#   'provide',
#   'an',
#   'ETA',
#   'on',
#   'when/if',
#   'this',
#   'feature',
#   'will',
#   'be',
#   'released',
#   'Kindly',
#   'check',
#   'our',
#   'products',
#   'announcement',
#   'page',
#   '1',
#   'and',
#   'AWS',
#   'Blog',
#   '2',
#   'periodically',
#   'for',
#   'updates',
#   '[',
#   ']',
#   'https',
#   '//aws.amazon.com/new/',
#   '2',
#   'https',
#   '//aws.amazon.com/blogs/aws/'],
#  ['Now',
#   'that',
#   'Microsoft',
#   'has',
#   'this',
#   'feature',
#   'I',
#   "'d",
#   'really',
#   'like',
#   'aws',
#   'to',
#   'support',
#   'it',
#   'as',
#   'well',
#   'Basically',
#   'cold',
#   'starts',
#   'are',
#   'no',
#   'longer',
#   'concern',
#   'when',
#   'you',
#   'use',
#   'azure',
#   '...',
#   'For',
#   'anyone',
#   'curious',
#   'here',
#   'is',
#   'the',
#   'announcement',
#   'https',
#   '//azure.microsoft.com/en-us/blog/announcing-the-azure-functions-premium-plan-for-enterprise-serverless-workloads/',
#   'Please',
#   'log',
#   'my',
#   'vote',
#   'on',
#   'this',
#   'as',
#   'well',
#   'It',
#   'would',
#   'make',
#   'life',
#   'so',
#   'much',
#   'easier',
#   'by',
#   'not',
#   'having',
#   'to',
#   'focus',
#   'every',
#   'decision',
#   'around',
#   '``',
#   'how',
#   'can',
#   'we',
#   'reduce',
#   'cold',
#   'starts',
#   'further',
#   "''",
#   'and',
#   'having',
#   'to',
#   'manually',
#   'warm',
#   'lambdas',
#   'which',
#   'you',
#   'need',
#   'to',
#   'go',
#   'through',
#   'api',
#   'gateway',
#   'when',
#   'you',
#   "'re",
#   'using',
#   'xray',
#   '.'],
#  ['Hello',
#   'One',
#   'can',
#   'keep',
#   'your',
#   'lamdbas',
#   'warm',
#   'with',
#   'this',
#   'plugin',
#   'https',
#   '//github.com/FidelLimited/serverless-plugin-warmup',
#   'use',
#   'it',
#   'myself',
#   'and',
#   'it',
#   'works'],
#  ['Can',
#   'we',
#   'check',
#   'how',
#   'many',
#   'concurrent',
#   'lambda',
#   'currently',
#   'run',
#   'Sometimes',
#   'want',
#   'to',
#   'know',
#   'how',
#   'many',
#   'lambda',
#   'is',
#   'still',
#   'running',
#   'To',
#   'limit',
#   'concurrent',
#   'or',
#   'spawn',
#   'new',
#   'one',
#   'to',
#   'keep',
#   'the',
#   'same',
#   'amount',
#   'of',
#   'parallel',
#   'Are',
#   'there',
#   'any',
#   'API',
#   'to',
#   'let',
#   'me',
#   'know',
#   'this',
#   'information'],
#  ['There',
#   'is',
#   'currently',
#   'no',
#   'API',
#   'to',
#   'tell',
#   'you',
#   'the',
#   'real',
#   'time',
#   'concrete',
#   'number',
#   'of',
#   'concurrent',
#   'executions',
#   'but',
#   'you',
#   'can',
#   'make',
#   'fair',
#   'estimate',
#   'by',
#   'using',
#   'the',
#   'provided',
#   'cloudwatch',
#   'metrics',
#   'and',
#   'multiplying',
#   'the',
#   'number',
#   'of',
#   'invocations',
#   'supplied',
#   'down',
#   'to',
#   'the',
#   'minute',
#   'with',
#   'the',
#   'average',
#   'duration',
#   'of',
#   'executions',
#   'supplied',
#   'in',
#   'ms',
#   'at',
#   'given',
#   'point',
#   'in',
#   'time',
#   'We',
#   'are',
#   'looking',
#   'into',
#   'features',
#   'that',
#   'will',
#   'help',
#   'in',
#   'this',
#   'concurrent',
#   'and',
#   'throttling',
#   'area'],
#  ['Hi',
#   'cecilia',
#   'AWS',
#   'Is',
#   'there',
#   'service',
#   'or',
#   'API',
#   'to',
#   'do',
#   'the',
#   'same',
#   'yet'],
#  ['Is',
#   'possible',
#   'to',
#   'change',
#   'lambda',
#   'timeout',
#   'container',
#   'Hey',
#   'I',
#   "'m",
#   'trying',
#   'to',
#   'avoid',
#   'cold',
#   'start',
#   'in',
#   'my',
#   'lambda',
#   'functions',
#   'Is',
#   'there',
#   'any',
#   'way',
#   'to',
#   'control',
#   'the',
#   'container',
#   'timeout',
#   'Can',
#   'reserve',
#   'or',
#   '10',
#   'containers',
#   'for',
#   'longer',
#   'period',
#   'of',
#   'time',
#   'Even',
#   'if',
#   'this',
#   'will',
#   'be',
#   'an',
#   'extra',
#   'charge',
#   'I',
#   'just',
#   'want',
#   'to',
#   'know',
#   'if',
#   'is',
#   'anything',
#   'can',
#   'do',
#   'to',
#   'control',
#   'container',
#   'timeout',
#   'besides',
#   'keeping',
#   'it',
#   'warm',
#   'with',
#   'schedule',
#   'requests',
#   'Edited',
#   'by',
#   'jnabais',
#   'on',
#   '20',
#   '2019',
#   '3:33',
#   'AM'],
#  ['Hello',
#   'Unfortunately',
#   'as',
#   'of',
#   'now',
#   'it',
#   'is',
#   'not',
#   'possible',
#   'to',
#   'control',
#   'the',
#   'container',
#   'timeout',
#   'and',
#   'reserve',
#   'it',
#   'for',
#   'longer',
#   'time',
#   'I',
#   'see',
#   'that',
#   'you',
#   'are',
#   'already',
#   'following',
#   'the',
#   'best',
#   'practices',
#   'of',
#   'keeping',
#   'lambda',
#   'functions',
#   'warm',
#   'using',
#   'scheduled',
#   'requests',
#   'Thank',
#   'you',
#   'for',
#   'the',
#   'feedback',
#   'I',
#   'will',
#   'forward',
#   'this',
#   'feature',
#   'request',
#   'to',
#   'the',
#   'internal',
#   'team',
#   'However',
#   'we',
#   'will',
#   'not',
#   'be',
#   'able',
#   'to',
#   'provide',
#   'an',
#   'ETA',
#   'for',
#   'when/if',
#   'this',
#   'feature',
#   'will',
#   'be',
#   'released',
#   'Kindly',
#   'check',
#   'our',
#   'products',
#   'announcement',
#   'page',
#   '1',
#   'and',
#   'AWS',
#   'Blog',
#   '2',
#   'periodically',
#   'for',
#   'updates',
#   '[',
#   ']',
#   'https',
#   '//aws.amazon.com/new/',
#   '2',
#   'https',
#   '//aws.amazon.com/blogs/aws/'],
#  ['Is',
#   'the',
#   'permission',
#   'DetachNetworkInterfaces',
#   'reasonable',
#   'If',
#   'you',
#   'run',
#   'an',
#   'AWS',
#   'Lambda',
#   'function',
#   'in',
#   'VPC',
#   'does',
#   'it',
#   'make',
#   'sense',
#   'to',
#   'add',
#   'the',
#   'action',
#   'DetachNetworkInferace',
#   'to',
#   'the',
#   'IAM',
#   'role',
#   'We',
#   'run',
#   'all',
#   'of',
#   'our',
#   'Lambda',
#   'function',
#   'within',
#   'VPC',
#   'It',
#   'is',
#   'my',
#   'understanding',
#   'that',
#   'in',
#   'this',
#   'case',
#   'the',
#   'function',
#   'needs',
#   'an',
#   'ENI',
#   'to',
#   'access',
#   'VPC',
#   'resources',
#   'To',
#   'enable',
#   'this',
#   'we',
#   'attach',
#   'the',
#   'AWS',
#   'managed',
#   'policy',
#   'AWSLambdaVPCAccessExecutionRole',
#   'to',
#   'the',
#   'functions',
#   'While',
#   'browsing',
#   'the',
#   'permission',
#   'noticed',
#   'that',
#   'the',
#   'action',
#   'DetachNetworkInterface',
#   'is',
#   'missing',
#   '{',
#   '``',
#   'Version',
#   "''",
#   '``',
#   '2012-10-17',
#   "''",
#   '``',
#   'Statement',
#   "''",
#   '[',
#   '``',
#   'Effect',
#   "''",
#   '``',
#   'Allow',
#   "''",
#   '``',
#   'Action',
#   "''",
#   '[',
#   '``',
#   'logs',
#   'CreateLogGroup',
#   "''",
#   '``',
#   'logs',
#   'CreateLogStream',
#   "''",
#   '``',
#   'logs',
#   'PutLogEvents',
#   "''",
#   '``',
#   'ec2',
#   'CreateNetworkInterface',
#   "''",
#   '``',
#   'ec2',
#   'DescribeNetworkInterfaces',
#   "''",
#   '``',
#   'ec2',
#   'DeleteNetworkInterface',
#   "''",
#   ',',
#   '``',
#   'Resource',
#   "''",
#   '``',
#   "''",
#   ']',
#   'How',
#   'can',
#   'the',
#   'container',
#   'that',
#   'runs',
#   'the',
#   'function',
#   'delete',
#   'the',
#   'ENI',
#   'if',
#   'it',
#   'ca',
#   "n't",
#   'detach',
#   'the',
#   'ENI',
#   'This',
#   'is',
#   'bit',
#   'of',
#   'deep',
#   'dive',
#   'question',
#   'but',
#   'am',
#   'just',
#   'curious',
#   'about',
#   'the',
#   'internals',
#   'of',
#   'AWS',
#   'Lambda'],
#  ['Hello',
#   'AWS',
#   'Lambda',
#   'is',
#   'managed',
#   'service',
#   'the',
#   'operations',
#   'of',
#   'attaching/detaching',
#   'the',
#   'network',
#   'interfaces',
#   'are',
#   'taken',
#   'care',
#   'of',
#   'internally',
#   'As',
#   'this',
#   'is',
#   'internal',
#   'information',
#   'we',
#   'can',
#   'not',
#   'provide',
#   'much',
#   'details',
#   'related',
#   'to',
#   'this',
#   'However',
#   'we',
#   'need',
#   'the',
#   'create',
#   'and',
#   'delete',
#   'permissions',
#   'because',
#   'these',
#   'ENIs',
#   'are',
#   'created',
#   'in',
#   'your',
#   'account',
#   'and',
#   'would',
#   'require',
#   'permissions',
#   'for',
#   'the',
#   'same',
#   'I',
#   'hope',
#   'this',
#   'answers',
#   'your',
#   'query',
#   'Please',
#   'let',
#   'us',
#   'know',
#   'if',
#   'you',
#   'have',
#   'any',
#   'other',
#   'queries'],
#  ['Thanks'],
#  ['Pass',
#   'Cognito',
#   'credentials/identity',
#   'from',
#   'API',
#   'Gateway',
#   'to',
#   'Lambda',
#   'Python',
#   '3.6',
#   '.',
#   'Hi',
#   'I',
#   'have',
#   'couple',
#   'of',
#   'endpoints',
#   'in',
#   'API',
#   'Gateway',
#   'configured',
#   'with',
#   'Cognito',
#   'Authorizer',
#   'a',
#   'Client',
#   'App',
#   'in',
#   'Cognito',
#   'User',
#   'Pool',
#   'configured',
#   'with',
#   'the',
#   'Client',
#   'Credentials',
#   'flow',
#   ',',
#   'the',
#   'endpoints',
#   'are',
#   'integrated',
#   'with',
#   'Lambda',
#   'function',
#   'Python',
#   '3.6',
#   '.',
#   'need',
#   'to',
#   'know',
#   'in',
#   'my',
#   'Lambda',
#   'function',
#   'what',
#   "'s",
#   'the',
#   'client',
#   'app',
#   'used',
#   'to',
#   'perform',
#   'the',
#   'API',
#   'access',
#   'but',
#   'do',
#   "n't",
#   'see',
#   'anything',
#   'in',
#   'the',
#   'context',
#   'object',
#   'and',
#   'my',
#   'event',
#   'variable',
#   'about',
#   'the',
#   'Cognito',
#   'identity',
#   'Any',
#   'idea',
#   'Thank',
#   'you',
#   'so',
#   'much'],
#  ['Hello',
#   'Amazon',
#   'Cognito',
#   'user',
#   'pool',
#   'returns',
#   'different',
#   'properties',
#   'in',
#   'the',
#   'JSON',
#   'claims',
#   'response',
#   'after',
#   'the',
#   'method',
#   'caller',
#   'is',
#   'successfully',
#   'authenticated',
#   'The',
#   'JSON',
#   'claims',
#   'response',
#   'looks',
#   'like',
#   'below',
#   '{',
#   '``',
#   'sub',
#   "''",
#   '``',
#   'x-x-x-x-x',
#   "''",
#   '``',
#   'aud',
#   "''",
#   '``',
#   'xyz',
#   "''",
#   '``',
#   'email_verified',
#   "''",
#   '``',
#   'true',
#   "''",
#   '``',
#   'token_use',
#   "''",
#   '``',
#   'id',
#   "''",
#   '``',
#   'auth_time',
#   "''",
#   '``',
#   '1499671038',
#   "''",
#   '``',
#   'iss',
#   "''",
#   '``',
#   'https',
#   '//cognito-idp.us-west-2.amazonaws.com/us-west-2_abcd',
#   "''",
#   '``',
#   'cognito',
#   'username',
#   "''",
#   '``',
#   'user2',
#   "''",
#   '``',
#   'exp',
#   "''",
#   '``',
#   '10',
#   '08:17:18',
#   'UTC',
#   '2017',
#   "''",
#   '``',
#   'iat',
#   "''",
#   '``',
#   '10',
#   '07:17:18',
#   'UTC',
#   '2017',
#   "''",
#   '``',
#   'email',
#   "''",
#   '``',
#   'abc',
#   'xyz.com',
#   "''",
#   'The',
#   'context',
#   'variable',
#   'holds',
#   'all',
#   'the',
#   'contextual',
#   'information',
#   'of',
#   'your',
#   'API',
#   'call',
#   'will',
#   'be',
#   'used',
#   'to',
#   'get',
#   'these',
#   'properties',
#   'from',
#   'claims',
#   'response',
#   '1',
#   '.',
#   'The',
#   'aud',
#   'claim',
#   'here',
#   'will',
#   'hold',
#   'the',
#   'app',
#   'client',
#   'ID',
#   'You',
#   'can',
#   'add',
#   'the',
#   'below',
#   'in',
#   'the',
#   'mapping',
#   'template',
#   'of',
#   'Integration',
#   'Request',
#   '{',
#   '``',
#   'context',
#   "''",
#   '{',
#   '``',
#   'appclient',
#   "''",
#   '``',
#   'context.authorizer.claims',
#   "'aud",
#   ']',
#   "''",
#   '}',
#   'hope',
#   'this',
#   'helps',
#   'Please',
#   'let',
#   'us',
#   'know',
#   'if',
#   'you',
#   'have',
#   'any',
#   'other',
#   'queries',
#   '[',
#   ']',
#   'https',
#   '//docs.aws.amazon.com/apigateway/latest/developerguide/apigateway-enable-cognito-user-pool.html'],
#  ['Lambda',
#   'Layers',
#   'not',
#   'supported',
#   'with',
#   'SAM/CloudFormation',
#   'in',
#   'eu-north-1',
#   'Have',
#   'serverless-template',
#   'with',
#   '``',
#   'AWS',
#   ':Serverless',
#   ':LayerVersion',
#   "''",
#   'when',
#   'trying',
#   'to',
#   'deploy',
#   'in',
#   'eu-north-1',
#   'get',
#   '``',
#   'FAILED',
#   'Reason',
#   'Template',
#   'format',
#   'error',
#   'Unrecognized',
#   'resource',
#   'types',
#   'https',
#   '//forums.aws.amazon.com/',
#   "''",
#   'When',
#   'trying',
#   'in',
#   'eu-west-1',
#   'it',
#   'deploys',
#   'OK.',
#   'Bug',
#   'or',
#   'just',
#   'not',
#   'supported',
#   'in',
#   'Stockholm'],
#  ["'ve",
#   'noticed',
#   'the',
#   'same',
#   'problem',
#   'with',
#   'eu-north-1',
#   'Have',
#   'not',
#   'been',
#   'able',
#   'to',
#   'find',
#   'any',
#   'documentation',
#   'regarding',
#   'this',
#   'This',
#   'forum',
#   'post',
#   'was',
#   'the',
#   'only',
#   'relevant',
#   'search',
#   'result',
#   'on',
#   'Google'],
#  ['got',
#   'message',
#   'from',
#   'someone',
#   'saying',
#   'that',
#   'the',
#   'support',
#   'for',
#   'Layers/Serverless',
#   'in',
#   'CF',
#   'is',
#   'deployed',
#   'by',
#   'the',
#   'Lambda-team',
#   'not',
#   'CF-team',
#   ',',
#   'and',
#   'that',
#   'latest',
#   'version',
#   'hopefully',
#   'would',
#   'come',
#   'soon',
#   '...',
#   'have',
#   'not',
#   'tested',
#   'rcently'],
#  ['CodeBuild',
#   'Error',
#   'UNAUTHORIZED_OPERATION_CREATE_NETWORK_INTERFACE',
#   'Error',
#   'in',
#   'codebuild',
#   'UNAUTHORIZED_OPERATION_CREATE_NETWORK_INTERFACE',
#   'The',
#   'service',
#   'role',
#   'is',
#   'not',
#   'authorized',
#   'to',
#   'perform',
#   'ec2',
#   'CreateNetworkInterface',
#   'am',
#   'trying',
#   'to',
#   'allow',
#   'my',
#   'Codebuild',
#   'config',
#   'connect',
#   'to',
#   'VPC',
#   'but',
#   'when',
#   'allow',
#   'the',
#   'connection',
#   'i',
#   'am',
#   'getting',
#   'the',
#   'following',
#   'error',
#   'upon',
#   'build',
#   'UNAUTHORIZED_OPERATION_CREATE_NETWORK_INTERFACE',
#   'The',
#   'service',
#   'role',
#   'is',
#   'not',
#   'authorized',
#   'to',
#   'perform',
#   'ec2',
#   'CreateNetworkInterface',
#   'have',
#   'already',
#   'attempted',
#   'to',
#   'add',
#   'the',
#   'ec2',
#   'CreateNetworkInterface',
#   'to',
#   'all',
#   'used',
#   'roles',
#   'but',
#   'still',
#   'no',
#   'luck'],
#  ["'ve",
#   'hit',
#   'the',
#   'same',
#   'problem',
#   'did',
#   'you',
#   'have',
#   'any',
#   'luck',
#   'sorting',
#   'it',
#   'out',
#   'UPDATE',
#   'I',
#   'was',
#   'using',
#   'codestar',
#   'for',
#   'this',
#   'and',
#   'the',
#   'generated',
#   'permission',
#   'boundary',
#   'on',
#   'the',
#   'pipeline',
#   'role',
#   'seems',
#   'to',
#   'be',
#   'the',
#   'issue',
#   'Temporarily',
#   'removing',
#   'it',
#   'and',
#   'adding',
#   'the',
#   'EC2',
#   'permissions',
#   'seems',
#   'to',
#   'have',
#   'fixed',
#   'it',
#   'for',
#   'now',
#   'I',
#   "'ll",
#   'need',
#   'to',
#   'narrow',
#   'down',
#   'what',
#   'need',
#   'to',
#   'add',
#   'to',
#   'the',
#   'boundary',
#   'for',
#   'it',
#   'to',
#   'work',
#   'but',
#   'that',
#   'part',
#   'is',
#   'probably',
#   'specific',
#   'to',
#   'my',
#   'account',
#   'Good',
#   'luck',
#   'Edited',
#   'by',
#   'Buzzologist',
#   'on',
#   '20',
#   '2019',
#   '7:05',
#   'PM'],
#  ['You',
#   'have',
#   'to',
#   'grant',
#   'few',
#   'different',
#   'EC2',
#   'permissions',
#   'for',
#   'it',
#   'to',
#   'work',
#   '{',
#   '``',
#   'Effect',
#   "''",
#   '``',
#   'Allow',
#   "''",
#   '``',
#   'Action',
#   "''",
#   '[',
#   '``',
#   'ec2',
#   'CreateNetworkInterface',
#   "''",
#   '``',
#   'ec2',
#   'DescribeDhcpOptions',
#   "''",
#   '``',
#   'ec2',
#   'DescribeNetworkInterfaces',
#   "''",
#   '``',
#   'ec2',
#   'DeleteNetworkInterface',
#   "''",
#   '``',
#   'ec2',
#   'DescribeSubnets',
#   "''",
#   '``',
#   'ec2',
#   'DescribeSecurityGroups',
#   "''",
#   '``',
#   'ec2',
#   'DescribeVpcs',
#   "''",
#   ',',
#   '``',
#   'Resource',
#   "''",
#   '``',
#   "''",
#   ',',
#   '``',
#   'Effect',
#   "''",
#   '``',
#   'Allow',
#   "''",
#   '``',
#   'Action',
#   "''",
#   '[',
#   '``',
#   'ec2',
#   'CreateNetworkInterfacePermission',
#   "''",
#   ',',
#   '``',
#   'Resource',
#   "''",
#   '``',
#   'arn',
#   'aws',
#   'ec2',
#   '<',
#   'REGION',
#   ':',
#   'ACCOUNTNUMBER',
#   ':',
#   'network-interface/*',
#   "''",
#   '``',
#   'Condition',
#   "''",
#   '{',
#   '``',
#   'StringEquals',
#   "''",
#   '{',
#   '``',
#   'ec2',
#   'Subnet',
#   "''",
#   '[',
#   '``',
#   'arn',
#   'aws',
#   'ec2',
#   '<',
#   'REGION',
#   ':',
#   'ACCOUNTNUMBER',
#   ':',
#   'subnet/subnet-',
#   'ID',
#   "''",
#   ',',
#   '``',
#   'ec2',
#   'AuthorizedService',
#   "''",
#   '``',
#   'codebuild.amazonaws.com',
#   "''",
#   '}',
#   'The',
#   'permission',
#   'section',
#   'is',
#   'only',
#   'need',
#   'if',
#   'you',
#   'want',
#   'to',
#   'restrict',
#   'code',
#   'build',
#   'to',
#   'only',
#   'using',
#   'specific',
#   'subnet',
#   'It',
#   'can',
#   'be',
#   'removed',
#   'if',
#   'you',
#   'do',
#   "n't",
#   'want',
#   'that',
#   'restriction'],
#  ['Sending',
#   'Webpush',
#   'notification',
#   'through',
#   'Lambda',
#   'Hi',
#   'I',
#   'am',
#   'developing',
#   'progressive',
#   'web',
#   'app',
#   'PWA',
#   'and',
#   'as',
#   'part',
#   'of',
#   'that',
#   'am',
#   'trying',
#   'to',
#   'send',
#   'web',
#   'push',
#   'notification',
#   'to',
#   'clients',
#   'The',
#   'setup',
#   'is',
#   'upon',
#   'certain',
#   'actions',
#   'by',
#   'client',
#   'a',
#   'message',
#   'containing',
#   'subscription',
#   'and',
#   'payload',
#   'information',
#   'is',
#   'stored',
#   'in',
#   'SQS',
#   'and',
#   'whenever',
#   'message',
#   'is',
#   'pushed',
#   'to',
#   'SQS',
#   'a',
#   'lambda',
#   'is',
#   'triggered',
#   'The',
#   'lambda',
#   'is',
#   'used',
#   'to',
#   'send',
#   'the',
#   'push',
#   'notification',
#   'to',
#   'the',
#   'clients',
#   'using',
#   'the',
#   'nodejs',
#   'web-push',
#   'library',
#   'However',
#   'what',
#   'see',
#   'is',
#   'lambda',
#   'is',
#   'successfully',
#   'invoked',
#   'and',
#   'able',
#   'to',
#   'read',
#   'the',
#   'message',
#   'from',
#   'SQS',
#   'but',
#   'it',
#   'does',
#   'not',
#   'deliver',
#   'the',
#   'web',
#   'push',
#   'notification',
#   'The',
#   'code',
#   'does',
#   'not',
#   'log',
#   '``',
#   'Succeeded',
#   "''",
#   'or',
#   'any',
#   'error',
#   'details',
#   'It',
#   'directly',
#   'logs',
#   '``',
#   'Everything',
#   'done',
#   "''",
#   'Let',
#   'me',
#   'know',
#   'what',
#   'am',
#   'doing',
#   'wrong',
#   'Here',
#   'is',
#   'the',
#   'lambda',
#   'code',
#   'const',
#   'webpush',
#   'require',
#   "'web-push",
#   ')',
#   'exports.handler',
#   'async',
#   'function',
#   'event',
#   'context',
#   '{',
#   'var',
#   'publicVapidKey=',
#   "''",
#   'A_public_vapid_key',
#   "''",
#   'var',
#   'privateVapidKey=',
#   "''",
#   'A_pprivate_vapid_key',
#   "''",
#   'var',
#   'supportEmail=',
#   "''",
#   'our',
#   'email.address',
#   "''",
#   '//',
#   'Replace',
#   'with',
#   'your',
#   'email',
#   'webpush.setVapidDetails',
#   '`',
#   'mailto',
#   '$',
#   'supportEmail',
#   '`',
#   'publicVapidKey',
#   'privateVapidKey',
#   ';',
#   'console.log',
#   'event',
#   ';',
#   'event.Records.forEach',
#   'record',
#   '>',
#   'console.log',
#   'record',
#   ';',
#   'console.log',
#   '``',
#   'Body',
#   "''",
#   'JSON.parse',
#   'record.body',
#   ')',
#   'const',
#   'body',
#   'JSON.parse',
#   'record.body',
#   ';',
#   'const',
#   'subscription',
#   'body.subscription',
#   'const',
#   'requestPayload',
#   'body.payload',
#   'const',
#   'payload',
#   'JSON.stringify',
#   '{',
#   'title',
#   'requestPayload.title',
#   'content',
#   'requestPayload.content',
#   'openUrl',
#   'requestPayload.url',
#   ')',
#   'webpush.sendNotification',
#   'subscription',
#   'payload',
#   '.then',
#   '(',
#   '=',
#   '{',
#   'console.log',
#   "'\\nNotification",
#   'pushed',
#   'successfully',
#   "'",
#   'record.MessageId',
#   ';',
#   'context.done',
#   '``',
#   'Succeeded',
#   "''",
#   '//deleteMessage',
#   'element',
#   'queueUrl',
#   '}',
#   '.catch',
#   'error',
#   '>',
#   'console.error',
#   '`',
#   '\\nError',
#   'in',
#   'sending',
#   'notification',
#   '$',
#   'error',
#   '-',
#   '{',
#   'error.stack',
#   '`',
#   ';',
#   'context.fail',
#   'error',
#   ';',
#   ')',
#   'console.log',
#   '``',
#   'Everything',
#   'Done',
#   "''",
#   '}',
#   ';',
#   'return',
#   '}',
#   '}',
#   'Edited',
#   'by',
#   'ashishsheth',
#   'on',
#   ',',
#   '2019',
#   '9:59',
#   'PM'],
#  ['Code',
#   'Storage',
#   'Does',
#   'it',
#   'reuse',
#   'deployment',
#   'package',
#   'Hello',
#   'I',
#   'have',
#   'several',
#   'functions',
#   'using',
#   'same',
#   'deployment',
#   'package',
#   'like',
#   'this',
#   '...',
#   '``',
#   'DeleteDashuserLambdaFunction',
#   "''",
#   '{',
#   '``',
#   'Type',
#   "''",
#   '``',
#   'AWS',
#   ':Lambda',
#   ':Function',
#   "''",
#   '``',
#   'Properties',
#   "''",
#   '{',
#   '``',
#   'Code',
#   "''",
#   '{',
#   '``',
#   'S3Bucket',
#   "''",
#   '``',
#   'dev.eu-west-1.serverless.deploys.em.com',
#   "''",
#   '``',
#   'S3Key',
#   "''",
#   '``',
#   'serverless/user-service-ts/dev/1554451324595-2019-04-05T08:02:04.595Z/user-service-ts.zip',
#   "''",
#   ',',
#   '...',
#   '``',
#   'InviteDashuserLambdaFunction',
#   "''",
#   '{',
#   '``',
#   'Type',
#   "''",
#   '``',
#   'AWS',
#   ':Lambda',
#   ':Function',
#   "''",
#   '``',
#   'Properties',
#   "''",
#   '{',
#   '``',
#   'Code',
#   "''",
#   '{',
#   '``',
#   'S3Bucket',
#   "''",
#   '``',
#   'dev.eu-west-1.serverless.deploys.em.com',
#   "''",
#   '``',
#   'S3Key',
#   "''",
#   '``',
#   'serverless/user-service-ts/dev/1554451324595-2019-04-05T08:02:04.595Z/user-service-ts.zip',
#   "''",
#   ',',
#   '...',
#   'Will',
#   'the',
#   'lambda',
#   'reuse',
#   'the',
#   'deployment',
#   'package',
#   'What',
#   "'s",
#   'more',
#   'effective',
#   'from',
#   'the',
#   'code',
#   'storage',
#   'perspective',
#   'use',
#   'one',
#   'zip',
#   'say',
#   '10MB',
#   'for',
#   'several',
#   'functions',
#   'or',
#   'split',
#   'into',
#   'smaller',
#   'zips',
#   '10',
#   'packages',
#   'MB',
#   'each',
#   '?'],
#  ['Lambda',
#   'javascript',
#   'API',
#   'missing',
#   'functions',
#   'am',
#   'trying',
#   'to',
#   'setup',
#   'Lambda',
#   'to',
#   'call',
#   'cloudWatch.getMetricWidgetImage',
#   '{',
#   '...',
#   ')',
#   'but',
#   'the',
#   'api',
#   'is',
#   'returning',
#   'not',
#   'found',
#   'error',
#   'If',
#   'test',
#   'locally',
#   'with',
#   'the',
#   'npm',
#   'api',
#   'version',
#   'then',
#   'it',
#   'works',
#   'but',
#   'it',
#   'appears',
#   'that',
#   'api',
#   'included',
#   'with',
#   'Lambda',
#   'does',
#   'not',
#   'include',
#   'this',
#   'function',
#   '{',
#   '``',
#   'errorMessage',
#   "''",
#   "''",
#   'cloudWatch.getMetricWidgetImage',
#   'is',
#   'not',
#   'function',
#   "''",
#   "''",
#   'errorType',
#   "''",
#   "''",
#   'TypeError',
#   "''",
#   "''",
#   'stackTrace',
#   "''",
#   '[',
#   '``',
#   'exports.handler',
#   '/var/task/index.js:9:39',
#   "''",
#   '}',
#   'Below',
#   'is',
#   'my',
#   'code',
#   'the',
#   'console.log',
#   'is',
#   'there',
#   'to',
#   'test',
#   'whether',
#   'the',
#   'property',
#   'existed',
#   'and',
#   'to',
#   'check',
#   'if',
#   'some',
#   'of',
#   'the',
#   'other',
#   'functions',
#   'existed',
#   'that',
#   'call',
#   'below',
#   'just',
#   'returns',
#   'undefined',
#   'const',
#   'AWS',
#   'require',
#   "'aws-sdk",
#   ')',
#   'const',
#   'cloudWatch',
#   'new',
#   'AWS.CloudWatch',
#   ')',
#   'exports.handler',
#   'async',
#   'event',
#   '=',
#   '{',
#   'const',
#   'params',
#   '{',
#   'MetricWidget',
#   'JSON.stringify',
#   'event',
#   '}',
#   'console.log',
#   'new',
#   'AWS.CloudWatch',
#   ')',
#   '.getMetricWidgetImage',
#   ';',
#   'const',
#   'response',
#   'await',
#   'cloudWatch.getMetricWidgetImage',
#   'params',
#   '.promise',
#   ')',
#   'return',
#   'response.MetricWidgetImage',
#   '}'],
#  ['Expired',
#   'Token',
#   'Occasionally',
#   'my',
#   'lambda',
#   'calls',
#   'will',
#   'get',
#   'errors',
#   'for',
#   'few',
#   'minutes',
#   'that',
#   'look',
#   'like',
#   'this',
#   '[',
#   'ExpiredToken',
#   'The',
#   'provided',
#   'token',
#   'has',
#   'expired',
#   ']',
#   'message',
#   "'The",
#   'provided',
#   'token',
#   'has',
#   'expired',
#   "'",
#   'code',
#   "'ExpiredToken",
#   ',',
#   'time',
#   '19',
#   '2015',
#   '00:32:14',
#   'GMT-0800',
#   'PST',
#   ',',
#   'statusCode',
#   '400',
#   'retryable',
#   'true',
#   'This',
#   'seems',
#   'to',
#   'be',
#   'coming',
#   'from',
#   'the',
#   'my',
#   'attempt',
#   'to',
#   'upload',
#   'to',
#   'S3',
#   'My',
#   'role',
#   'has',
#   'that',
#   'ability',
#   'and',
#   'it',
#   'works',
#   'most',
#   'of',
#   'the',
#   'time'],
#  ['Thanks',
#   'for',
#   'reporting',
#   'this',
#   'issue',
#   'Jeremymcjunkin',
#   'We',
#   'are',
#   'working',
#   'on',
#   'fix',
#   'and',
#   'will',
#   'update',
#   'this',
#   'thread',
#   'when',
#   'it',
#   'has',
#   'been',
#   'pushed'],
#  ['Agreed',
#   'thanks',
#   '--',
#   'is',
#   'there',
#   'any',
#   'update',
#   'from',
#   'the',
#   'AWS',
#   'side',
#   'on',
#   'this',
#   'We',
#   "'re",
#   'also',
#   'seeing',
#   'this',
#   'issue',
#   'frequently',
#   'and',
#   'are',
#   'hoping',
#   'to',
#   'fix',
#   'soon',
#   'Thanks'],
#  ['We',
#   "'ve",
#   'deployed',
#   'change',
#   'that',
#   'should',
#   'fix',
#   'the',
#   'issue',
#   'Please',
#   'let',
#   'us',
#   'know',
#   'if',
#   'you',
#   'are',
#   'still',
#   'seeing',
#   'this',
#   'happen'],
#  ['just',
#   'received',
#   'similar',
#   'error',
#   'Is',
#   'this',
#   'an',
#   'issue',
#   'on',
#   'the',
#   'Lambda',
#   'side',
#   'or',
#   'something',
#   "'m",
#   'doing',
#   'wrong',
#   '2015-07-16T04:35:22.871Z',
#   '11a7f9e9-2b74-11e5-8c00-475603917ab3',
#   '``',
#   'errorMessage',
#   "''",
#   "''",
#   'The',
#   'security',
#   'token',
#   'included',
#   'in',
#   'the',
#   'request',
#   'is',
#   'invalid',
#   '``',
#   "''",
#   'errorType',
#   "''",
#   "''",
#   'UnrecognizedClientException',
#   "''",
#   "''",
#   'stackTrace',
#   "''",
#   '[',
#   '``',
#   'Request.extractError',
#   '/var/runtime/node_modules/aws-sdk/lib/protocol/json.js:43:27',
#   "''",
#   "''",
#   'Request.callListeners',
#   '/var/runtime/node_modules/aws-sdk/lib/sequential_executor.js:105:20',
#   "''",
#   "''",
#   'Request.emit',
#   '/var/runtime/node_modules/aws-sdk/lib/sequential_executor.js:77:10',
#   "''",
#   "''",
#   'Request.emit',
#   '/var/runtime/node_modules/aws-sdk/lib/request.js:595:14',
#   "''",
#   "''",
#   'Request.transition',
#   '/var/runtime/node_modules/aws-sdk/lib/request.js:21:10',
#   "''",
#   "''",
#   'AcceptorStateMachine.runTo',
#   '/var/runtime/node_modules/aws-sdk/lib/state_machine.js:14:12',
#   "''",
#   "''",
#   '/var/runtime/node_modules/aws-sdk/lib/state_machine.js:26:10',
#   "''",
#   "''",
#   'Request.',
#   'anonymous',
#   '(',
#   '/var/runtime/node_modules/aws-sdk/lib/request.js:37:9',
#   "''",
#   "''",
#   'Request.',
#   'anonymous',
#   '(',
#   '/var/runtime/node_modules/aws-sdk/lib/request.js:597:12',
#   "''",
#   "''",
#   'Request.callListeners',
#   '/var/runtime/node_modules/aws-sdk/lib/sequential_executor.js:115:18',
#   "''",
#   '}',
#   'END',
#   'RequestId',
#   '11a7f9e9-2b74-11e5-8c00-475603917ab3',
#   'Edited',
#   'by',
#   'M.',
#   'Garnaat',
#   'on',
#   '16',
#   '2015',
#   '12:39',
#   'AM'],
#  ['That',
#   'particular',
#   'problem',
#   'seemed',
#   'to',
#   'go',
#   'away',
#   'over',
#   'night',
#   'Now',
#   "'m",
#   'getting',
#   'this',
#   '2015-07-16T14:39:31.785Z',
#   '77258836-2bc8-11e5-820b-0f95ad6ce145',
#   '``',
#   'errorMessage',
#   "''",
#   "''",
#   'The',
#   'AWS',
#   'Access',
#   'Key',
#   'Id',
#   'you',
#   'provided',
#   'does',
#   'not',
#   'exist',
#   'in',
#   'our',
#   'records',
#   '``',
#   "''",
#   'errorType',
#   "''",
#   "''",
#   'InvalidAccessKeyId',
#   "''",
#   "''",
#   'stackTrace',
#   "''",
#   '[',
#   '``',
#   'Request.extractError',
#   '/var/runtime/node_modules/aws-sdk/lib/services/s3.js:321:35',
#   "''",
#   "''",
#   'Request.callListeners',
#   '/var/runtime/node_modules/aws-sdk/lib/sequential_executor.js:105:20',
#   "''",
#   "''",
#   'Request.emit',
#   '/var/runtime/node_modules/aws-sdk/lib/sequential_executor.js:77:10',
#   "''",
#   "''",
#   'Request.emit',
#   '/var/runtime/node_modules/aws-sdk/lib/request.js:595:14',
#   "''",
#   "''",
#   'Request.transition',
#   '/var/runtime/node_modules/aws-sdk/lib/request.js:21:10',
#   "''",
#   "''",
#   'AcceptorStateMachine.runTo',
#   '/var/runtime/node_modules/aws-sdk/lib/state_machine.js:14:12',
#   "''",
#   "''",
#   '/var/runtime/node_modules/aws-sdk/lib/state_machine.js:26:10',
#   "''",
#   "''",
#   'Request.',
#   'anonymous',
#   '(',
#   '/var/runtime/node_modules/aws-sdk/lib/request.js:37:9',
#   "''",
#   "''",
#   'Request.',
#   'anonymous',
#   '(',
#   '/var/runtime/node_modules/aws-sdk/lib/request.js:597:12',
#   "''",
#   "''",
#   'Request.callListeners',
#   '/var/runtime/node_modules/aws-sdk/lib/sequential_executor.js:115:18',
#   "''",
#   '}',
#   'END',
#   'RequestId',
#   '77258836-2bc8-11e5-820b-0f95ad6ce145',
#   'think',
#   'the',
#   'issue',
#   'is',
#   'that',
#   'occasionally',
#   'delete',
#   'my',
#   'Lambda',
#   'function',
#   'and',
#   'all',
#   'roles',
#   'and',
#   'policies',
#   'have',
#   'created',
#   'for',
#   'it',
#   'and',
#   'start',
#   'over',
#   'again',
#   'This',
#   'is',
#   'an',
#   'easy',
#   'thing',
#   'to',
#   'do',
#   'with',
#   'kappa',
#   'and',
#   'it',
#   "'s",
#   'good',
#   'test',
#   'to',
#   'make',
#   'sure',
#   'my',
#   'configuration',
#   'is',
#   'actually',
#   'working',
#   'properly',
#   'However',
#   'if',
#   'the',
#   'role',
#   'gets',
#   'deleted',
#   'it',
#   'seems',
#   'like',
#   'some',
#   'STS',
#   'credentials',
#   'are',
#   'being',
#   'cached',
#   'somewhere',
#   'and',
#   'continue',
#   'to',
#   'be',
#   'used',
#   'to',
#   'execute',
#   'the',
#   'Lambda',
#   'function',
#   'even',
#   'though',
#   'they',
#   'are',
#   'no',
#   'longer',
#   'valid',
#   'Usually',
#   'waiting',
#   'an',
#   'hour',
#   'clears',
#   'up',
#   'the',
#   'problem',
#   'although',
#   'this',
#   'latest',
#   'one',
#   'has',
#   'lasted',
#   'more',
#   'than',
#   'an',
#   'hour',
#   'I',
#   "'ve",
#   'been',
#   'using',
#   'this',
#   'basic',
#   'workflow',
#   'since',
#   'Lambda',
#   'was',
#   'released',
#   'and',
#   "'ve",
#   'never',
#   'had',
#   'this',
#   'problem',
#   'before',
#   'so',
#   'think',
#   'something',
#   'has',
#   'changed',
#   'on',
#   'the',
#   'AWS',
#   'side',
#   'to',
#   'cause',
#   'this',
#   'Mitch'],
#  ["'ve",
#   'been',
#   'seeing',
#   'this',
#   'is',
#   'my',
#   'lambda',
#   'function',
#   'as',
#   'well',
#   'It',
#   "'s",
#   'simple',
#   'function',
#   'that',
#   'reads',
#   'some',
#   'data',
#   'from',
#   'S3',
#   'checks',
#   'an',
#   'internet',
#   'site',
#   'and',
#   'then',
#   'writes',
#   'it',
#   'back',
#   'It',
#   'get',
#   'this',
#   '{',
#   'ExpiredToken',
#   'The',
#   'provided',
#   'token',
#   'has',
#   'expired',
#   'message',
#   "'The",
#   'provided',
#   'token',
#   'has',
#   'expired',
#   "'",
#   'code',
#   "'ExpiredToken",
#   ',',
#   'time',
#   '11',
#   '2015',
#   '21:46:03',
#   'GMT+0000',
#   'UTC',
#   ',',
#   'statusCode',
#   '400',
#   'retryable',
#   'true',
#   'It',
#   'happens',
#   'infrequently',
#   'the',
#   'lambda',
#   'function',
#   'is',
#   'running',
#   'every',
#   '15',
#   'minutes',
#   'and',
#   'this',
#   'happens',
#   'once',
#   'or',
#   'twice',
#   'day',
#   'But',
#   'it',
#   'has',
#   'me',
#   'concerned',
#   'to',
#   'use',
#   'it',
#   'for',
#   'more',
#   'mission',
#   'critical',
#   'work'],
#  ['Has',
#   'this',
#   'been',
#   'resolved',
#   'I',
#   "'m",
#   'getting',
#   'this',
#   'same',
#   'issue',
#   'for',
#   'java',
#   'web',
#   'service',
#   'running',
#   'in',
#   'tomcat',
#   'EBS',
#   'using',
#   'latest',
#   '1.10.50',
#   'libs'],
#  ['am',
#   'getting',
#   'the',
#   'same',
#   'issue',
#   'using',
#   'the',
#   'same',
#   'configuration',
#   'as',
#   'corvi42'],
#  ['Hi',
#   'I',
#   'still',
#   'get',
#   'same',
#   'error',
#   "'Token",
#   'expired',
#   'when',
#   'try',
#   'to',
#   'upload',
#   'bulk',
#   'data',
#   'like',
#   'upload',
#   'of',
#   'multiple',
#   'folder',
#   'nearly',
#   'each',
#   'folder',
#   'of',
#   'size',
#   '20GB',
#   'and',
#   'more',
#   'from',
#   'client',
#   'side',
#   'to',
#   's3',
#   'Is',
#   'this',
#   'resolved',
#   'ExpiredToken',
#   'The',
#   'provided',
#   'token',
#   'has',
#   'expired',
#   'at',
#   'constructor.extractError',
#   'bucket_name/inspections/20180730_DTS4/Run4/Cam3/180730_DTS4_4~F394~C3.jpg',
#   "''",
#   'Please',
#   'let',
#   'me',
#   'know',
#   'if',
#   'the',
#   'issue',
#   'could',
#   'be',
#   'resolved',
#   'from',
#   'client',
#   'side',
#   'Edited',
#   'by',
#   'Ranjitha',
#   'on',
#   ',',
#   '2019',
#   '11:33',
#   'PM'],
#  ['How',
#   'to',
#   'run',
#   'python',
#   'code',
#   'on',
#   'AWS',
#   'lambda',
#   'with',
#   'package',
#   'dependencies',
#   '500MB',
#   'The',
#   'requirement',
#   'is',
#   'that',
#   'have',
#   'to',
#   'trigger',
#   'SageMaker',
#   'endpoint',
#   'on',
#   'lambda',
#   'to',
#   'get',
#   'predictions',
#   'which',
#   'is',
#   'easy',
#   'but',
#   'have',
#   'to',
#   'do',
#   'some',
#   'extra',
#   'processing',
#   'for',
#   'variable',
#   'importance',
#   'using',
#   'packages',
#   'such',
#   'as',
#   'XGBoost',
#   'and',
#   'SHAP',
#   'I',
#   'am',
#   'able',
#   'to',
#   'hit',
#   'the',
#   'endpoint',
#   'and',
#   'get',
#   'variable',
#   'importance',
#   'using',
#   'the',
#   'SageMaker',
#   'Jupyter',
#   'notebook',
#   'Now',
#   'I',
#   'want',
#   'to',
#   'replicate',
#   'the',
#   'same',
#   'thing',
#   'on',
#   'AWS',
#   'lambda',
#   '1',
#   'How',
#   'to',
#   'run',
#   'python',
#   'code',
#   'on',
#   'AWS',
#   'lambda',
#   'with',
#   'package',
#   'dependencies',
#   'for',
#   'Pandas',
#   'XGBoost',
#   'and',
#   'SHAP',
#   'total',
#   'package',
#   'size',
#   'greater',
#   'than',
#   '500MB',
#   '.',
#   'The',
#   'unzipped',
#   'deployment',
#   'package',
#   'size',
#   'is',
#   'greater',
#   'than',
#   '250',
#   'MB',
#   'hence',
#   'lambda',
#   'is',
#   'not',
#   'allowing',
#   'to',
#   'deploy',
#   'I',
#   'even',
#   'tried',
#   'using',
#   'lambda',
#   'function',
#   'from',
#   'Cloud9',
#   'and',
#   'got',
#   'the',
#   'same',
#   'error',
#   'due',
#   'to',
#   'size',
#   'restrictions',
#   'I',
#   'have',
#   'also',
#   'tried',
#   'lambda',
#   'layers',
#   'but',
#   'no',
#   'luck',
#   '2',
#   'Is',
#   'there',
#   'way',
#   'for',
#   'me',
#   'to',
#   'run',
#   'the',
#   'code',
#   'with',
#   'such',
#   'big',
#   'packages',
#   'on',
#   'or',
#   'through',
#   'lambda',
#   'bypassing',
#   'the',
#   'deployment',
#   'package',
#   'size',
#   'limitation',
#   'of',
#   '250',
#   'MB',
#   ')',
#   'Is',
#   'there',
#   'way',
#   'to',
#   'trigger',
#   'SageMaker',
#   'notebook',
#   'execution',
#   'through',
#   'lambda',
#   'which',
#   'would',
#   'do',
#   'the',
#   'calculations',
#   'and',
#   'return',
#   'the',
#   'output',
#   'back',
#   'to',
#   'lambda',
#   'Edited',
#   'by',
#   'Tdoo7',
#   'on',
#   ',',
#   '2019',
#   '2:37',
#   'PM'],
#  ['Global',
#   'Accelerator',
#   'with',
#   'Lambda',
#   'path',
#   'patterns',
#   'Hi',
#   'I',
#   'have',
#   'an',
#   'application',
#   'load',
#   'balancer',
#   'set',
#   'up',
#   'and',
#   'can',
#   'send',
#   'requests',
#   'via',
#   'the',
#   'one',
#   'ALB',
#   'to',
#   'different',
#   'lambda',
#   'functions',
#   'based',
#   'on',
#   'path',
#   'patterns',
#   'I',
#   'added',
#   'global',
#   'accelerator',
#   'and',
#   'the',
#   'path',
#   'patterns',
#   'do',
#   "n't",
#   'seem',
#   'to',
#   'be',
#   'recognised',
#   'when',
#   'using',
#   'the',
#   'global',
#   'accelerator',
#   'Just',
#   'wondering',
#   'if',
#   'this',
#   'is',
#   'functionality',
#   'that',
#   'should',
#   'work',
#   'I',
#   'tried',
#   'seeing',
#   'if',
#   'could',
#   'add',
#   'additional',
#   'endpoint',
#   'groups',
#   'but',
#   'ca',
#   "n't",
#   'add',
#   'second',
#   'listener',
#   'for',
#   'port',
#   '80',
#   'which',
#   'the',
#   'ALB',
#   'is',
#   'listening',
#   'on',
#   'Any',
#   'ideas',
#   'appreciated',
#   'Thanks'],
#  ['Hi',
#   'there',
#   'Yes',
#   'this',
#   'is',
#   'functionality',
#   'that',
#   'should',
#   'work',
#   'An',
#   'ALB',
#   'behind',
#   'Global',
#   'Accelerator',
#   'allows',
#   'you',
#   'to',
#   'route',
#   'to',
#   'your',
#   'Lambda',
#   'functions',
#   'based',
#   'on',
#   'HTTP',
#   'request',
#   'method',
#   'HTTP',
#   'header',
#   'path',
#   'pattern',
#   'or',
#   'query',
#   'string',
#   'The',
#   'one',
#   'ALB',
#   'condition',
#   'that',
#   'would',
#   'not',
#   'work',
#   'as',
#   'expected',
#   'is',
#   'source',
#   'IP',
#   'since',
#   'Global',
#   'Accelerator',
#   'does',
#   'not',
#   'yet',
#   'preserve',
#   'the',
#   'source',
#   'IP',
#   'Are',
#   'you',
#   'able',
#   'to',
#   'describe',
#   'any',
#   'more',
#   'details',
#   'of',
#   'your',
#   'setup',
#   'to',
#   'help',
#   'us',
#   'get',
#   'to',
#   'the',
#   'bottom',
#   'of',
#   'this',
#   'When',
#   'you',
#   'say',
#   'the',
#   'path',
#   'patterns',
#   'are',
#   "n't",
#   'recognized',
#   'what',
#   'exact',
#   'behavior',
#   'do',
#   'you',
#   'see',
#   'Thanks',
#   'Harvo'],
#  ['Possible',
#   'to',
#   'access',
#   'the',
#   'domain/host',
#   'in',
#   'Lambda',
#   'Edge',
#   'origin',
#   'request',
#   'event',
#   'All',
#   'can',
#   'see',
#   'in',
#   'the',
#   'origin',
#   'request',
#   '@',
#   'event',
#   'payload',
#   'is',
#   'the',
#   'cloudfront',
#   'hostname',
#   'Is',
#   'it',
#   'possible',
#   'to',
#   'access',
#   'the',
#   'hostname',
#   'of',
#   'the',
#   'HTTP',
#   'request',
#   'that',
#   'triggered',
#   'the',
#   'event',
#   'As',
#   'in',
#   'if',
#   'somebody',
#   'typed',
#   'in',
#   'foobar.example.org',
#   'into',
#   'their',
#   'browser',
#   'bar',
#   'vs',
#   'asdfafagwgag.cloudfront.net',
#   '.',
#   'have',
#   'wildcard',
#   'Alternate',
#   'Domain',
#   'Name',
#   'CNAME',
#   ',',
#   'say',
#   '*.example.org',
#   ',',
#   'and',
#   'need',
#   'to',
#   'alter',
#   'the',
#   'response',
#   'based',
#   'upon',
#   'the',
#   'value',
#   'of',
#   'requested',
#   'hostname'],
#  ['By',
#   'default',
#   'event.Records',
#   '0',
#   '.cf.request.headers',
#   "'host",
#   ']',
#   '0',
#   '[',
#   "'value",
#   ']',
#   'contains',
#   'the',
#   '*.cloudfront.net',
#   'hostname',
#   'of',
#   'the',
#   'CloudFront',
#   'distribution',
#   'in',
#   'an',
#   'origin',
#   'request',
#   'event',
#   'If',
#   'you',
#   'need',
#   'access',
#   'the',
#   'Host',
#   'header',
#   'from',
#   'the',
#   'original',
#   'incoming',
#   'request',
#   'in',
#   'an',
#   'origin',
#   'request',
#   'trigger',
#   'you',
#   "'ll",
#   'want',
#   'to',
#   'configure',
#   'the',
#   'Cache',
#   'Behavior',
#   'to',
#   'whitelist',
#   'the',
#   'Host',
#   'header',
#   'for',
#   'forwarding',
#   'to',
#   'the',
#   'origin',
#   'server',
#   'Making',
#   'that',
#   'change',
#   'will',
#   'expose',
#   'the',
#   'original',
#   'host',
#   'header',
#   'here',
#   'instead',
#   'of',
#   'the',
#   'CloudFront-assigned',
#   'distribution',
#   'hostname'],
#  ['Would',
#   'also',
#   'really',
#   'like',
#   'this',
#   'feature',
#   'the',
#   'proposed',
#   'solution',
#   'does',
#   "n't",
#   'work',
#   'because',
#   'Host',
#   'is',
#   'not',
#   'one',
#   'of',
#   'the',
#   'headers',
#   'that',
#   'can',
#   'be',
#   'whitelisted'],
#  ['Hi',
#   'arkadiyt',
#   'It',
#   'looks',
#   'like',
#   'you',
#   'are',
#   'working',
#   'with',
#   'S3',
#   'origin',
#   'Could',
#   'you',
#   'please',
#   'share',
#   'your',
#   'use',
#   'case',
#   'that',
#   'will',
#   'be',
#   'solved',
#   'if',
#   'host',
#   'header',
#   'is',
#   'allowed',
#   'to',
#   'be',
#   'whitelisted',
#   'for',
#   'S3',
#   'origin',
#   'and',
#   'available',
#   'in',
#   'origin',
#   'request',
#   'event',
#   'Thanks',
#   'Abhishek'],
#  ['want',
#   'to',
#   'redirect',
#   'users',
#   'from',
#   'www.my-website.com',
#   'to',
#   'my-website.com',
#   '.',
#   'It',
#   "'s",
#   'possible',
#   'to',
#   'do',
#   'it',
#   'in',
#   'the',
#   'viewer',
#   'event',
#   'but',
#   "'d",
#   'prefer',
#   'the',
#   'origin',
#   'event',
#   'so',
#   'it',
#   'can',
#   'be',
#   'cached',
#   'Right',
#   'now',
#   'work',
#   'around',
#   'this',
#   'by',
#   'creating',
#   'separate',
#   'distribution',
#   'for',
#   'www.my-website.com',
#   ',',
#   'with',
#   'an',
#   'origin',
#   'request',
#   'that',
#   'always',
#   'redirects',
#   'This',
#   'seems',
#   'bit',
#   'hacky',
#   'to',
#   'me',
#   'and',
#   "'d",
#   'rather',
#   'have',
#   'single',
#   'distribution',
#   'for',
#   'both',
#   'Thanks'],
#  ['Hi',
#   'arkadiyt',
#   'Thanks',
#   'for',
#   'sharing',
#   'your',
#   'use',
#   'case',
#   'As',
#   'host',
#   'header',
#   'whitelisting',
#   'is',
#   'not',
#   'available',
#   'yet',
#   'for',
#   'S3',
#   'origin',
#   'there',
#   'are',
#   'few',
#   'workarounds',
#   'possible',
#   'which',
#   'will',
#   'let',
#   'you',
#   'keep',
#   'one',
#   'distribution',
#   'It',
#   'involves',
#   'setting',
#   'up',
#   'the',
#   'CloudFront',
#   'origin',
#   'as',
#   'custom',
#   'origin',
#   'instead',
#   'of',
#   'S3',
#   'origin',
#   'Either',
#   'of',
#   'below',
#   'two',
#   'approaches',
#   'will',
#   'work',
#   'a',
#   'Enable',
#   'S3',
#   'static',
#   'website',
#   'hosting',
#   'and',
#   'configure',
#   'an',
#   'S3',
#   'bucket',
#   'as',
#   'custom',
#   'origin',
#   'in',
#   'CloudFront',
#   'https',
#   '//docs.aws.amazon.com/AmazonS3/latest/dev/WebsiteHosting.html',
#   '.',
#   'Create',
#   'CNAME',
#   'record',
#   'that',
#   'points',
#   'to',
#   'an',
#   'S3',
#   'bucket',
#   'and',
#   'use',
#   'this',
#   'CNAME',
#   'as',
#   'custom',
#   'origin',
#   'in',
#   'CloudFront',
#   'But',
#   'this',
#   'will',
#   'not',
#   'be',
#   'an',
#   'option',
#   'if',
#   'you',
#   'are',
#   'using',
#   'an',
#   'origin',
#   'access',
#   'identity',
#   'to',
#   'restrict',
#   'access',
#   'to',
#   'your',
#   'S3',
#   'bucket',
#   'https',
#   '//docs.aws.amazon.com/AmazonCloudFront/latest/DeveloperGuide/private-content-restricting-access-to-s3.html',
#   'Thanks',
#   'Abhishek'],
#  ['The',
#   'primary',
#   'problem',
#   'here',
#   'is',
#   'that',
#   'Cloudfront',
#   'overwrites',
#   'the',
#   'host',
#   'header',
#   'in',
#   'the',
#   'request',
#   'to',
#   'the',
#   'origin',
#   'host',
#   'I',
#   'was',
#   'able',
#   'to',
#   'workaround',
#   'this',
#   'by',
#   'using',
#   'combination',
#   'of',
#   'viewer-request',
#   '@',
#   'and',
#   'origin-request',
#   '@',
#   'E.',
#   'In',
#   'the',
#   'viewer',
#   'request',
#   '@',
#   'copy',
#   'the',
#   'host',
#   'header',
#   'into',
#   'another',
#   'header',
#   'like',
#   'x-forwarded-host',
#   '//',
#   'viewer-request.js',
#   'exports.handler',
#   '(',
#   'event',
#   'context',
#   'callback',
#   '=',
#   '{',
#   'const',
#   'request',
#   'event.Records',
#   '0',
#   '.cf.request',
#   'request.headers',
#   "'",
#   'x-forwarded-host',
#   ']',
#   '[',
#   'key',
#   "'",
#   'X-Forwarded-Host',
#   ',',
#   'value',
#   'request.headers.host',
#   '0',
#   '.value',
#   ']',
#   'return',
#   'callback',
#   'null',
#   'request',
#   '}',
#   'Configure',
#   'your',
#   'cloudfront',
#   'to',
#   'whitelist',
#   'x-forwarded-host',
#   'host',
#   'header',
#   'in',
#   'the',
#   'behaviour',
#   'This',
#   'way',
#   'the',
#   'Cloudfront',
#   'also',
#   'takes',
#   'into',
#   'consideration',
#   'the',
#   'x-forwarded-host',
#   'when',
#   'caching',
#   'and',
#   'also',
#   'passes',
#   'the',
#   'header',
#   'along',
#   'to',
#   'the',
#   'origin-request',
#   'lambda',
#   '.',
#   'So',
#   'now',
#   'in',
#   'your',
#   'origin-request',
#   'lambda',
#   'you',
#   'can',
#   'access',
#   'the',
#   'x-forwarded-host',
#   'header',
#   '//',
#   'origin-request.js',
#   'exports.handler',
#   '(',
#   'event',
#   'context',
#   'callback',
#   '=',
#   '{',
#   'const',
#   'request',
#   'event.Records',
#   '0',
#   '.cf.request',
#   'const',
#   'headers',
#   'request.headers',
#   'const',
#   'requestHost',
#   'headers',
#   "'",
#   'x-forwarded-host',
#   ']',
#   '0',
#   '.value',
#   'console.log',
#   'requestHost',
#   ';',
#   'callback',
#   'null',
#   'request',
#   ';'],
#  ['Hi',
#   'HavaH',
#   'Cloudfront',
#   'overwrites',
#   'the',
#   'host',
#   'header',
#   'in',
#   'the',
#   'request',
#   'to',
#   'the',
#   'origin',
#   'domain',
#   'name',
#   'only',
#   'if',
#   'host',
#   'header',
#   'is',
#   'not',
#   'whitelisted',
#   'in',
#   'the',
#   'cache',
#   'behavior',
#   'By',
#   'whitelisting',
#   'host',
#   'header',
#   'you',
#   'can',
#   'access',
#   'unmodified',
#   'host',
#   'header',
#   'in',
#   'the',
#   'origin-request',
#   'function',
#   '-',
#   'Abhishek'],
#  ['also',
#   'need',
#   'this',
#   'My',
#   'use',
#   'case',
#   'is',
#   'that',
#   'have',
#   'single',
#   'page',
#   'react',
#   'app',
#   'in',
#   'my',
#   's3',
#   'bucket',
#   'and',
#   '10s',
#   'of',
#   'CNames',
#   'on',
#   'my',
#   'cloudfront',
#   'I',
#   'need',
#   'to',
#   'whitelist',
#   'the',
#   'Host',
#   'name',
#   'in',
#   'the',
#   'headers',
#   'to',
#   'inject',
#   'opengraph',
#   'tags',
# ...
#  ['+1',
#   'We',
#   'are',
#   'using',
#   'lambda',
#   'for',
#   'image',
#   'and',
#   'document',
#   'processing',
#   'but',
#   'we',
#   'have',
#   'stopped',
#   'developing',
#   'because',
#   'of',
#   'the',
#   '512mb',
#   'temp',
#   'storage',
#   'limit',
#   'it',
#   'is',
#   'just',
#   'way',
#   'to',
#   'low',
#   'for',
#   'processing',
#   'documents'],
#  ['+1'],
#  ['+1',
#   'Lots',
#   'of',
#   'use',
#   'cases',
#   'where',
#   'this',
#   'expands',
#   'the',
#   'capabilities',
#   'of',
#   'Lambda',
#   'but',
#   'can',
#   'understand',
#   'the',
#   'challenges',
#   'in',
#   'mounting',
#   'and',
#   'making',
#   'the',
#   'index',
#   'of',
#   'file',
#   'system',
#   'available',
#   'in',
#   'short',
#   'period',
#   'of',
#   'time',
#   'that',
#   'it',
#   'could',
#   'be',
#   'utilized',
#   'efficiently',
#   'within',
#   'the',
#   'minute',
#   'time',
#   'frame',
#   'Lambda',
#   'function',
#   'is',
#   'alloted',
#   'Granted',
#   'we',
#   'could',
#   'use',
#   'S3',
#   'in',
#   'some',
#   'cases',
#   'many',
#   'applications',
#   'want',
#   'the',
#   'file',
#   'stored',
#   'locally',
#   'before',
#   'they',
#   'make',
#   'modifications',
#   'which',
#   'means',
#   'the',
#   'source',
#   'and',
#   'destination',
#   'file',
#   'size',
#   'total',
#   'needs',
#   'to',
#   'be',
#   'less',
#   'than',
#   '512MB',
#   'which',
#   'is',
#   'half',
#   'the',
#   'problem',
#   'The',
#   'other',
#   'half',
#   'is',
#   'if',
#   'you',
#   're-use',
#   'the',
#   'same',
#   'source',
#   'file',
#   'multiple',
#   'times',
#   'one',
#   'step',
#   'would',
#   'be',
#   'removed',
#   'if',
#   'the',
#   'file',
#   'was',
#   'already',
#   'there',
#   'on',
#   'the',
#   'mounted',
#   'file',
#   'system',
#   'For',
#   'AWS',
#   'engineers',
#   'looking',
#   'into',
#   'this',
#   'I',
#   'would',
#   'suggest',
#   'thinking',
#   'about',
#   'the',
#   'problem',
#   'with',
#   'the',
#   'idea',
#   'of',
#   'specialized',
#   'version',
#   'of',
#   'EFS',
#   'specifically',
#   'for',
#   'use',
#   'only',
#   'with',
#   'Lambda',
#   'with',
#   'limited',
#   'storage',
#   'sizes',
#   'say',
#   '20GB',
#   'and/or',
#   'limits',
#   'on',
#   'the',
#   'number',
#   'of',
#   'files/descriptors',
#   'say',
#   '10,000',
#   'I',
#   'can',
#   'not',
#   'speak',
#   'for',
#   'everyone',
#   'here',
#   'but',
#   'our',
#   'need',
#   'is',
#   'primarily',
#   'to',
#   'not',
#   'have',
#   'to',
#   'duplicate',
#   'work',
#   'in',
#   'multiple',
#   'lambda',
#   'functions',
#   'persistent',
#   'files',
#   'across',
#   'all',
#   'of',
#   'the',
#   'Lambda',
#   'functions',
#   'in',
#   'an',
#   'EFS',
#   'as',
#   'well',
#   'as',
#   'provide',
#   'additional',
#   'drive',
#   'space',
#   'than',
#   'the',
#   '512MB',
#   'we',
#   "'re",
#   'allotted',
#   'today'],
#  ['have',
#   'another',
#   'use',
#   'case',
#   'I',
#   'am',
#   'rendering',
#   'animations',
#   'using',
#   'spot',
#   'instances',
#   'spun',
#   'up',
#   'by',
#   'lambda',
#   'function',
#   'Those',
#   'instances',
#   'share',
#   'an',
#   'EFS',
#   'setup',
#   'to',
#   'render',
#   'together',
#   'Right',
#   'now',
#   'I',
#   'am',
#   'uploading',
#   'zip',
#   'file',
#   'to',
#   's3',
#   'which',
#   'triggers',
#   'the',
#   'lambda',
#   'and',
#   'the',
#   'new',
#   'servers',
#   'then',
#   'pull',
#   'down',
#   'the',
#   's3',
#   'object',
#   'My',
#   'process',
#   'would',
#   'be',
#   'greatly',
#   'streamlined',
#   'if',
#   'could',
#   'drop',
#   'that',
#   'zip',
#   'directly',
#   'into',
#   'the',
#   'EFS',
#   'via',
#   'the',
#   'lambda'],
#  ['+1'],
#  ['Year',
#   'and',
#   'half',
#   'passed',
#   'and',
#   'the',
#   'engineer',
#   'log',
#   'is',
#   'freezed',
#   'as',
#   'always'],
#  ['Alias',
#   'dimension',
#   'not',
#   'available',
#   'According',
#   'to',
#   'the',
#   'documentation',
#   'here',
#   'https',
#   '//docs.aws.amazon.com/lambda/latest/dg/monitoring-functions-metrics.html',
#   'we',
#   'should',
#   'have',
#   'access',
#   'to',
#   'an',
#   'Alias',
#   'dimension',
#   'when',
#   'looking',
#   'at',
#   'lambda',
#   'metrics',
#   'in',
#   'cloudwatch',
#   'Despite',
#   'seeing',
#   'all',
#   'the',
#   'other',
#   'dimensions',
#   'from',
#   'that',
#   'doc',
#   'including',
#   'Resource',
#   'and',
#   'ExecutedVersion',
#   ',',
#   'none',
#   'of',
#   'our',
#   'functions',
#   'have',
#   'the',
#   'Alias',
#   'dimension',
#   'attached',
#   'to',
#   'them',
#   'Is',
#   'anyone',
#   'else',
#   'seeing',
#   'something',
#   'similar'],
#  ['Bump', 'This', 'is', 'in', 'us-west-2', 'for', 'the', 'record'],
#  ['bump',
#   'Is',
#   'anyone',
#   'else',
#   'experiencing',
#   'something',
#   'similar',
#   'to',
#   'this',
#   'It',
#   "'s",
#   'sort',
#   'of',
#   'an',
#   'issue',
#   'when',
#   'we',
#   'want',
#   'to',
#   'get',
#   'look',
#   'at',
#   'all',
#   'our',
#   'dev',
#   'aliases',
#   'for',
#   'example'],
#  ['Can',
#   'anyone',
#   'from',
#   'Amazon',
#   'comment',
#   'on',
#   'this',
#   'Are',
#   'the',
#   'docs',
#   'wrong',
#   'Is',
#   'there',
#   'some',
#   'special',
#   'way',
#   'to',
#   'enable',
#   'this',
#   'dimension',
#   'on',
#   'cloudwatch'],
#  ['Bump'],
#  ['To',
#   'update',
#   'this',
#   'I',
#   'contacted',
#   'AWS',
#   'support',
#   'and',
#   'apparently',
#   'the',
#   'docs',
#   'were',
#   'wrong',
#   'there',
#   'was',
#   'no',
#   'such',
#   'dimension'],
#  ['Lambda',
#   '``',
#   'Task',
#   'timed',
#   'out',
#   "''",
#   'on',
#   'first',
#   'or',
#   'invocations',
#   'then',
#   'works',
#   "'ve",
#   'got',
#   'collection',
#   'of',
#   'Lambda',
#   'functions',
#   'serving',
#   'as',
#   'simple',
#   'CRUD',
#   'REST',
#   'API',
#   'via',
#   'API',
#   'Gateway',
#   'If',
#   'leave',
#   'the',
#   'function',
#   'idle',
#   'for',
#   'awhile',
#   'or',
#   'after',
#   'deploy',
#   'the',
#   'first',
#   'few',
#   'invocations',
#   'timeout',
#   'and',
#   'just',
#   'return',
#   'an',
#   '``',
#   'Internal',
#   'Server',
#   'Error',
#   "''",
#   'It',
#   'starts',
#   'working',
#   'fine',
#   'after',
#   'or',
#   'invocations',
#   'and',
#   'then',
#   'no',
#   'troubles',
#   'after',
#   'that',
#   'until',
#   'it',
#   'goes',
#   'idle',
#   'again',
#   'The',
#   'logs',
#   'say',
#   '``',
#   '2019-03-25T14:38:56.148Z',
#   '3ccc877d-ced0-4ad9-81cc-ccf4e0cea87c',
#   'Task',
#   'timed',
#   'out',
#   'after',
#   '5.01',
#   'seconds',
#   "''",
#   'Here',
#   "'s",
#   'one',
#   'of',
#   'my',
#   'lambdas',
#   'that',
#   "'s",
#   'exhibiting',
#   'the',
#   'behavior',
#   'getAccounts',
#   'async',
#   'event',
#   'context',
#   'callback',
#   '=',
#   '{',
#   'context.callbackWaitsForEmptyEventLoop',
#   'false',
#   'const',
#   'connection',
#   'mysql.createConnection',
#   'dbConfig',
#   'try',
#   'const',
#   'results',
#   'await',
#   'executeQuery',
#   'connection',
#   "'select",
#   'from',
#   'accounts',
#   ',',
#   ']',
#   'context.succeed',
#   '{',
#   'statusCode',
#   '200',
#   'headers',
#   'responseHeaders',
#   'body',
#   'JSON.stringify',
#   'results',
#   '}',
#   '}',
#   'catch',
#   'err',
#   '{',
#   'console.log',
#   "'There",
#   'was',
#   'an',
#   'error',
#   "'",
#   'err',
#   'context.fail',
#   '{',
#   'statusCode',
#   '400',
#   'headers',
#   'responseHeaders',
#   'body',
#   'JSON.stringify',
#   'err.errorMessage',
#   '}',
#   '}',
#   'finally',
#   'connection.destroy',
#   ')',
#   '}',
#   'function',
#   'executeQuery',
#   'conn',
#   'query',
#   'args',
#   '{',
#   'return',
#   'new',
#   'Promise',
#   '(',
#   'resolve',
#   'reject',
#   '=',
#   '{',
#   'conn.connect',
#   'connError',
#   '>',
#   'if',
#   'connError',
#   '{',
#   'console.log',
#   "'Connection",
#   'error',
#   "'",
#   'JSON.stringify',
#   'connError',
#   ')',
#   'reject',
#   'connError',
#   '}',
#   'else',
#   'conn.query',
#   'query',
#   'args',
#   '(',
#   'err',
#   'results',
#   '=',
#   '{',
#   'if',
#   'err',
#   '{',
#   'console.log',
#   "'Query",
#   'error',
#   "'",
#   'JSON.stringify',
#   'err',
#   ')',
#   'reject',
#   'err',
#   '}',
#   'else',
#   'resolve',
#   'results',
#   '}',
#   ')',
#   '}',
#   '}',
#   'Edited',
#   'by',
#   'stackwalker',
#   'on',
#   '25',
#   '2019',
#   '8:08',
#   'AM',
#   'Edited',
#   'by',
#   'stackwalker',
#   'on',
#   '25',
#   '2019',
#   '8:10',
#   'AM'],
#  ['Lambda',
#   'using',
#   'extra',
#   'libaries',
#   'Hello',
#   'I',
#   'am',
#   'trying',
#   'to',
#   'use',
#   'an',
#   'extra',
#   'libary',
#   'zbar',
#   'in',
#   'lambda',
#   'but',
#   'im',
#   'not',
#   'sure',
#   'how',
#   'would',
#   'go',
#   'about',
#   'packing',
#   'this',
#   'up',
#   'normally',
#   'would',
#   'just',
#   'install',
#   'it',
#   'with',
#   'yum',
#   'install',
#   'zbar',
#   'i',
#   'know',
#   'can',
#   'do',
#   'binaries',
#   'but',
#   'dont',
#   'see',
#   'how',
#   'to',
#   'get',
#   'repo',
#   'package',
#   'Thanks'],
#  ['Hello',
#   'Here',
#   'are',
#   'guidelines',
#   'for',
#   'building',
#   'packages',
#   'for',
#   'dependencies',
#   'You',
#   'likely',
#   'need',
#   'the',
#   'one',
#   'for',
#   'Python',
#   'http',
#   '//docs.aws.amazon.com/lambda/latest/dg/deployment-package-v2.html',
#   'this',
#   'helps',
#   'Thanks',
#   'Vishal'],
#  ['Hi',
#   'have',
#   'been',
#   'trying',
#   'hard',
#   'to',
#   'get',
#   'zbar',
#   'working',
#   'in',
#   'my',
#   'lambda',
#   'function',
#   'This',
#   'is',
#   'the',
#   'error',
#   'am',
#   'getting',
#   'when',
#   'trying',
#   'to',
#   'access',
#   'the',
#   'libzbar',
#   'libray',
#   'Unable',
#   'to',
#   'import',
#   'module',
#   "'lambda_function",
#   ':',
#   'libzbar.so.0',
#   'can',
#   'not',
#   'openshared',
#   'object',
#   'file',
#   'No',
#   'such',
#   'file',
#   'or',
#   'directory',
#   'I',
#   'got',
#   'libzbar.so.0',
#   'from',
#   'lambda',
#   'docker',
#   'image',
#   'and',
#   'placed',
#   'it',
#   'in',
#   'bin',
#   'directory',
#   'that',
#   'will',
#   'be',
#   'included',
#   'in',
#   'my',
#   'zip',
#   'package',
#   'and',
#   'then',
#   'in',
#   'my',
#   'code',
#   'added',
#   'these',
#   'two',
#   'lines',
#   'to',
#   'let',
#   'the',
#   'lambda',
#   'know',
#   'about',
#   'where',
#   'to',
#   'look',
#   'for',
#   'the',
#   'file',
#   'os.environ',
#   'os.environ',
#   "'",
#   "'",
#   'os.environ',
#   "'/bin",
#   'os.environ',
#   'os.environ',
#   "'/bin",
#   'But',
#   'it',
#   'is',
#   'still',
#   'not',
#   'working',
#   'Can',
#   'anyone',
#   'help'],
#  ['Did',
#   'you',
#   'ever',
#   'figure',
#   'this',
#   'out',
#   'I',
#   'am',
#   'also',
#   'interested'],
#  ['Possible',
#   'to',
#   'add',
#   'Lambda',
#   '``',
#   'shut',
#   'down',
#   "''",
#   'callback',
#   'Hello',
#   'all',
#   'I',
#   'got',
#   'reply',
#   'from',
#   'AWSSupport',
#   'on',
#   'Twitter',
#   'saying',
#   'can',
#   'always',
#   'post',
#   'feedback',
#   'here',
#   'I',
#   "'m",
#   'new',
#   'here',
#   'so',
#   'bear',
#   'with',
#   'me',
#   'if',
#   'this',
#   'was',
#   'already',
#   'asked',
#   'I',
#   'can',
#   'imagine',
#   'the',
#   'feature',
#   "'m",
#   'about',
#   'to',
#   'describe',
#   'is',
#   'not',
#   'that',
#   'easy',
#   'to',
#   'implement',
#   'and',
#   'believe',
#   'that',
#   'there',
#   'might',
#   'be',
#   'good',
#   'reason',
#   'why',
#   'this',
#   'was',
#   "n't",
#   'implemented',
#   'yet',
#   'But',
#   'still',
#   'it',
#   'does',
#   "n't",
#   'hurt',
#   'to',
#   'ask',
#   'Would',
#   'it',
#   'be',
#   'possible',
#   'to',
#   'optionally',
#   'call',
#   'the',
#   'function',
#   'one',
#   'last',
#   'time',
#   'once',
#   'the',
#   'instance',
#   'is',
#   'about',
#   'to',
#   'be',
#   'shut',
#   'down',
#   'This',
#   'would',
#   'eg',
#   'enable',
#   'us',
#   'to',
#   'resolve',
#   'the',
#   'already',
#   'known',
#   'issue',
#   'with',
#   'DB',
#   'connection',
#   'management',
#   'I',
#   "'m",
#   'talking',
#   'about',
#   'the',
#   'case',
#   'in',
#   'which',
#   'you',
#   'establish',
#   'DB',
#   'connection',
#   'eg',
#   'to',
#   'the',
#   'DocumentDB',
#   ',',
#   'and',
#   'it',
#   'remains',
#   'open',
#   'even',
#   'though',
#   'the',
#   'Lambda',
#   'instance',
#   'was',
#   'shut',
#   'down',
#   'With',
#   'this',
#   'new',
#   '``',
#   'callback',
#   "''",
#   'implemented',
#   'it',
#   'would',
#   'be',
#   'possible',
#   'to',
#   'close',
#   'the',
#   'active',
#   'connection',
#   'thus',
#   'removing',
#   'the',
#   'possibility',
#   'to',
#   'max',
#   'out',
#   'on',
#   'the',
#   'number',
#   'of',
#   'connections',
#   'towards',
#   'the',
#   'DB',
#   'It',
#   'does',
#   "n't",
#   'have',
#   'to',
#   'be',
#   'separate',
#   'callback',
#   'a',
#   'simple',
#   'param',
#   'in',
#   'the',
#   'context',
#   'argument',
#   'of',
#   'the',
#   'function',
#   'would',
#   'also',
#   'suffice',
#   'believe',
#   'I',
#   "'m",
#   'aware',
#   'of',
#   'few',
#   'alternative',
#   'approaches',
#   'like',
#   'eg',
#   'setting',
#   'up',
#   'single',
#   'EC2',
#   'instance',
#   'single',
#   'point',
#   'of',
#   'failure',
#   'to',
#   'manage',
#   'all',
#   'connections',
#   'but',
#   'that',
#   'seems',
#   'to',
#   'be',
#   'bit',
#   'unnecessary',
#   'or',
#   'would',
#   'say',
#   '``',
#   'serverful',
#   "''",
#   'Happy',
#   'to',
#   'hear',
#   'what',
#   'others',
#   'think',
#   'about',
#   'this',
#   'feature',
#   'and',
#   'also',
#   'about',
#   'this',
#   'specific',
#   'situation',
#   'Correct',
#   'me',
#   'if',
#   "'m",
#   'wrong',
#   'about',
#   'anything',
#   'always',
#   'glad',
#   'to',
#   'learn',
#   'something',
#   'new',
#   'Thanks'],
#  ['Authorizer',
#   'function',
#   'not',
#   'logging',
#   'to',
#   'CloudWatch',
#   'Greetings',
#   'Full',
#   'Disclosure',
#   'I',
#   'am',
#   'still',
#   'very',
#   'new',
#   'to',
#   'AWS',
#   'For',
#   'my',
#   'first',
#   'AWS',
#   'project',
#   'I',
#   'am',
#   'creating',
#   'websocket',
#   'connection',
#   'between',
#   'my',
#   'website',
#   'and',
#   'my',
#   'DynamoDB',
#   'table',
#   'Inasmuch',
#   'I',
#   'have',
#   'created',
#   'the',
#   'tables',
#   'a',
#   'Websocket',
#   'API',
#   'and',
#   'the',
#   'supporting',
#   'Lambda',
#   'functions',
#   'Everything',
#   'is',
#   'working',
#   'great',
#   'I',
#   'then',
#   'added',
#   'JS',
#   'Lamba',
#   'Authorizer',
#   'function',
#   'Node',
#   '8.10',
#   ',',
#   'and',
#   'something',
#   'peculiar',
#   'is',
#   'occurring',
#   'Within',
#   'the',
#   'function',
#   'I',
#   'am',
#   'using',
#   'simple',
#   'console.log',
#   'statements',
#   'to',
#   'help',
#   'me',
#   'debug',
#   'an',
#   'Unauthorized',
#   'condition',
#   'When',
#   'Test',
#   'the',
#   'function',
#   'the',
#   'logs',
#   'appear',
#   'in',
#   'CloudWatch',
#   'However',
#   'when',
#   'attempt',
#   'to',
#   'make',
#   'connection',
#   'from',
#   'my',
#   'website',
#   'no',
#   'logs',
#   'appear',
#   'in',
#   'CloudWatch',
#   'All',
#   'my',
#   'other',
#   'Lambda',
#   'functions',
#   '$',
#   'connect',
#   '$',
#   'disconnect',
#   'and',
#   'the',
#   'routing',
#   'functions',
#   'all',
#   'work',
#   'normally',
#   'and',
#   'output',
#   'their',
#   'console.log',
#   'text',
#   'to',
#   'CloudWatch',
#   'Only',
#   'the',
#   'Authorizer',
#   'function',
#   'fails',
#   'to',
#   'send',
#   'logs',
#   'and',
#   'yet',
#   'when',
#   'click',
#   'on',
#   'the',
#   '``',
#   'Test',
#   "''",
#   'button',
#   'the',
#   'logs',
#   'are',
#   'sent',
#   'I',
#   'was',
#   'thinking',
#   'that',
#   'there',
#   'might',
#   'be',
#   'some',
#   'log',
#   'settings',
#   'on',
#   'the',
#   'function',
#   'itself',
#   'but',
#   "'m",
#   'not',
#   'able',
#   'to',
#   'locate',
#   'anything',
#   'other',
#   'than',
#   'this',
#   'entry',
#   'in',
#   'the',
#   'Developer',
#   'Allow',
#   'logs',
#   'CreateLogGroup',
#   'Allow',
#   'logs',
#   'CreateLogStream',
#   'Allow',
#   'logs',
#   'DescribeLogGroups',
#   'Allow',
#   'logs',
#   'DescribeLogStreams',
#   'Allow',
#   'logs',
#   'PutLogEvents',
#   'Allow',
#   'logs',
#   'GetLogEvents',
#   'Allow',
#   'logs',
#   'FilterLogEvents',
#   'Other',
#   'than',
#   'the',
#   'global',
#   'log',
#   'setting',
#   'in',
#   'the',
#   'Websocket',
#   'API',
#   'I',
#   'ca',
#   "n't",
#   'figure',
#   'out',
#   'why',
#   'all',
#   'my',
#   'APIs',
#   'except',
#   'the',
#   'Authorizer',
#   'will',
#   'log',
#   'to',
#   'CloudWatch',
#   'Has',
#   'anyone',
#   'run',
#   'into',
#   'something',
#   'like',
#   'this',
#   'before',
#   'and',
#   'if',
#   'so',
#   'what',
#   'did',
#   'you',
#   'do',
#   'to',
#   'fix',
#   'it',
#   'If',
#   'not',
#   'can',
#   'anyone',
#   'give',
#   'me',
#   'hint',
#   'as',
#   'to',
#   'where',
#   'can',
#   'look',
#   'to',
#   'debug',
#   'this',
#   'issue',
#   'Thank',
#   'you'],
#  ['To',
#   'answer',
#   'my',
#   'own',
#   'question',
#   'the',
#   'problem',
#   'was',
#   'indeed',
#   'due',
#   'to',
#   'the',
#   '``',
#   'Unauthorized',
#   "''",
#   'problem',
#   'that',
#   'mentioned',
#   'but',
#   'thought',
#   'it',
#   'has',
#   'nothing',
#   'to',
#   'do',
#   'with',
#   'it',
#   'When',
#   'setup',
#   'my',
#   'authorizer',
#   'I',
#   'set',
#   'Lambda',
#   'Event',
#   'payload',
#   'for',
#   'custom',
#   'header',
#   'and',
#   'had',
#   'neglected',
#   'to',
#   'set',
#   'that',
#   'header',
#   'in',
#   'my',
#   'browser',
#   'session',
#   'According',
#   'to',
#   'the',
#   'documentation',
#   'at',
#   'https',
#   '//docs.aws.amazon.com/apigateway/latest/developerguide/configure-api-gateway-lambda-authorization-with-console.html',
#   'section',
#   '9b',
#   'the',
#   'API',
#   'Gateway',
#   'will',
#   'throw',
#   '401',
#   'Unauthorized',
#   'error',
#   'without',
#   'even',
#   'executing',
#   'the',
#   'Lambda',
#   'function',
#   'So',
#   'that',
#   'was',
#   'the',
#   'source',
#   'of',
#   'the',
#   'problem']]

# %%
text['description'] = cleantext

# %% [markdown]
# #### Step 4) Remove stop words

# %%
stop_words = corpus.stopwords.words('english')

new_stop_words = ['something', "'m", 'please', 'thank', 'thanks', 'hello', 'hi', 'hey', "'ve", 'regards', "ca", 'I', "'d",
                  "n\'t", "s3", "aws", "ec2", "regards", "'s", "help", "Edited", "sns", "cloudfront", "vpc", "rds", 
                  "beanstalk", "lambda", "Amazon", 'wo', "Elastic"]
stop_words.extend(new_stop_words)

cleantext = []


for i in range(0, len(stop_words)):
    stop_words[i] = stop_words[i].upper()

# print(stop_words)

m = len(text['description'])

for i in range(0, m):
    n = len(text['description'][i])
    
    sentence = []
    
    for j in range(0, n):
        if text['description'][i][j].upper() not in stop_words:
            sentence.append(text['description'][i][j])
    
    cleantext.append(sentence)

# %%
text['description'] = cleantext

text['description']
# Out:
# 0     [Deploy, multiple, end, point, Springboot, wan...
# 1     [trigger, second, function, response, external...
# 2     [Sounds, like, might, want, provide, external,...
# 3     [Exception, thrown, invoking, local, developin...
# 4     [Option, set, minimum, number, 'warm, function...
# 5     [feedback, forward, feature, request, internal...
# 6     [Microsoft, feature, really, like, support, we...
# 7     [One, keep, lamdbas, warm, plugin, https, //gi...
# 8     [check, many, concurrent, currently, run, Some...
# 9     [currently, API, tell, real, time, concrete, n...
# 10                         [cecilia, service, API, yet]
# 11    [possible, change, timeout, container, trying,...
# 12    [Unfortunately, possible, control, container, ...
# 13    [permission, DetachNetworkInterfaces, reasonab...
# 14    [managed, service, operations, attaching/detac...
# 15                                                   []
# 16    [Pass, Cognito, credentials/identity, API, Gat...
# 17    [Cognito, user, pool, returns, different, prop...
# 18    [Layers, supported, SAM/CloudFormation, eu-nor...
# 19    [noticed, problem, eu-north-1, able, find, doc...
# 20    [got, message, someone, saying, support, Layer...
# 21    [CodeBuild, Error, UNAUTHORIZED_OPERATION_CREA...
# 22    [hit, problem, luck, sorting, UPDATE, using, c...
# 23    [grant, different, permissions, work, {, ``, E...
# 24    [Sending, Webpush, notification, developing, p...
# 25    [Code, Storage, reuse, deployment, package, se...
# 26    [javascript, API, missing, functions, trying, ...
# 27    [Expired, Token, Occasionally, calls, get, err...
# 28    [reporting, issue, Jeremymcjunkin, working, fi...
# 29    [Agreed, --, update, side, 're, also, seeing, ...
#                             ...
# 61                [+1, Read, efs, would, enough, needs]
# 62    [feature, request, already, logged, appropriat...
# 63     [+1, EFS, together, powerful, ML, web, services]
# 64    [+1, Essential, access, data, EFS, important, ...
# 65    [+1, updates, request, need, support, persiste...
# 66    [+1, great, Lambdas, working, thousands, small...
# 67    [+1, !, Would, really, love, migrate, existing...
# 68    [Umair, update, ETA, well, year, long, keep, e...
# 69    [+1, would, helpful, us, since, sometimes, pro...
# 70                                      [+1, great, ML]
# 71    [+1, using, image, document, processing, stopp...
# 72                                                 [+1]
# 73    [+1, Lots, use, cases, expands, capabilities, ...
# 74    [another, use, case, rendering, animations, us...
# 75                                                 [+1]
# 76    [Year, half, passed, engineer, log, freezed, a...
# 77    [Alias, dimension, available, According, docum...
# 78                            [Bump, us-west-2, record]
# 79    [bump, anyone, else, experiencing, similar, so...
# 80    [anyone, comment, docs, wrong, special, way, e...
# 81                                               [Bump]
# 82    [update, contacted, support, apparently, docs,...
# 83    [``, Task, timed, '', first, invocations, work...
# 84    [using, extra, libaries, trying, use, extra, l...
# 85    [guidelines, building, packages, dependencies,...
# 86    [trying, hard, get, zbar, working, function, e...
# 87                     [ever, figure, also, interested]
# 88    [Possible, add, ``, shut, '', callback, got, r...
# 89    [Authorizer, function, logging, CloudWatch, Gr...
# 90    [answer, question, problem, indeed, due, ``, U...
# Name: description, Length: 91, dtype: object

# %% [markdown]
# #### Step 5) Remove all the 'words' that are only symbols and convert all words to lowercase

# %%
cleantext = []

for msg in text['description']:
    sent = []
    for word in msg:
        if word.isalnum() == True:
            sent.append(word.lower())
    cleantext.append(sent)

cleantext
# Out:
# [['deploy',
#   'multiple',
#   'end',
#   'point',
#   'springboot',
#   'want',
#   'clarify',
#   'comes',
#   'deploying',
#   'multiple',
#   'rest',
#   'endpoints',
#   'implemented',
#   'single',
#   'springboot',
#   'application',
#   'expose',
#   'end',
#   'points',
#   'original',
#   'spring',
#   'boot',
#   'writing',
#   'single',
#   'function',
#   'update',
#   'paths',
#   'add',
#   'multiple',
#   'paths',
#   'snippet',
#   'single',
#   'function',
#   'spring',
#   'boot',
#   'expose',
#   'end',
#   'point',
#   'resources',
#   'petstorefunction',
#   'type',
#   'properties',
#   'handler',
#   'runtime',
#   'java8',
#   'codeuri',
#   'memorysize',
#   '1512',
#   'policies',
#   'awslambdabasicexecutionrole',
#   'timeout',
#   '60',
#   'events',
#   'getresource',
#   'type',
#   'api',
#   'properties',
#   'path',
#   'method',
#   'need',
#   'write',
#   'function',
#   'per',
#   'end',
#   'point',
#   'spin',
#   'multiple',
#   'springboot',
#   'containers',
#   'way',
#   'share',
#   'single',
#   'spring',
#   'boot',
#   'container',
#   'across',
#   'multiple',
#   'end',
#   'points',
#   'clarify',
#   'isuru'],
#  ['trigger',
#   'second',
#   'function',
#   'response',
#   'external',
#   'http',
#   'service',
#   'process',
#   'uses',
#   'system',
#   'slow',
#   'http',
#   'requests',
#   'could',
#   'make',
#   'function',
#   'generates',
#   'request',
#   'sends',
#   'server',
#   'idling',
#   'task',
#   'waiting',
#   'response',
#   'would',
#   'great',
#   'waste',
#   'time',
#   'resources',
#   'instead',
#   'seems',
#   'would',
#   'better',
#   'trigger',
#   'second',
#   'function',
#   'processes',
#   'result',
#   'http',
#   'response',
#   'call',
#   'function',
#   'would',
#   'alive',
#   'time',
#   'request',
#   'seconds',
#   'times',
#   'many',
#   'requests',
#   'thing',
#   'possible',
#   'would',
#   'suggest',
#   'setting',
#   'jeroenv',
#   '10',
#   '2019'],
#  ['sounds',
#   'like',
#   'might',
#   'want',
#   'provide',
#   'external',
#   'service',
#   'callback',
#   'url',
#   'way',
#   'done',
#   'whatever',
#   'slow',
#   'processing',
#   'send',
#   'results',
#   'url',
#   'invoke',
#   'function',
#   'course',
#   'assuming',
#   'external',
#   'service',
#   'capability',
#   'alter',
#   'capability',
#   'really',
#   'anything',
#   'available',
#   'http',
#   'call',
#   'invoke',
#   'results'],
#  ['exception',
#   'thrown',
#   'invoking',
#   'local',
#   'developing',
#   'nodejs',
#   'function',
#   'vs',
#   'code',
#   'using',
#   'serverless',
#   'framework',
#   'able',
#   'debug',
#   'locally',
#   'vs',
#   'code',
#   'encountered',
#   'issue',
#   'try',
#   'invoke',
#   'another',
#   'deployed',
#   'within',
#   'local',
#   'using',
#   'shown',
#   'following',
#   'code',
#   'snippet',
#   'var',
#   'require',
#   'var',
#   'new',
#   'return',
#   'params',
#   'however',
#   'throws',
#   'incompletesignatureexception',
#   'along',
#   'following',
#   'message',
#   'valid',
#   'pair',
#   'missing',
#   'authorization',
#   'header',
#   'deploy',
#   'calling',
#   'invocation',
#   'second',
#   'works',
#   'fine',
#   'must',
#   'additional',
#   'need',
#   'invoking',
#   'locally',
#   'trouble',
#   'know',
#   'note',
#   'nowhere',
#   'code',
#   'explicitly',
#   'setting',
#   'signature',
#   'header',
#   'values',
#   'search',
#   'solution',
#   'returned',
#   'suggestions',
#   'related',
#   'api',
#   'gateway',
#   'custom',
#   'authorizers',
#   'api',
#   'gateway',
#   'trying',
#   'invoke',
#   'alanwarren395',
#   '11',
#   '2019',
#   'alanwarren395',
#   '11',
#   '2019'],
#  ['option',
#   'set',
#   'minimum',
#   'number',
#   'functions',
#   'nice',
#   'heave',
#   'feature',
#   'would',
#   'option',
#   'set',
#   'option',
#   'ability',
#   'set',
#   'minimum',
#   'number',
#   'warmed',
#   'instances',
#   'well',
#   'able',
#   'set',
#   'specific',
#   'schedule',
#   'similar',
#   'cron',
#   'job',
#   'schedule',
#   'exchange',
#   'fee',
#   'would',
#   'developers',
#   'write',
#   'workarounds',
#   'services',
#   'need',
#   'certain',
#   'level',
#   'responsiveness',
#   'cold',
#   'periods',
#   'think',
#   'people',
#   'uncommon',
#   'things',
#   'late',
#   'night'],
#  ['feedback',
#   'forward',
#   'feature',
#   'request',
#   'internal',
#   'team',
#   'however',
#   'able',
#   'provide',
#   'eta',
#   'feature',
#   'released',
#   'kindly',
#   'check',
#   'products',
#   'announcement',
#   'page',
#   '1',
#   'blog',
#   '2',
#   'periodically',
#   'updates',
#   'https',
#   '2',
#   'https'],
#  ['microsoft',
#   'feature',
#   'really',
#   'like',
#   'support',
#   'well',
#   'basically',
#   'cold',
#   'starts',
#   'longer',
#   'concern',
#   'use',
#   'azure',
#   'anyone',
#   'curious',
#   'announcement',
#   'https',
#   'log',
#   'vote',
#   'well',
#   'would',
#   'make',
#   'life',
#   'much',
#   'easier',
#   'focus',
#   'every',
#   'decision',
#   'around',
#   'reduce',
#   'cold',
#   'starts',
#   'manually',
#   'warm',
#   'lambdas',
#   'need',
#   'go',
#   'api',
#   'gateway',
#   'using',
#   'xray'],
#  ['one', 'keep', 'lamdbas', 'warm', 'plugin', 'https', 'use', 'works'],
#  ['check',
#   'many',
#   'concurrent',
#   'currently',
#   'run',
#   'sometimes',
#   'want',
#   'know',
#   'many',
#   'still',
#   'running',
#   'limit',
#   'concurrent',
#   'spawn',
#   'new',
#   'one',
#   'keep',
#   'amount',
#   'parallel',
#   'api',
#   'let',
#   'know',
#   'information'],
#  ['currently',
#   'api',
#   'tell',
#   'real',
#   'time',
#   'concrete',
#   'number',
#   'concurrent',
#   'executions',
#   'make',
#   'fair',
#   'estimate',
#   'using',
#   'provided',
#   'cloudwatch',
#   'metrics',
#   'multiplying',
#   'number',
#   'invocations',
#   'supplied',
#   'minute',
#   'average',
#   'duration',
#   'executions',
#   'supplied',
#   'ms',
#   'given',
#   'point',
#   'time',
#   'looking',
#   'features',
#   'concurrent',
#   'throttling',
#   'area'],
#  ['cecilia', 'service', 'api', 'yet'],
#  ['possible',
#   'change',
#   'timeout',
#   'container',
#   'trying',
#   'avoid',
#   'cold',
#   'start',
#   'functions',
#   'way',
#   'control',
#   'container',
#   'timeout',
#   'reserve',
#   '10',
#   'containers',
#   'longer',
#   'period',
#   'time',
#   'even',
#   'extra',
#   'charge',
#   'want',
#   'know',
#   'anything',
#   'control',
#   'container',
#   'timeout',
#   'besides',
#   'keeping',
#   'warm',
#   'schedule',
#   'requests',
#   'jnabais',
#   '20',
#   '2019'],
#  ['unfortunately',
#   'possible',
#   'control',
#   'container',
#   'timeout',
#   'reserve',
#   'longer',
#   'time',
#   'see',
#   'already',
#   'following',
#   'best',
#   'practices',
#   'keeping',
#   'functions',
#   'warm',
#   'using',
#   'scheduled',
#   'requests',
#   'feedback',
#   'forward',
#   'feature',
#   'request',
#   'internal',
#   'team',
#   'however',
#   'able',
#   'provide',
#   'eta',
#   'feature',
#   'released',
#   'kindly',
#   'check',
#   'products',
#   'announcement',
#   'page',
#   '1',
#   'blog',
#   '2',
#   'periodically',
#   'updates',
#   'https',
#   '2',
#   'https'],
#  ['permission',
#   'detachnetworkinterfaces',
#   'reasonable',
#   'run',
#   'function',
#   'make',
#   'sense',
#   'add',
#   'action',
#   'detachnetworkinferace',
#   'iam',
#   'role',
#   'run',
#   'function',
#   'within',
#   'understanding',
#   'case',
#   'function',
#   'needs',
#   'eni',
#   'access',
#   'resources',
#   'enable',
#   'attach',
#   'managed',
#   'policy',
#   'awslambdavpcaccessexecutionrole',
#   'functions',
#   'browsing',
#   'permission',
#   'noticed',
#   'action',
#   'detachnetworkinterface',
#   'missing',
#   'version',
#   'statement',
#   'effect',
#   'allow',
#   'action',
#   'logs',
#   'createloggroup',
#   'logs',
#   'createlogstream',
#   'logs',
#   'putlogevents',
#   'createnetworkinterface',
#   'describenetworkinterfaces',
#   'deletenetworkinterface',
#   'resource',
#   'container',
#   'runs',
#   'function',
#   'delete',
#   'eni',
#   'detach',
#   'eni',
#   'bit',
#   'deep',
#   'dive',
#   'question',
#   'curious',
#   'internals'],
#  ['managed',
#   'service',
#   'operations',
#   'network',
#   'interfaces',
#   'taken',
#   'care',
#   'internally',
#   'internal',
#   'information',
#   'provide',
#   'much',
#   'details',
#   'related',
#   'however',
#   'need',
#   'create',
#   'delete',
#   'permissions',
#   'enis',
#   'created',
#   'account',
#   'would',
#   'require',
#   'permissions',
#   'hope',
#   'answers',
#   'query',
#   'let',
#   'us',
#   'know',
#   'queries'],
#  [],
#  ['pass',
#   'cognito',
#   'api',
#   'gateway',
#   'python',
#   'couple',
#   'endpoints',
#   'api',
#   'gateway',
#   'configured',
#   'cognito',
#   'authorizer',
#   'client',
#   'app',
#   'cognito',
#   'user',
#   'pool',
#   'configured',
#   'client',
#   'credentials',
#   'flow',
#   'endpoints',
#   'integrated',
#   'function',
#   'python',
#   'need',
#   'know',
#   'function',
#   'client',
#   'app',
#   'used',
#   'perform',
#   'api',
#   'access',
#   'see',
#   'anything',
#   'context',
#   'object',
#   'event',
#   'variable',
#   'cognito',
#   'identity',
#   'idea',
#   'much'],
#  ['cognito',
#   'user',
#   'pool',
#   'returns',
#   'different',
#   'properties',
#   'json',
#   'claims',
#   'response',
#   'method',
#   'caller',
#   'successfully',
#   'authenticated',
#   'json',
#   'claims',
#   'response',
#   'looks',
#   'like',
#   'sub',
#   'aud',
#   'xyz',
#   'true',
#   'id',
#   '1499671038',
#   'iss',
#   'https',
#   'cognito',
#   'username',
#   'user2',
#   'exp',
#   '10',
#   'utc',
#   '2017',
#   'iat',
#   '10',
#   'utc',
#   '2017',
#   'email',
#   'abc',
#   'context',
#   'variable',
#   'holds',
#   'contextual',
#   'information',
#   'api',
#   'call',
#   'used',
#   'get',
#   'properties',
#   'claims',
#   'response',
#   '1',
#   'aud',
#   'claim',
#   'hold',
#   'app',
#   'client',
#   'id',
#   'add',
#   'mapping',
#   'template',
#   'integration',
#   'request',
#   'context',
#   'appclient',
#   'hope',
#   'helps',
#   'let',
#   'us',
#   'know',
#   'queries',
#   'https'],
#  ['layers',
#   'supported',
#   'trying',
#   'deploy',
#   'get',
#   'failed',
#   'reason',
#   'template',
#   'format',
#   'error',
#   'unrecognized',
#   'resource',
#   'types',
#   'https',
#   'trying',
#   'deploys',
#   'bug',
#   'supported',
#   'stockholm'],
#  ['noticed',
#   'problem',
#   'able',
#   'find',
#   'documentation',
#   'regarding',
#   'forum',
#   'post',
#   'relevant',
#   'search',
#   'result',
#   'google'],
#  ['got',
#   'message',
#   'someone',
#   'saying',
#   'support',
#   'cf',
#   'deployed',
#   'latest',
#   'version',
#   'hopefully',
#   'would',
#   'come',
#   'soon',
#   'tested',
#   'rcently'],
#  ['codebuild',
#   'error',
#   'error',
#   'codebuild',
#   'service',
#   'role',
#   'authorized',
#   'perform',
#   'createnetworkinterface',
#   'trying',
#   'allow',
#   'codebuild',
#   'config',
#   'connect',
#   'allow',
#   'connection',
#   'getting',
#   'following',
#   'error',
#   'upon',
#   'build',
#   'service',
#   'role',
#   'authorized',
#   'perform',
#   'createnetworkinterface',
#   'already',
#   'attempted',
#   'add',
#   'createnetworkinterface',
#   'used',
#   'roles',
#   'still',
#   'luck'],
#  ['hit',
#   'problem',
#   'luck',
#   'sorting',
#   'update',
#   'using',
#   'codestar',
#   'generated',
#   'permission',
#   'boundary',
#   'pipeline',
#   'role',
#   'seems',
#   'issue',
#   'temporarily',
#   'removing',
#   'adding',
#   'permissions',
#   'seems',
#   'fixed',
#   'need',
#   'narrow',
#   'need',
#   'add',
#   'boundary',
#   'work',
#   'part',
#   'probably',
#   'specific',
#   'account',
#   'good',
#   'luck',
#   'buzzologist',
#   '20',
#   '2019',
#   'pm'],
#  ['grant',
#   'different',
#   'permissions',
#   'work',
#   'effect',
#   'allow',
#   'action',
#   'createnetworkinterface',
#   'describedhcpoptions',
#   'describenetworkinterfaces',
#   'deletenetworkinterface',
#   'describesubnets',
#   'describesecuritygroups',
#   'describevpcs',
#   'resource',
#   'effect',
#   'allow',
#   'action',
#   'createnetworkinterfacepermission',
#   'resource',
#   'arn',
#   'region',
#   'accountnumber',
#   'condition',
#   'stringequals',
#   'subnet',
#   'arn',
#   'region',
#   'accountnumber',
#   'id',
#   'authorizedservice',
#   'permission',
#   'section',
#   'need',
#   'want',
#   'restrict',
#   'code',
#   'build',
#   'using',
#   'specific',
#   'subnet',
#   'removed',
#   'want',
#   'restriction'],
#  ['sending',
#   'webpush',
#   'notification',
#   'developing',
#   'progressive',
#   'web',
#   'app',
#   'pwa',
#   'part',
#   'trying',
#   'send',
#   'web',
#   'push',
#   'notification',
#   'clients',
#   'setup',
#   'upon',
#   'certain',
#   'actions',
#   'client',
#   'message',
#   'containing',
#   'subscription',
#   'payload',
#   'information',
#   'stored',
#   'sqs',
#   'whenever',
#   'message',
#   'pushed',
#   'sqs',
#   'triggered',
#   'used',
#   'send',
#   'push',
#   'notification',
#   'clients',
#   'using',
#   'nodejs',
#   'library',
#   'however',
#   'see',
#   'successfully',
#   'invoked',
#   'able',
#   'read',
#   'message',
#   'sqs',
#   'deliver',
#   'web',
#   'push',
#   'notification',
#   'code',
#   'log',
#   'succeeded',
#   'error',
#   'details',
#   'directly',
#   'logs',
#   'everything',
#   'done',
#   'let',
#   'know',
#   'wrong',
#   'code',
#   'const',
#   'webpush',
#   'require',
#   'async',
#   'function',
#   'event',
#   'context',
#   'var',
#   'var',
#   'var',
#   'replace',
#   'email',
#   'mailto',
#   'supportemail',
#   'publicvapidkey',
#   'privatevapidkey',
#   'event',
#   'record',
#   'record',
#   'body',
#   'const',
#   'body',
#   'const',
#   'subscription',
#   'const',
#   'requestpayload',
#   'const',
#   'payload',
#   'title',
#   'content',
#   'openurl',
#   'subscription',
#   'payload',
#   'pushed',
#   'successfully',
#   'succeeded',
#   'element',
#   'queueurl',
#   'error',
#   'sending',
#   'notification',
#   'error',
#   'error',
#   'everything',
#   'done',
#   'return',
#   'ashishsheth',
#   '2019',
#   'pm'],
#  ['code',
#   'storage',
#   'reuse',
#   'deployment',
#   'package',
#   'several',
#   'functions',
#   'using',
#   'deployment',
#   'package',
#   'like',
#   'deletedashuserlambdafunction',
#   'type',
#   'properties',
#   'code',
#   's3bucket',
#   's3key',
#   'invitedashuserlambdafunction',
#   'type',
#   'properties',
#   'code',
#   's3bucket',
#   's3key',
#   'reuse',
#   'deployment',
#   'package',
#   'effective',
#   'code',
#   'storage',
#   'perspective',
#   'use',
#   'one',
#   'zip',
#   'say',
#   '10mb',
#   'several',
#   'functions',
#   'split',
#   'smaller',
#   'zips',
#   '10',
#   'packages',
#   'mb'],
#  ['javascript',
#   'api',
#   'missing',
#   'functions',
#   'trying',
#   'setup',
#   'call',
#   'api',
#   'returning',
#   'found',
#   'error',
#   'test',
#   'locally',
#   'npm',
#   'api',
#   'version',
#   'works',
#   'appears',
#   'api',
#   'included',
#   'include',
#   'function',
#   'errormessage',
#   'function',
#   'errortype',
#   'typeerror',
#   'stacktrace',
#   'code',
#   'test',
#   'whether',
#   'property',
#   'existed',
#   'check',
#   'functions',
#   'existed',
#   'call',
#   'returns',
#   'undefined',
#   'const',
#   'require',
#   'const',
#   'cloudwatch',
#   'new',
#   'async',
#   'event',
#   'const',
#   'params',
#   'metricwidget',
#   'event',
#   'new',
#   'const',
#   'response',
#   'await',
#   'params',
#   'return'],
#  ['expired',
#   'token',
#   'occasionally',
#   'calls',
#   'get',
#   'errors',
#   'minutes',
#   'look',
#   'like',
#   'expiredtoken',
#   'provided',
#   'token',
#   'expired',
#   'message',
#   'provided',
#   'token',
#   'expired',
#   'code',
#   'time',
#   '19',
#   '2015',
#   'pst',
#   'statuscode',
#   '400',
#   'retryable',
#   'true',
#   'seems',
#   'coming',
#   'attempt',
#   'upload',
#   'role',
#   'ability',
#   'works',
#   'time'],
#  ['reporting',
#   'issue',
#   'jeremymcjunkin',
#   'working',
#   'fix',
#   'update',
#   'thread',
#   'pushed'],
#  ['agreed',
#   'update',
#   'side',
#   'also',
#   'seeing',
#   'issue',
#   'frequently',
#   'hoping',
#   'fix',
#   'soon'],
#  ['deployed',
#   'change',
#   'fix',
#   'issue',
#   'let',
#   'us',
#   'know',
#   'still',
#   'seeing',
#   'happen'],
#  ['received',
#   'similar',
#   'error',
#   'issue',
#   'side',
#   'wrong',
#   'errormessage',
#   'security',
#   'token',
#   'included',
#   'request',
#   'invalid',
#   'errortype',
#   'unrecognizedclientexception',
#   'stacktrace',
#   'anonymous',
#   'anonymous',
#   'end',
#   'requestid',
#   'garnaat',
#   '16',
#   '2015'],
#  ['particular',
#   'problem',
#   'seemed',
#   'go',
#   'away',
#   'night',
#   'getting',
#   'errormessage',
#   'access',
#   'key',
#   'id',
#   'provided',
#   'exist',
#   'records',
#   'errortype',
#   'invalidaccesskeyid',
#   'stacktrace',
#   'anonymous',
#   'anonymous',
#   'end',
#   'requestid',
#   'think',
#   'issue',
#   'occasionally',
#   'delete',
#   'function',
#   'roles',
#   'policies',
#   'created',
#   'start',
#   'easy',
#   'thing',
#   'kappa',
#   'good',
#   'test',
#   'make',
#   'sure',
#   'configuration',
#   'actually',
#   'working',
#   'properly',
#   'however',
#   'role',
#   'gets',
#   'deleted',
#   'seems',
#   'like',
#   'sts',
#   'credentials',
#   'cached',
#   'somewhere',
#   'continue',
#   'used',
#   'execute',
#   'function',
#   'even',
#   'though',
#   'longer',
#   'valid',
#   'usually',
#   'waiting',
#   'hour',
#   'clears',
#   'problem',
#   'although',
#   'latest',
#   'one',
#   'lasted',
#   'hour',
#   'using',
#   'basic',
#   'workflow',
#   'since',
#   'released',
#   'never',
#   'problem',
#   'think',
#   'changed',
#   'side',
#   'cause',
#   'mitch'],
#  ['seeing',
#   'function',
#   'well',
#   'simple',
#   'function',
#   'reads',
#   'data',
#   'checks',
#   'internet',
#   'site',
#   'writes',
#   'back',
#   'get',
#   'expiredtoken',
#   'provided',
#   'token',
#   'expired',
#   'message',
#   'provided',
#   'token',
#   'expired',
#   'code',
#   'time',
#   '11',
#   '2015',
#   'utc',
#   'statuscode',
#   '400',
#   'retryable',
#   'true',
#   'happens',
#   'infrequently',
#   'function',
#   'running',
#   'every',
#   '15',
#   'minutes',
#   'happens',
#   'twice',
#   'day',
#   'concerned',
#   'use',
#   'mission',
#   'critical',
#   'work'],
#  ['resolved',
#   'getting',
#   'issue',
#   'java',
#   'web',
#   'service',
#   'running',
#   'tomcat',
#   'ebs',
#   'using',
#   'latest',
#   'libs'],
#  ['getting', 'issue', 'using', 'configuration', 'corvi42'],
#  ['still',
#   'get',
#   'error',
#   'expired',
#   'try',
#   'upload',
#   'bulk',
#   'data',
#   'like',
#   'upload',
#   'multiple',
#   'folder',
#   'nearly',
#   'folder',
#   'size',
#   '20gb',
#   'client',
#   'side',
#   'resolved',
#   'expiredtoken',
#   'provided',
#   'token',
#   'expired',
#   'let',
#   'know',
#   'issue',
#   'could',
#   'resolved',
#   'client',
#   'side',
#   'ranjitha',
#   '2019',
#   'pm'],
#  ['run',
#   'python',
#   'code',
#   'package',
#   'dependencies',
#   '500mb',
#   'requirement',
#   'trigger',
#   'sagemaker',
#   'endpoint',
#   'get',
#   'predictions',
#   'easy',
#   'extra',
#   'processing',
#   'variable',
#   'importance',
#   'using',
#   'packages',
#   'xgboost',
#   'shap',
#   'able',
#   'hit',
#   'endpoint',
#   'get',
#   'variable',
#   'importance',
#   'using',
#   'sagemaker',
#   'jupyter',
#   'notebook',
#   'want',
#   'replicate',
#   'thing',
#   '1',
#   'run',
#   'python',
#   'code',
#   'package',
#   'dependencies',
#   'pandas',
#   'xgboost',
#   'shap',
#   'total',
#   'package',
#   'size',
#   'greater',
#   '500mb',
#   'unzipped',
#   'deployment',
#   'package',
#   'size',
#   'greater',
#   '250',
#   'mb',
#   'hence',
#   'allowing',
#   'deploy',
#   'even',
#   'tried',
#   'using',
#   'function',
#   'cloud9',
#   'got',
#   'error',
#   'due',
#   'size',
#   'restrictions',
#   'also',
#   'tried',
#   'layers',
#   'luck',
#   '2',
#   'way',
#   'run',
#   'code',
#   'big',
#   'packages',
#   'bypassing',
#   'deployment',
#   'package',
#   'size',
#   'limitation',
#   '250',
#   'mb',
#   'way',
#   'trigger',
#   'sagemaker',
#   'notebook',
#   'execution',
#   'would',
#   'calculations',
#   'return',
#   'output',
#   'back',
#   'tdoo7',
#   '2019',
#   'pm'],
#  ['global',
#   'accelerator',
#   'path',
#   'patterns',
#   'application',
#   'load',
#   'balancer',
#   'set',
#   'send',
#   'requests',
#   'via',
#   'one',
#   'alb',
#   'different',
#   'functions',
#   'based',
#   'path',
#   'patterns',
#   'added',
#   'global',
#   'accelerator',
#   'path',
#   'patterns',
#   'seem',
#   'recognised',
#   'using',
#   'global',
#   'accelerator',
#   'wondering',
#   'functionality',
#   'work',
#   'tried',
#   'seeing',
#   'could',
#   'add',
#   'additional',
#   'endpoint',
#   'groups',
#   'add',
#   'second',
#   'listener',
#   'port',
#   '80',
#   'alb',
#   'listening',
#   'ideas',
#   'appreciated'],
#  ['yes',
#   'functionality',
#   'work',
#   'alb',
#   'behind',
#   'global',
#   'accelerator',
#   'allows',
#   'route',
#   'functions',
#   'based',
#   'http',
#   'request',
#   'method',
#   'http',
#   'header',
#   'path',
#   'pattern',
#   'query',
#   'string',
#   'one',
#   'alb',
#   'condition',
#   'would',
#   'work',
#   'expected',
#   'source',
#   'ip',
#   'since',
#   'global',
#   'accelerator',
#   'yet',
#   'preserve',
#   'source',
#   'ip',
#   'able',
#   'describe',
#   'details',
#   'setup',
#   'us',
#   'get',
#   'bottom',
#   'say',
#   'path',
#   'patterns',
#   'recognized',
#   'exact',
#   'behavior',
#   'see',
#   'harvo'],
#  ['possible',
#   'access',
#   'edge',
#   'origin',
#   'request',
#   'event',
#   'see',
#   'origin',
#   'request',
#   'event',
#   'payload',
#   'hostname',
#   'possible',
#   'access',
#   'hostname',
#   'http',
#   'request',
#   'triggered',
#   'event',
#   'somebody',
#   'typed',
#   'browser',
#   'bar',
#   'vs',
#   'wildcard',
#   'alternate',
#   'domain',
#   'name',
#   'cname',
#   'say',
#   'need',
#   'alter',
#   'response',
#   'based',
#   'upon',
#   'value',
#   'requested',
#   'hostname'],
#  ['default',
#   '0',
#   '0',
#   'contains',
#   'hostname',
#   'distribution',
#   'origin',
#   'request',
#   'event',
#   'need',
#   'access',
#   'host',
#   'header',
#   'original',
#   'incoming',
#   'request',
#   'origin',
#   'request',
#   'trigger',
#   'want',
#   'configure',
#   'cache',
#   'behavior',
#   'whitelist',
#   'host',
#   'header',
#   'forwarding',
#   'origin',
#   'server',
#   'making',
#   'change',
#   'expose',
#   'original',
#   'host',
#   'header',
#   'instead',
#   'distribution',
#   'hostname'],
#  ['would',
#   'also',
#   'really',
#   'like',
#   'feature',
#   'proposed',
#   'solution',
#   'work',
#   'host',
#   'one',
#   'headers',
#   'whitelisted'],
#  ['arkadiyt',
#   'looks',
#   'like',
#   'working',
#   'origin',
#   'could',
#   'share',
#   'use',
#   'case',
#   'solved',
#   'host',
#   'header',
#   'allowed',
#   'whitelisted',
#   'origin',
#   'available',
#   'origin',
#   'request',
#   'event',
#   'abhishek'],
#  ['want',
#   'redirect',
#   'users',
#   'possible',
#   'viewer',
#   'event',
#   'prefer',
#   'origin',
#   'event',
#   'cached',
#   'right',
#   'work',
#   'around',
#   'creating',
#   'separate',
#   'distribution',
#   'origin',
#   'request',
#   'always',
#   'redirects',
#   'seems',
#   'bit',
#   'hacky',
#   'rather',
#   'single',
#   'distribution'],
#  ['arkadiyt',
#   'sharing',
#   'use',
#   'case',
#   'host',
#   'header',
#   'whitelisting',
#   'available',
#   'yet',
#   'origin',
#   'workarounds',
#   'possible',
#   'let',
#   'keep',
#   'one',
#   'distribution',
#   'involves',
#   'setting',
#   'origin',
#   'custom',
#   'origin',
#   'instead',
#   'origin',
#   'either',
#   'two',
#   'approaches',
#   'work',
#   'enable',
#   'static',
#   'website',
#   'hosting',
#   'configure',
#   'bucket',
#   'custom',
#   'origin',
#   'https',
#   'create',
#   'cname',
#   'record',
#   'points',
#   'bucket',
#   'use',
#   'cname',
#   'custom',
#   'origin',
#   'option',
#   'using',
#   'origin',
#   'access',
#   'identity',
#   'restrict',
#   'access',
#   'bucket',
#   'https',
#   'abhishek'],
#  ['primary',
#   'problem',
#   'overwrites',
#   'host',
#   'header',
#   'request',
#   'origin',
#   'host',
#   'able',
#   'workaround',
#   'using',
#   'combination',
#   'viewer',
#   'request',
#   'copy',
#   'host',
#   'header',
#   'another',
#   'header',
#   'like',
#   'event',
#   'context',
#   'callback',
#   'const',
#   'request',
#   '0',
#   'key',
#   'value',
#   '0',
#   'return',
#   'callback',
#   'null',
#   'request',
#   'configure',
#   'whitelist',
#   'host',
#   'header',
#   'behaviour',
#   'way',
#   'also',
#   'takes',
#   'consideration',
#   'caching',
#   'also',
#   'passes',
#   'header',
#   'along',
#   'access',
#   'header',
#   'event',
#   'context',
#   'callback',
#   'const',
#   'request',
#   '0',
#   'const',
#   'headers',
#   'const',
#   'requesthost',
#   'headers',
#   '0',
#   'requesthost',
#   'callback',
#   'null',
#   'request'],
#  ['havah',
#   'overwrites',
#   'host',
#   'header',
#   'request',
#   'origin',
#   'domain',
#   'name',
#   'host',
#   'header',
#   'whitelisted',
#   'cache',
#   'behavior',
#   'whitelisting',
#   'host',
#   'header',
#   'access',
#   'unmodified',
#   'host',
#   'header',
#   'function',
#   'abhishek'],
#  ['also',
#   'need',
#   'use',
#   'case',
#   'single',
#   'page',
#   'react',
#   'app',
#   'bucket',
#   '10s',
#   'cnames',
#   'need',
#   'whitelist',
#   'host',
#   'name',
#   'headers',
#   'inject',
#   'opengraph',
#   'tags',
#   'html',
#   'depending',
#   'host',
#   'name',
#   'request',
#   'otherwise',
#   'serve',
#   'content',
#   'bucket',
#   'configured',
#   'private',
#   'accessible',
#   'react',
#   'code',
#   'could',
#   'per',
#   'host',
#   'name',
#   'browser',
#   'bots',
#   'like',
#   'facebook',
#   'crawler',
#   '27',
#   '2019',
#   'pm'],
#  ['validate',
#   'given',
#   'cloudwatch',
#   'events',
#   'scheduleexpression',
#   'valid',
#   'like',
#   'able',
#   'validate',
#   'cloudwatch',
#   'events',
#   'scheduleexpression',
#   'rate',
#   'cron',
#   'making',
#   'putrule',
#   'api',
#   'call',
#   'javascript',
#   'available',
#   'feature'],
#  ['net',
#   'trouble',
#   'referencing',
#   'core',
#   'library',
#   'playing',
#   'toolkit',
#   'created',
#   'example',
#   'function',
#   'uppercases',
#   'string',
#   'tested',
#   'good',
#   'want',
#   'create',
#   'library',
#   'method',
#   'use',
#   'code',
#   'created',
#   'core',
#   'library',
#   'simple',
#   'static',
#   'public',
#   'object',
#   'single',
#   'public',
#   'method',
#   'added',
#   'reference',
#   'library',
#   'project',
#   'looks',
#   'good',
#   'however',
#   'matter',
#   'tried',
#   'seem',
#   'reference',
#   'public',
#   'class',
#   'method',
#   'project',
#   'went',
#   'created',
#   'simple',
#   'core',
#   'console',
#   'app',
#   'project',
#   'added',
#   'library',
#   'problem',
#   'referencing',
#   'library',
#   'compared',
#   'project',
#   'settings',
#   'standalone',
#   'console',
#   'app',
#   'seem',
#   'building',
#   'core',
#   'going',
#   'new',
#   'core',
#   'probably',
#   'stupid',
#   'grants',
#   '26',
#   '2019'],
#  ['found',
#   'ide',
#   'issue',
#   'even',
#   'though',
#   'intellisense',
#   'show',
#   'library',
#   'entered',
#   'using',
#   'show',
#   'class',
#   'members',
#   'still',
#   'compiled',
#   'worked',
#   'saved',
#   'project',
#   'exited',
#   'restart',
#   'intellisense',
#   'library',
#   'tags',
#   'started',
#   'working'],
#  ['mounting',
#   'efs',
#   'file',
#   'systems',
#   'would',
#   'consider',
#   'possibility',
#   'mount',
#   'specific',
#   'efs',
#   'file',
#   'system',
#   'within',
#   'function',
#   'way',
#   'functions',
#   'could',
#   'stream',
#   'large',
#   'amount',
#   'data',
#   'functions'],
#  ['sylvain',
#   'perron',
#   'feedback',
#   'brought',
#   'comments',
#   'attention',
#   'service',
#   'team',
#   'evaluate',
#   'request',
#   'collaboration'],
#  ['sylvain',
#   'currently',
#   'need',
#   'use',
#   'intermediate',
#   'store',
#   'like',
#   'transfer',
#   'large',
#   'amounts',
#   'data',
#   'definitely',
#   'appreciate',
#   'feedback',
#   'looking',
#   'make',
#   'simpler'],
#  ['update',
#   'case',
#   'need',
#   'download',
#   'even',
#   'file',
#   'qc',
#   'checks',
#   'using',
#   'various',
#   'functions',
#   'download',
#   'file',
#   'efs',
#   'file',
#   'system',
#   'mounted',
#   'function',
#   'would',
#   'save',
#   'time',
#   'bandwidth',
#   'download',
#   'file',
#   'invocation',
#   'shatgupt',
#   '17',
#   '2016',
#   'specify',
#   'file',
#   'downloaded'],
#  ['would',
#   'like',
#   'use',
#   'toooo',
#   'sloowwwww',
#   'work',
#   'also',
#   'many',
#   'functionality',
#   'missing',
#   'partial',
#   'update',
#   'least',
#   'append',
#   'file',
#   'many',
#   'feature',
#   'want',
#   'request',
#   'would',
#   'easier',
#   'using',
#   'efs',
#   'waiting',
#   'update'],
#  ['given',
#   'package',
#   'size',
#   '50mb',
#   'space',
#   '512mb',
#   'lambdas',
#   'become',
#   'unusable',
#   'functions',
#   'need',
#   'disk',
#   'storage',
#   'example',
#   'functions',
#   'use',
#   'precomputed',
#   'ml',
#   'model',
#   'files',
#   'get',
#   'pretty',
#   'large',
#   'like',
#   'rocksdb',
#   'cold',
#   'start',
#   'delays',
#   '512',
#   'mb',
#   'limits',
#   'copying',
#   'viable',
#   'solution',
#   'viable',
#   'needs',
#   'essential',
#   'ability',
#   'attach',
#   'kind',
#   'larger',
#   'disk',
#   'volume',
#   'love',
#   'want',
#   'see',
#   'become',
#   'successful',
#   'anyone',
#   'respond',
#   'plans',
#   'address',
#   'needs',
#   'ayush',
#   'gupta',
#   '11',
#   '2016',
#   'pm'],
#  [],
#  ['people', 'asking', 'hacker', 'news'],
#  ['ml',
#   'computations',
#   'would',
#   'perfect',
#   'use',
#   'libraries',
#   'expect',
#   'grabbing',
#   'model',
#   'files',
#   'even',
#   'mounts',
#   'would',
#   'great'],
#  ['read', 'efs', 'would', 'enough', 'needs'],
#  ['feature',
#   'request',
#   'already',
#   'logged',
#   'appropriate',
#   'team',
#   'however',
#   'eta',
#   'feature',
#   'available',
#   'keep',
#   'eye',
#   'blogs',
#   'stay',
#   'updated',
#   'latest',
#   'news',
#   'umair'],
#  ['efs', 'together', 'powerful', 'ml', 'web', 'services'],
#  ['essential',
#   'access',
#   'data',
#   'efs',
#   'important',
#   'bioinformatics',
#   'applications'],
#  ['updates',
#   'request',
#   'need',
#   'support',
#   'persistence',
#   'certain',
#   'stream',
#   'data',
#   'function',
#   'appreciate',
#   'comments',
#   'suryanittala',
#   '13',
#   '2017'],
#  ['great', 'lambdas', 'working', 'thousands', 'small', 'files'],
#  ['would',
#   'really',
#   'love',
#   'migrate',
#   'existing',
#   'legacy',
#   'file',
#   'processes',
#   'world',
#   'ample',
#   'storage',
#   'required',
#   'launching',
#   'ephemeral',
#   'instances',
#   'workloads',
#   'seems',
#   '2010'],
#  ['umair',
#   'update',
#   'eta',
#   'well',
#   'year',
#   'long',
#   'keep',
#   'eye',
#   'blogs',
#   'damian'],
#  ['would',
#   'helpful',
#   'us',
#   'since',
#   'sometimes',
#   'process',
#   'files',
#   'since',
#   '512mb',
#   'even',
#   'processing',
#   'files',
#   '250mb',
#   'hard',
#   'since',
#   'input',
#   'output',
#   'file',
#   'need',
#   'store'],
#  ['great', 'ml'],
#  ['using',
#   'image',
#   'document',
#   'processing',
#   'stopped',
#   'developing',
#   '512mb',
#   'temp',
#   'storage',
#   'limit',
#   'way',
#   'low',
#   'processing',
#   'documents'],
#  [],
#  ['lots',
#   'use',
#   'cases',
#   'expands',
#   'capabilities',
#   'understand',
#   'challenges',
#   'mounting',
#   'making',
#   'index',
#   'file',
#   'system',
#   'available',
#   'short',
#   'period',
#   'time',
#   'could',
#   'utilized',
#   'efficiently',
#   'within',
#   'minute',
#   'time',
#   'frame',
#   'function',
#   'alloted',
#   'granted',
#   'could',
#   'use',
#   'cases',
#   'many',
#   'applications',
#   'want',
#   'file',
#   'stored',
#   'locally',
#   'make',
#   'modifications',
#   'means',
#   'source',
#   'destination',
#   'file',
#   'size',
#   'total',
#   'needs',
#   'less',
#   '512mb',
#   'half',
#   'problem',
#   'half',
#   'source',
#   'file',
#   'multiple',
#   'times',
#   'one',
#   'step',
#   'would',
#   'removed',
#   'file',
#   'already',
#   'mounted',
#   'file',
#   'system',
#   'engineers',
#   'looking',
#   'would',
#   'suggest',
#   'thinking',
#   'problem',
#   'idea',
#   'specialized',
#   'version',
#   'efs',
#   'specifically',
#   'use',
#   'limited',
#   'storage',
#   'sizes',
#   'say',
#   '20gb',
#   'limits',
#   'number',
#   'say',
#   'speak',
#   'everyone',
#   'need',
#   'primarily',
#   'duplicate',
#   'work',
#   'multiple',
#   'functions',
#   'persistent',
#   'files',
#   'across',
#   'functions',
#   'efs',
#   'well',
#   'provide',
#   'additional',
#   'drive',
#   'space',
#   '512mb',
#   'allotted',
#   'today'],
#  ['another',
#   'use',
#   'case',
#   'rendering',
#   'animations',
#   'using',
#   'spot',
#   'instances',
#   'spun',
#   'function',
#   'instances',
#   'share',
#   'efs',
#   'setup',
#   'render',
#   'together',
#   'right',
#   'uploading',
#   'zip',
#   'file',
#   'triggers',
#   'new',
#   'servers',
#   'pull',
#   'object',
#   'process',
#   'would',
#   'greatly',
#   'streamlined',
#   'could',
#   'drop',
#   'zip',
#   'directly',
#   'efs',
#   'via'],
#  [],
#  ['year', 'half', 'passed', 'engineer', 'log', 'freezed', 'always'],
#  ['alias',
#   'dimension',
#   'available',
#   'according',
#   'documentation',
#   'https',
#   'access',
#   'alias',
#   'dimension',
#   'looking',
#   'metrics',
#   'cloudwatch',
#   'despite',
#   'seeing',
#   'dimensions',
#   'doc',
#   'including',
#   'resource',
#   'executedversion',
#   'none',
#   'functions',
#   'alias',
#   'dimension',
#   'attached',
#   'anyone',
#   'else',
#   'seeing',
#   'similar'],
#  ['bump', 'record'],
#  ['bump',
#   'anyone',
#   'else',
#   'experiencing',
#   'similar',
#   'sort',
#   'issue',
#   'want',
#   'get',
#   'look',
#   'dev',
#   'aliases',
#   'example'],
#  ['anyone',
#   'comment',
#   'docs',
#   'wrong',
#   'special',
#   'way',
#   'enable',
#   'dimension',
#   'cloudwatch'],
#  ['bump'],
#  ['update',
#   'contacted',
#   'support',
#   'apparently',
#   'docs',
#   'wrong',
#   'dimension'],
#  ['task',
#   'timed',
#   'first',
#   'invocations',
#   'works',
#   'got',
#   'collection',
#   'functions',
#   'serving',
#   'simple',
#   'crud',
#   'rest',
#   'api',
#   'via',
#   'api',
#   'gateway',
#   'leave',
#   'function',
#   'idle',
#   'awhile',
#   'deploy',
#   'first',
#   'invocations',
#   'timeout',
#   'return',
#   'internal',
#   'server',
#   'error',
#   'starts',
#   'working',
#   'fine',
#   'invocations',
#   'troubles',
#   'goes',
#   'idle',
#   'logs',
#   'say',
#   'task',
#   'timed',
#   'seconds',
#   'one',
#   'lambdas',
#   'exhibiting',
#   'behavior',
#   'getaccounts',
#   'async',
#   'event',
#   'context',
#   'callback',
#   'false',
#   'const',
#   'connection',
#   'dbconfig',
#   'try',
#   'const',
#   'results',
#   'await',
#   'executequery',
#   'connection',
#   'accounts',
#   'statuscode',
#   '200',
#   'headers',
#   'responseheaders',
#   'body',
#   'results',
#   'catch',
#   'err',
#   'error',
#   'err',
#   'statuscode',
#   '400',
#   'headers',
#   'responseheaders',
#   'body',
#   'finally',
#   'function',
#   'executequery',
#   'conn',
#   'query',
#   'args',
#   'return',
#   'new',
#   'promise',
#   'resolve',
#   'reject',
#   'connerror',
#   'connerror',
#   'error',
#   'connerror',
#   'reject',
#   'connerror',
#   'else',
#   'query',
#   'args',
#   'err',
#   'results',
#   'err',
#   'error',
#   'err',
#   'reject',
#   'err',
#   'else',
#   'resolve',
#   'results',
#   'stackwalker',
#   '25',
#   '2019',
#   'stackwalker',
#   '25',
#   '2019'],
#  ['using',
#   'extra',
#   'libaries',
#   'trying',
#   'use',
#   'extra',
#   'libary',
#   'zbar',
#   'im',
#   'sure',
#   'would',
#   'go',
#   'packing',
#   'normally',
#   'would',
#   'install',
#   'yum',
#   'install',
#   'zbar',
#   'know',
#   'binaries',
#   'dont',
#   'see',
#   'get',
#   'repo',
#   'package'],
#  ['guidelines',
#   'building',
#   'packages',
#   'dependencies',
#   'likely',
#   'need',
#   'one',
#   'python',
#   'http',
#   'helps',
#   'vishal'],
#  ['trying',
#   'hard',
#   'get',
#   'zbar',
#   'working',
#   'function',
#   'error',
#   'getting',
#   'trying',
#   'access',
#   'libzbar',
#   'libray',
#   'unable',
#   'import',
#   'module',
#   'openshared',
#   'object',
#   'file',
#   'file',
#   'directory',
#   'got',
#   'docker',
#   'image',
#   'placed',
#   'bin',
#   'directory',
#   'included',
#   'zip',
#   'package',
#   'code',
#   'added',
#   'two',
#   'lines',
#   'let',
#   'know',
#   'look',
#   'file',
#   'still',
#   'working',
#   'anyone'],
#  ['ever', 'figure', 'also', 'interested'],
#  ['possible',
#   'add',
#   'shut',
#   'callback',
#   'got',
#   'reply',
#   'awssupport',
#   'twitter',
#   'saying',
#   'always',
#   'post',
#   'feedback',
#   'new',
#   'bear',
#   'already',
#   'asked',
#   'imagine',
#   'feature',
#   'describe',
#   'easy',
#   'implement',
#   'believe',
#   'might',
#   'good',
#   'reason',
#   'implemented',
#   'yet',
#   'still',
#   'hurt',
#   'ask',
#   'would',
#   'possible',
#   'optionally',
#   'call',
#   'function',
#   'one',
#   'last',
#   'time',
#   'instance',
#   'shut',
#   'would',
#   'eg',
#   'enable',
#   'us',
#   'resolve',
#   'already',
#   'known',
#   'issue',
#   'db',
#   'connection',
#   'management',
#   'talking',
#   'case',
#   'establish',
#   'db',
#   'connection',
#   'eg',
#   'documentdb',
#   'remains',
#   'open',
#   'even',
#   'though',
#   'instance',
#   'shut',
#   'new',
#   'callback',
#   'implemented',
#   'would',
#   'possible',
#   'close',
#   'active',
#   'connection',
#   'thus',
#   'removing',
#   'possibility',
#   'max',
#   'number',
#   'connections',
#   'towards',
#   'db',
#   'separate',
#   'callback',
#   'simple',
#   'param',
#   'context',
#   'argument',
#   'function',
#   'would',
#   'also',
#   'suffice',
#   'believe',
#   'aware',
#   'alternative',
#   'approaches',
#   'like',
#   'eg',
#   'setting',
#   'single',
#   'instance',
#   'single',
#   'point',
#   'failure',
#   'manage',
#   'connections',
#   'seems',
#   'bit',
#   'unnecessary',
#   'would',
#   'say',
#   'serverful',
#   'happy',
#   'hear',
#   'others',
#   'think',
#   'feature',
#   'also',
#   'specific',
#   'situation',
#   'correct',
#   'wrong',
#   'anything',
#   'always',
#   'glad',
#   'learn',
#   'new'],
#  ['authorizer',
#   'function',
#   'logging',
#   'cloudwatch',
#   'greetings',
#   'full',
#   'disclosure',
#   'still',
#   'new',
#   'first',
#   'project',
#   'creating',
#   'websocket',
#   'connection',
#   'website',
#   'dynamodb',
#   'table',
#   'inasmuch',
#   'created',
#   'tables',
#   'websocket',
#   'api',
#   'supporting',
#   'functions',
#   'everything',
#   'working',
#   'great',
#   'added',
#   'js',
#   'lamba',
#   'authorizer',
#   'function',
#   'node',
#   'peculiar',
#   'occurring',
#   'within',
#   'function',
#   'using',
#   'simple',
#   'statements',
#   'debug',
#   'unauthorized',
#   'condition',
#   'test',
#   'function',
#   'logs',
#   'appear',
#   'cloudwatch',
#   'however',
#   'attempt',
#   'make',
#   'connection',
#   'website',
#   'logs',
#   'appear',
#   'cloudwatch',
#   'functions',
#   'connect',
#   'disconnect',
#   'routing',
#   'functions',
#   'work',
#   'normally',
#   'output',
#   'text',
#   'cloudwatch',
#   'authorizer',
#   'function',
#   'fails',
#   'send',
#   'logs',
#   'yet',
#   'click',
#   'test',
#   'button',
#   'logs',
#   'sent',
#   'thinking',
#   'might',
#   'log',
#   'settings',
#   'function',
#   'able',
#   'locate',
#   'anything',
#   'entry',
#   'developer',
#   'allow',
#   'logs',
#   'createloggroup',
#   'allow',
#   'logs',
#   'createlogstream',
#   'allow',
#   'logs',
#   'describeloggroups',
#   'allow',
#   'logs',
#   'describelogstreams',
#   'allow',
#   'logs',
#   'putlogevents',
#   'allow',
#   'logs',
#   'getlogevents',
#   'allow',
#   'logs',
#   'filterlogevents',
#   'global',
#   'log',
#   'setting',
#   'websocket',
#   'api',
#   'figure',
#   'apis',
#   'except',
#   'authorizer',
#   'log',
#   'cloudwatch',
#   'anyone',
#   'run',
#   'like',
#   'fix',
#   'anyone',
#   'give',
#   'hint',
#   'look',
#   'debug',
#   'issue'],
#  ['answer',
#   'question',
#   'problem',
#   'indeed',
#   'due',
#   'unauthorized',
#   'problem',
#   'mentioned',
#   'thought',
#   'nothing',
#   'setup',
#   'authorizer',
#   'set',
#   'event',
#   'payload',
#   'custom',
#   'header',
#   'neglected',
#   'set',
#   'header',
#   'browser',
#   'session',
#   'according',
#   'documentation',
#   'https',
#   'section',
#   '9b',
#   'api',
#   'gateway',
#   'throw',
#   '401',
#   'unauthorized',
#   'error',
#   'without',
#   'even',
#   'executing',
#   'function',
#   'source',
#   'problem']]

# %% [markdown]
# #### Step 6) Remove repeated words in the same sentence

# %%
text['description'] = cleantext

cleantext = []

for msg in text['description']:
    sent = []
    for word in msg:
        if word not in sent:
            sent.append(word.lower())
    cleantext.append(sent)

cleantext
# Out:
# [['deploy',
#   'multiple',
#   'end',
#   'point',
#   'springboot',
#   'want',
#   'clarify',
#   'comes',
#   'deploying',
#   'rest',
#   'endpoints',
#   'implemented',
#   'single',
#   'application',
#   'expose',
#   'points',
#   'original',
#   'spring',
#   'boot',
#   'writing',
#   'function',
#   'update',
#   'paths',
#   'add',
#   'snippet',
#   'resources',
#   'petstorefunction',
#   'type',
#   'properties',
#   'handler',
#   'runtime',
#   'java8',
#   'codeuri',
#   'memorysize',
#   '1512',
#   'policies',
#   'awslambdabasicexecutionrole',
#   'timeout',
#   '60',
#   'events',
#   'getresource',
#   'api',
#   'path',
#   'method',
#   'need',
#   'write',
#   'per',
#   'spin',
#   'containers',
#   'way',
#   'share',
#   'container',
#   'across',
#   'isuru'],
#  ['trigger',
#   'second',
#   'function',
#   'response',
#   'external',
#   'http',
#   'service',
#   'process',
#   'uses',
#   'system',
#   'slow',
#   'requests',
#   'could',
#   'make',
#   'generates',
#   'request',
#   'sends',
#   'server',
#   'idling',
#   'task',
#   'waiting',
#   'would',
#   'great',
#   'waste',
#   'time',
#   'resources',
#   'instead',
#   'seems',
#   'better',
#   'processes',
#   'result',
#   'call',
#   'alive',
#   'seconds',
#   'times',
#   'many',
#   'thing',
#   'possible',
#   'suggest',
#   'setting',
#   'jeroenv',
#   '10',
#   '2019'],
#  ['sounds',
#   'like',
#   'might',
#   'want',
#   'provide',
#   'external',
#   'service',
#   'callback',
#   'url',
#   'way',
#   'done',
#   'whatever',
#   'slow',
#   'processing',
#   'send',
#   'results',
#   'invoke',
#   'function',
#   'course',
#   'assuming',
#   'capability',
#   'alter',
#   'really',
#   'anything',
#   'available',
#   'http',
#   'call'],
#  ['exception',
#   'thrown',
#   'invoking',
#   'local',
#   'developing',
#   'nodejs',
#   'function',
#   'vs',
#   'code',
#   'using',
#   'serverless',
#   'framework',
#   'able',
#   'debug',
#   'locally',
#   'encountered',
#   'issue',
#   'try',
#   'invoke',
#   'another',
#   'deployed',
#   'within',
#   'shown',
#   'following',
#   'snippet',
#   'var',
#   'require',
#   'new',
#   'return',
#   'params',
#   'however',
#   'throws',
#   'incompletesignatureexception',
#   'along',
#   'message',
#   'valid',
#   'pair',
#   'missing',
#   'authorization',
#   'header',
#   'deploy',
#   'calling',
#   'invocation',
#   'second',
#   'works',
#   'fine',
#   'must',
#   'additional',
#   'need',
#   'trouble',
#   'know',
#   'note',
#   'nowhere',
#   'explicitly',
#   'setting',
#   'signature',
#   'values',
#   'search',
#   'solution',
#   'returned',
#   'suggestions',
#   'related',
#   'api',
#   'gateway',
#   'custom',
#   'authorizers',
#   'trying',
#   'alanwarren395',
#   '11',
#   '2019'],
#  ['option',
#   'set',
#   'minimum',
#   'number',
#   'functions',
#   'nice',
#   'heave',
#   'feature',
#   'would',
#   'ability',
#   'warmed',
#   'instances',
#   'well',
#   'able',
#   'specific',
#   'schedule',
#   'similar',
#   'cron',
#   'job',
#   'exchange',
#   'fee',
#   'developers',
#   'write',
#   'workarounds',
#   'services',
#   'need',
#   'certain',
#   'level',
#   'responsiveness',
#   'cold',
#   'periods',
#   'think',
#   'people',
#   'uncommon',
#   'things',
#   'late',
#   'night'],
#  ['feedback',
#   'forward',
#   'feature',
#   'request',
#   'internal',
#   'team',
#   'however',
#   'able',
#   'provide',
#   'eta',
#   'released',
#   'kindly',
#   'check',
#   'products',
#   'announcement',
#   'page',
#   '1',
#   'blog',
#   '2',
#   'periodically',
#   'updates',
#   'https'],
#  ['microsoft',
#   'feature',
#   'really',
#   'like',
#   'support',
#   'well',
#   'basically',
#   'cold',
#   'starts',
#   'longer',
#   'concern',
#   'use',
#   'azure',
#   'anyone',
#   'curious',
#   'announcement',
#   'https',
#   'log',
#   'vote',
#   'would',
#   'make',
#   'life',
#   'much',
#   'easier',
#   'focus',
#   'every',
#   'decision',
#   'around',
#   'reduce',
#   'manually',
#   'warm',
#   'lambdas',
#   'need',
#   'go',
#   'api',
#   'gateway',
#   'using',
#   'xray'],
#  ['one', 'keep', 'lamdbas', 'warm', 'plugin', 'https', 'use', 'works'],
#  ['check',
#   'many',
#   'concurrent',
#   'currently',
#   'run',
#   'sometimes',
#   'want',
#   'know',
#   'still',
#   'running',
#   'limit',
#   'spawn',
#   'new',
#   'one',
#   'keep',
#   'amount',
#   'parallel',
#   'api',
#   'let',
#   'information'],
#  ['currently',
#   'api',
#   'tell',
#   'real',
#   'time',
#   'concrete',
#   'number',
#   'concurrent',
#   'executions',
#   'make',
#   'fair',
#   'estimate',
#   'using',
#   'provided',
#   'cloudwatch',
#   'metrics',
#   'multiplying',
#   'invocations',
#   'supplied',
#   'minute',
#   'average',
#   'duration',
#   'ms',
#   'given',
#   'point',
#   'looking',
#   'features',
#   'throttling',
#   'area'],
#  ['cecilia', 'service', 'api', 'yet'],
#  ['possible',
#   'change',
#   'timeout',
#   'container',
#   'trying',
#   'avoid',
#   'cold',
#   'start',
#   'functions',
#   'way',
#   'control',
#   'reserve',
#   '10',
#   'containers',
#   'longer',
#   'period',
#   'time',
#   'even',
#   'extra',
#   'charge',
#   'want',
#   'know',
#   'anything',
#   'besides',
#   'keeping',
#   'warm',
#   'schedule',
#   'requests',
#   'jnabais',
#   '20',
#   '2019'],
#  ['unfortunately',
#   'possible',
#   'control',
#   'container',
#   'timeout',
#   'reserve',
#   'longer',
#   'time',
#   'see',
#   'already',
#   'following',
#   'best',
#   'practices',
#   'keeping',
#   'functions',
#   'warm',
#   'using',
#   'scheduled',
#   'requests',
#   'feedback',
#   'forward',
#   'feature',
#   'request',
#   'internal',
#   'team',
#   'however',
#   'able',
#   'provide',
#   'eta',
#   'released',
#   'kindly',
#   'check',
#   'products',
#   'announcement',
#   'page',
#   '1',
#   'blog',
#   '2',
#   'periodically',
#   'updates',
#   'https'],
#  ['permission',
#   'detachnetworkinterfaces',
#   'reasonable',
#   'run',
#   'function',
#   'make',
#   'sense',
#   'add',
#   'action',
#   'detachnetworkinferace',
#   'iam',
#   'role',
#   'within',
#   'understanding',
#   'case',
#   'needs',
#   'eni',
#   'access',
#   'resources',
#   'enable',
#   'attach',
#   'managed',
#   'policy',
#   'awslambdavpcaccessexecutionrole',
#   'functions',
#   'browsing',
#   'noticed',
#   'detachnetworkinterface',
#   'missing',
#   'version',
#   'statement',
#   'effect',
#   'allow',
#   'logs',
#   'createloggroup',
#   'createlogstream',
#   'putlogevents',
#   'createnetworkinterface',
#   'describenetworkinterfaces',
#   'deletenetworkinterface',
#   'resource',
#   'container',
#   'runs',
#   'delete',
#   'detach',
#   'bit',
#   'deep',
#   'dive',
#   'question',
#   'curious',
#   'internals'],
#  ['managed',
#   'service',
#   'operations',
#   'network',
#   'interfaces',
#   'taken',
#   'care',
#   'internally',
#   'internal',
#   'information',
#   'provide',
#   'much',
#   'details',
#   'related',
#   'however',
#   'need',
#   'create',
#   'delete',
#   'permissions',
#   'enis',
#   'created',
#   'account',
#   'would',
#   'require',
#   'hope',
#   'answers',
#   'query',
#   'let',
#   'us',
#   'know',
#   'queries'],
#  [],
#  ['pass',
#   'cognito',
#   'api',
#   'gateway',
#   'python',
#   'couple',
#   'endpoints',
#   'configured',
#   'authorizer',
#   'client',
#   'app',
#   'user',
#   'pool',
#   'credentials',
#   'flow',
#   'integrated',
#   'function',
#   'need',
#   'know',
#   'used',
#   'perform',
#   'access',
#   'see',
#   'anything',
#   'context',
#   'object',
#   'event',
#   'variable',
#   'identity',
#   'idea',
#   'much'],
#  ['cognito',
#   'user',
#   'pool',
#   'returns',
#   'different',
#   'properties',
#   'json',
#   'claims',
#   'response',
#   'method',
#   'caller',
#   'successfully',
#   'authenticated',
#   'looks',
#   'like',
#   'sub',
#   'aud',
#   'xyz',
#   'true',
#   'id',
#   '1499671038',
#   'iss',
#   'https',
#   'username',
#   'user2',
#   'exp',
#   '10',
#   'utc',
#   '2017',
#   'iat',
#   'email',
#   'abc',
#   'context',
#   'variable',
#   'holds',
#   'contextual',
#   'information',
#   'api',
#   'call',
#   'used',
#   'get',
#   '1',
#   'claim',
#   'hold',
#   'app',
#   'client',
#   'add',
#   'mapping',
#   'template',
#   'integration',
#   'request',
#   'appclient',
#   'hope',
#   'helps',
#   'let',
#   'us',
#   'know',
#   'queries'],
#  ['layers',
#   'supported',
#   'trying',
#   'deploy',
#   'get',
#   'failed',
#   'reason',
#   'template',
#   'format',
#   'error',
#   'unrecognized',
#   'resource',
#   'types',
#   'https',
#   'deploys',
#   'bug',
#   'stockholm'],
#  ['noticed',
#   'problem',
#   'able',
#   'find',
#   'documentation',
#   'regarding',
#   'forum',
#   'post',
#   'relevant',
#   'search',
#   'result',
#   'google'],
#  ['got',
#   'message',
#   'someone',
#   'saying',
#   'support',
#   'cf',
#   'deployed',
#   'latest',
#   'version',
#   'hopefully',
#   'would',
#   'come',
#   'soon',
#   'tested',
#   'rcently'],
#  ['codebuild',
#   'error',
#   'service',
#   'role',
#   'authorized',
#   'perform',
#   'createnetworkinterface',
#   'trying',
#   'allow',
#   'config',
#   'connect',
#   'connection',
#   'getting',
#   'following',
#   'upon',
#   'build',
#   'already',
#   'attempted',
#   'add',
#   'used',
#   'roles',
#   'still',
#   'luck'],
#  ['hit',
#   'problem',
#   'luck',
#   'sorting',
#   'update',
#   'using',
#   'codestar',
#   'generated',
#   'permission',
#   'boundary',
#   'pipeline',
#   'role',
#   'seems',
#   'issue',
#   'temporarily',
#   'removing',
#   'adding',
#   'permissions',
#   'fixed',
#   'need',
#   'narrow',
#   'add',
#   'work',
#   'part',
#   'probably',
#   'specific',
#   'account',
#   'good',
#   'buzzologist',
#   '20',
#   '2019',
#   'pm'],
#  ['grant',
#   'different',
#   'permissions',
#   'work',
#   'effect',
#   'allow',
#   'action',
#   'createnetworkinterface',
#   'describedhcpoptions',
#   'describenetworkinterfaces',
#   'deletenetworkinterface',
#   'describesubnets',
#   'describesecuritygroups',
#   'describevpcs',
#   'resource',
#   'createnetworkinterfacepermission',
#   'arn',
#   'region',
#   'accountnumber',
#   'condition',
#   'stringequals',
#   'subnet',
#   'id',
#   'authorizedservice',
#   'permission',
#   'section',
#   'need',
#   'want',
#   'restrict',
#   'code',
#   'build',
#   'using',
#   'specific',
#   'removed',
#   'restriction'],
#  ['sending',
#   'webpush',
#   'notification',
#   'developing',
#   'progressive',
#   'web',
#   'app',
#   'pwa',
#   'part',
#   'trying',
#   'send',
#   'push',
#   'clients',
#   'setup',
#   'upon',
#   'certain',
#   'actions',
#   'client',
#   'message',
#   'containing',
#   'subscription',
#   'payload',
#   'information',
#   'stored',
#   'sqs',
#   'whenever',
#   'pushed',
#   'triggered',
#   'used',
#   'using',
#   'nodejs',
#   'library',
#   'however',
#   'see',
#   'successfully',
#   'invoked',
#   'able',
#   'read',
#   'deliver',
#   'code',
#   'log',
#   'succeeded',
#   'error',
#   'details',
#   'directly',
#   'logs',
#   'everything',
#   'done',
#   'let',
#   'know',
#   'wrong',
#   'const',
#   'require',
#   'async',
#   'function',
#   'event',
#   'context',
#   'var',
#   'replace',
#   'email',
#   'mailto',
#   'supportemail',
#   'publicvapidkey',
#   'privatevapidkey',
#   'record',
#   'body',
#   'requestpayload',
#   'title',
#   'content',
#   'openurl',
#   'element',
#   'queueurl',
#   'return',
#   'ashishsheth',
#   '2019',
#   'pm'],
#  ['code',
#   'storage',
#   'reuse',
#   'deployment',
#   'package',
#   'several',
#   'functions',
#   'using',
#   'like',
#   'deletedashuserlambdafunction',
#   'type',
#   'properties',
#   's3bucket',
#   's3key',
#   'invitedashuserlambdafunction',
#   'effective',
#   'perspective',
#   'use',
#   'one',
#   'zip',
#   'say',
#   '10mb',
#   'split',
#   'smaller',
#   'zips',
#   '10',
#   'packages',
#   'mb'],
#  ['javascript',
#   'api',
#   'missing',
#   'functions',
#   'trying',
#   'setup',
#   'call',
#   'returning',
#   'found',
#   'error',
#   'test',
#   'locally',
#   'npm',
#   'version',
#   'works',
#   'appears',
#   'included',
#   'include',
#   'function',
#   'errormessage',
#   'errortype',
#   'typeerror',
#   'stacktrace',
#   'code',
#   'whether',
#   'property',
#   'existed',
#   'check',
#   'returns',
#   'undefined',
#   'const',
#   'require',
#   'cloudwatch',
#   'new',
#   'async',
#   'event',
#   'params',
#   'metricwidget',
#   'response',
#   'await',
#   'return'],
#  ['expired',
#   'token',
#   'occasionally',
#   'calls',
#   'get',
#   'errors',
#   'minutes',
#   'look',
#   'like',
#   'expiredtoken',
#   'provided',
#   'message',
#   'code',
#   'time',
#   '19',
#   '2015',
#   'pst',
#   'statuscode',
#   '400',
#   'retryable',
#   'true',
#   'seems',
#   'coming',
#   'attempt',
#   'upload',
#   'role',
#   'ability',
#   'works'],
#  ['reporting',
#   'issue',
#   'jeremymcjunkin',
#   'working',
#   'fix',
#   'update',
#   'thread',
#   'pushed'],
#  ['agreed',
#   'update',
#   'side',
#   'also',
#   'seeing',
#   'issue',
#   'frequently',
#   'hoping',
#   'fix',
#   'soon'],
#  ['deployed',
#   'change',
#   'fix',
#   'issue',
#   'let',
#   'us',
#   'know',
#   'still',
#   'seeing',
#   'happen'],
#  ['received',
#   'similar',
#   'error',
#   'issue',
#   'side',
#   'wrong',
#   'errormessage',
#   'security',
#   'token',
#   'included',
#   'request',
#   'invalid',
#   'errortype',
#   'unrecognizedclientexception',
#   'stacktrace',
#   'anonymous',
#   'end',
#   'requestid',
#   'garnaat',
#   '16',
#   '2015'],
#  ['particular',
#   'problem',
#   'seemed',
#   'go',
#   'away',
#   'night',
#   'getting',
#   'errormessage',
#   'access',
#   'key',
#   'id',
#   'provided',
#   'exist',
#   'records',
#   'errortype',
#   'invalidaccesskeyid',
#   'stacktrace',
#   'anonymous',
#   'end',
#   'requestid',
#   'think',
#   'issue',
#   'occasionally',
#   'delete',
#   'function',
#   'roles',
#   'policies',
#   'created',
#   'start',
#   'easy',
#   'thing',
#   'kappa',
#   'good',
#   'test',
#   'make',
#   'sure',
#   'configuration',
#   'actually',
#   'working',
#   'properly',
#   'however',
#   'role',
#   'gets',
#   'deleted',
#   'seems',
#   'like',
#   'sts',
#   'credentials',
#   'cached',
#   'somewhere',
#   'continue',
#   'used',
#   'execute',
#   'even',
#   'though',
#   'longer',
#   'valid',
#   'usually',
#   'waiting',
#   'hour',
#   'clears',
#   'although',
#   'latest',
#   'one',
#   'lasted',
#   'using',
#   'basic',
#   'workflow',
#   'since',
#   'released',
#   'never',
#   'changed',
#   'side',
#   'cause',
#   'mitch'],
#  ['seeing',
#   'function',
#   'well',
#   'simple',
#   'reads',
#   'data',
#   'checks',
#   'internet',
#   'site',
#   'writes',
#   'back',
#   'get',
#   'expiredtoken',
#   'provided',
#   'token',
#   'expired',
#   'message',
#   'code',
#   'time',
#   '11',
#   '2015',
#   'utc',
#   'statuscode',
#   '400',
#   'retryable',
#   'true',
#   'happens',
#   'infrequently',
#   'running',
#   'every',
#   '15',
#   'minutes',
#   'twice',
#   'day',
#   'concerned',
#   'use',
#   'mission',
#   'critical',
#   'work'],
#  ['resolved',
#   'getting',
#   'issue',
#   'java',
#   'web',
#   'service',
#   'running',
#   'tomcat',
#   'ebs',
#   'using',
#   'latest',
#   'libs'],
#  ['getting', 'issue', 'using', 'configuration', 'corvi42'],
#  ['still',
#   'get',
#   'error',
#   'expired',
#   'try',
#   'upload',
#   'bulk',
#   'data',
#   'like',
#   'multiple',
#   'folder',
#   'nearly',
#   'size',
#   '20gb',
#   'client',
#   'side',
#   'resolved',
#   'expiredtoken',
#   'provided',
#   'token',
#   'let',
#   'know',
#   'issue',
#   'could',
#   'ranjitha',
#   '2019',
#   'pm'],
#  ['run',
#   'python',
#   'code',
#   'package',
#   'dependencies',
#   '500mb',
#   'requirement',
#   'trigger',
#   'sagemaker',
#   'endpoint',
#   'get',
#   'predictions',
#   'easy',
#   'extra',
#   'processing',
#   'variable',
#   'importance',
#   'using',
#   'packages',
#   'xgboost',
#   'shap',
#   'able',
#   'hit',
#   'jupyter',
#   'notebook',
#   'want',
#   'replicate',
#   'thing',
#   '1',
#   'pandas',
#   'total',
#   'size',
#   'greater',
#   'unzipped',
#   'deployment',
#   '250',
#   'mb',
#   'hence',
#   'allowing',
#   'deploy',
#   'even',
#   'tried',
#   'function',
#   'cloud9',
#   'got',
#   'error',
#   'due',
#   'restrictions',
#   'also',
#   'layers',
#   'luck',
#   '2',
#   'way',
#   'big',
#   'bypassing',
#   'limitation',
#   'execution',
#   'would',
#   'calculations',
#   'return',
#   'output',
#   'back',
#   'tdoo7',
#   '2019',
#   'pm'],
#  ['global',
#   'accelerator',
#   'path',
#   'patterns',
#   'application',
#   'load',
#   'balancer',
#   'set',
#   'send',
#   'requests',
#   'via',
#   'one',
#   'alb',
#   'different',
#   'functions',
#   'based',
#   'added',
#   'seem',
#   'recognised',
#   'using',
#   'wondering',
#   'functionality',
#   'work',
#   'tried',
#   'seeing',
#   'could',
#   'add',
#   'additional',
#   'endpoint',
#   'groups',
#   'second',
#   'listener',
#   'port',
#   '80',
#   'listening',
#   'ideas',
#   'appreciated'],
#  ['yes',
#   'functionality',
#   'work',
#   'alb',
#   'behind',
#   'global',
#   'accelerator',
#   'allows',
#   'route',
#   'functions',
#   'based',
#   'http',
#   'request',
#   'method',
#   'header',
#   'path',
#   'pattern',
#   'query',
#   'string',
#   'one',
#   'condition',
#   'would',
#   'expected',
#   'source',
#   'ip',
#   'since',
#   'yet',
#   'preserve',
#   'able',
#   'describe',
#   'details',
#   'setup',
#   'us',
#   'get',
#   'bottom',
#   'say',
#   'patterns',
#   'recognized',
#   'exact',
#   'behavior',
#   'see',
#   'harvo'],
#  ['possible',
#   'access',
#   'edge',
#   'origin',
#   'request',
#   'event',
#   'see',
#   'payload',
#   'hostname',
#   'http',
#   'triggered',
#   'somebody',
#   'typed',
#   'browser',
#   'bar',
#   'vs',
#   'wildcard',
#   'alternate',
#   'domain',
#   'name',
#   'cname',
#   'say',
#   'need',
#   'alter',
#   'response',
#   'based',
#   'upon',
#   'value',
#   'requested'],
#  ['default',
#   '0',
#   'contains',
#   'hostname',
#   'distribution',
#   'origin',
#   'request',
#   'event',
#   'need',
#   'access',
#   'host',
#   'header',
#   'original',
#   'incoming',
#   'trigger',
#   'want',
#   'configure',
#   'cache',
#   'behavior',
#   'whitelist',
#   'forwarding',
#   'server',
#   'making',
#   'change',
#   'expose',
#   'instead'],
#  ['would',
#   'also',
#   'really',
#   'like',
#   'feature',
#   'proposed',
#   'solution',
#   'work',
#   'host',
#   'one',
#   'headers',
#   'whitelisted'],
#  ['arkadiyt',
#   'looks',
#   'like',
#   'working',
#   'origin',
#   'could',
#   'share',
#   'use',
#   'case',
#   'solved',
#   'host',
#   'header',
#   'allowed',
#   'whitelisted',
#   'available',
#   'request',
#   'event',
#   'abhishek'],
#  ['want',
#   'redirect',
#   'users',
#   'possible',
#   'viewer',
#   'event',
#   'prefer',
#   'origin',
#   'cached',
#   'right',
#   'work',
#   'around',
#   'creating',
#   'separate',
#   'distribution',
#   'request',
#   'always',
#   'redirects',
#   'seems',
#   'bit',
#   'hacky',
#   'rather',
#   'single'],
#  ['arkadiyt',
#   'sharing',
#   'use',
#   'case',
#   'host',
#   'header',
#   'whitelisting',
#   'available',
#   'yet',
#   'origin',
#   'workarounds',
#   'possible',
#   'let',
#   'keep',
#   'one',
#   'distribution',
#   'involves',
#   'setting',
#   'custom',
#   'instead',
#   'either',
#   'two',
#   'approaches',
#   'work',
#   'enable',
#   'static',
#   'website',
#   'hosting',
#   'configure',
#   'bucket',
#   'https',
#   'create',
#   'cname',
#   'record',
#   'points',
#   'option',
#   'using',
#   'access',
#   'identity',
#   'restrict',
#   'abhishek'],
#  ['primary',
#   'problem',
#   'overwrites',
#   'host',
#   'header',
#   'request',
#   'origin',
#   'able',
#   'workaround',
#   'using',
#   'combination',
#   'viewer',
#   'copy',
#   'another',
#   'like',
#   'event',
#   'context',
#   'callback',
#   'const',
#   '0',
#   'key',
#   'value',
#   'return',
#   'null',
#   'configure',
#   'whitelist',
#   'behaviour',
#   'way',
#   'also',
#   'takes',
#   'consideration',
#   'caching',
#   'passes',
#   'along',
#   'access',
#   'headers',
#   'requesthost'],
#  ['havah',
#   'overwrites',
#   'host',
#   'header',
#   'request',
#   'origin',
#   'domain',
#   'name',
#   'whitelisted',
#   'cache',
#   'behavior',
#   'whitelisting',
#   'access',
#   'unmodified',
#   'function',
#   'abhishek'],
#  ['also',
#   'need',
#   'use',
#   'case',
#   'single',
#   'page',
#   'react',
#   'app',
#   'bucket',
#   '10s',
#   'cnames',
#   'whitelist',
#   'host',
#   'name',
#   'headers',
#   'inject',
#   'opengraph',
#   'tags',
#   'html',
#   'depending',
#   'request',
#   'otherwise',
#   'serve',
#   'content',
#   'configured',
#   'private',
#   'accessible',
#   'code',
#   'could',
#   'per',
#   'browser',
#   'bots',
#   'like',
#   'facebook',
#   'crawler',
#   '27',
#   '2019',
#   'pm'],
#  ['validate',
#   'given',
#   'cloudwatch',
#   'events',
#   'scheduleexpression',
#   'valid',
#   'like',
#   'able',
#   'rate',
#   'cron',
#   'making',
#   'putrule',
#   'api',
#   'call',
#   'javascript',
#   'available',
#   'feature'],
#  ['net',
#   'trouble',
#   'referencing',
#   'core',
#   'library',
#   'playing',
#   'toolkit',
#   'created',
#   'example',
#   'function',
#   'uppercases',
#   'string',
#   'tested',
#   'good',
#   'want',
#   'create',
#   'method',
#   'use',
#   'code',
#   'simple',
#   'static',
#   'public',
#   'object',
#   'single',
#   'added',
#   'reference',
#   'project',
#   'looks',
#   'however',
#   'matter',
#   'tried',
#   'seem',
#   'class',
#   'went',
#   'console',
#   'app',
#   'problem',
#   'compared',
#   'settings',
#   'standalone',
#   'building',
#   'going',
#   'new',
#   'probably',
#   'stupid',
#   'grants',
#   '26',
#   '2019'],
#  ['found',
#   'ide',
#   'issue',
#   'even',
#   'though',
#   'intellisense',
#   'show',
#   'library',
#   'entered',
#   'using',
#   'class',
#   'members',
#   'still',
#   'compiled',
#   'worked',
#   'saved',
#   'project',
#   'exited',
#   'restart',
#   'tags',
#   'started',
#   'working'],
#  ['mounting',
#   'efs',
#   'file',
#   'systems',
#   'would',
#   'consider',
#   'possibility',
#   'mount',
#   'specific',
#   'system',
#   'within',
#   'function',
#   'way',
#   'functions',
#   'could',
#   'stream',
#   'large',
#   'amount',
#   'data'],
#  ['sylvain',
#   'perron',
#   'feedback',
#   'brought',
#   'comments',
#   'attention',
#   'service',
#   'team',
#   'evaluate',
#   'request',
#   'collaboration'],
#  ['sylvain',
#   'currently',
#   'need',
#   'use',
#   'intermediate',
#   'store',
#   'like',
#   'transfer',
#   'large',
#   'amounts',
#   'data',
#   'definitely',
#   'appreciate',
#   'feedback',
#   'looking',
#   'make',
#   'simpler'],
#  ['update',
#   'case',
#   'need',
#   'download',
#   'even',
#   'file',
#   'qc',
#   'checks',
#   'using',
#   'various',
#   'functions',
#   'efs',
#   'system',
#   'mounted',
#   'function',
#   'would',
#   'save',
#   'time',
#   'bandwidth',
#   'invocation',
#   'shatgupt',
#   '17',
#   '2016',
#   'specify',
#   'downloaded'],
#  ['would',
#   'like',
#   'use',
#   'toooo',
#   'sloowwwww',
#   'work',
#   'also',
#   'many',
#   'functionality',
#   'missing',
#   'partial',
#   'update',
#   'least',
#   'append',
#   'file',
#   'feature',
#   'want',
#   'request',
#   'easier',
#   'using',
#   'efs',
#   'waiting'],
#  ['given',
#   'package',
#   'size',
#   '50mb',
#   'space',
#   '512mb',
#   'lambdas',
#   'become',
#   'unusable',
#   'functions',
#   'need',
#   'disk',
#   'storage',
#   'example',
#   'use',
#   'precomputed',
#   'ml',
#   'model',
#   'files',
#   'get',
#   'pretty',
#   'large',
#   'like',
#   'rocksdb',
#   'cold',
#   'start',
#   'delays',
#   '512',
#   'mb',
#   'limits',
#   'copying',
#   'viable',
#   'solution',
#   'needs',
#   'essential',
#   'ability',
#   'attach',
#   'kind',
#   'larger',
#   'volume',
#   'love',
#   'want',
#   'see',
#   'successful',
#   'anyone',
#   'respond',
#   'plans',
#   'address',
#   'ayush',
#   'gupta',
#   '11',
#   '2016',
#   'pm'],
#  [],
#  ['people', 'asking', 'hacker', 'news'],
#  ['ml',
#   'computations',
#   'would',
#   'perfect',
#   'use',
#   'libraries',
#   'expect',
#   'grabbing',
#   'model',
#   'files',
#   'even',
#   'mounts',
#   'great'],
#  ['read', 'efs', 'would', 'enough', 'needs'],
#  ['feature',
#   'request',
#   'already',
#   'logged',
#   'appropriate',
#   'team',
#   'however',
#   'eta',
#   'available',
#   'keep',
#   'eye',
#   'blogs',
#   'stay',
#   'updated',
#   'latest',
#   'news',
#   'umair'],
#  ['efs', 'together', 'powerful', 'ml', 'web', 'services'],
#  ['essential',
#   'access',
#   'data',
#   'efs',
#   'important',
#   'bioinformatics',
#   'applications'],
#  ['updates',
#   'request',
#   'need',
#   'support',
#   'persistence',
#   'certain',
#   'stream',
#   'data',
#   'function',
#   'appreciate',
#   'comments',
#   'suryanittala',
#   '13',
#   '2017'],
#  ['great', 'lambdas', 'working', 'thousands', 'small', 'files'],
#  ['would',
#   'really',
#   'love',
#   'migrate',
#   'existing',
#   'legacy',
#   'file',
#   'processes',
#   'world',
#   'ample',
#   'storage',
#   'required',
#   'launching',
#   'ephemeral',
#   'instances',
#   'workloads',
#   'seems',
#   '2010'],
#  ['umair',
#   'update',
#   'eta',
#   'well',
#   'year',
#   'long',
#   'keep',
#   'eye',
#   'blogs',
#   'damian'],
#  ['would',
#   'helpful',
#   'us',
#   'since',
#   'sometimes',
#   'process',
#   'files',
#   '512mb',
#   'even',
#   'processing',
#   '250mb',
#   'hard',
#   'input',
#   'output',
#   'file',
#   'need',
#   'store'],
#  ['great', 'ml'],
#  ['using',
#   'image',
#   'document',
#   'processing',
#   'stopped',
#   'developing',
#   '512mb',
#   'temp',
#   'storage',
#   'limit',
#   'way',
#   'low',
#   'documents'],
#  [],
#  ['lots',
#   'use',
#   'cases',
#   'expands',
#   'capabilities',
#   'understand',
#   'challenges',
#   'mounting',
#   'making',
#   'index',
#   'file',
#   'system',
#   'available',
#   'short',
#   'period',
#   'time',
#   'could',
#   'utilized',
#   'efficiently',
#   'within',
#   'minute',
#   'frame',
#   'function',
#   'alloted',
#   'granted',
#   'many',
#   'applications',
#   'want',
#   'stored',
#   'locally',
#   'make',
#   'modifications',
#   'means',
#   'source',
#   'destination',
#   'size',
#   'total',
#   'needs',
#   'less',
#   '512mb',
#   'half',
#   'problem',
#   'multiple',
#   'times',
#   'one',
#   'step',
#   'would',
#   'removed',
#   'already',
#   'mounted',
#   'engineers',
#   'looking',
#   'suggest',
#   'thinking',
#   'idea',
#   'specialized',
#   'version',
#   'efs',
#   'specifically',
#   'limited',
#   'storage',
#   'sizes',
#   'say',
#   '20gb',
#   'limits',
#   'number',
#   'speak',
#   'everyone',
#   'need',
#   'primarily',
#   'duplicate',
#   'work',
#   'functions',
#   'persistent',
#   'files',
#   'across',
#   'well',
#   'provide',
#   'additional',
#   'drive',
#   'space',
#   'allotted',
#   'today'],
#  ['another',
#   'use',
#   'case',
#   'rendering',
#   'animations',
#   'using',
#   'spot',
#   'instances',
#   'spun',
#   'function',
#   'share',
#   'efs',
#   'setup',
#   'render',
#   'together',
#   'right',
#   'uploading',
#   'zip',
#   'file',
#   'triggers',
#   'new',
#   'servers',
#   'pull',
#   'object',
#   'process',
#   'would',
#   'greatly',
#   'streamlined',
#   'could',
#   'drop',
#   'directly',
#   'via'],
#  [],
#  ['year', 'half', 'passed', 'engineer', 'log', 'freezed', 'always'],
#  ['alias',
#   'dimension',
#   'available',
#   'according',
#   'documentation',
#   'https',
#   'access',
#   'looking',
#   'metrics',
#   'cloudwatch',
#   'despite',
#   'seeing',
#   'dimensions',
#   'doc',
#   'including',
#   'resource',
#   'executedversion',
#   'none',
#   'functions',
#   'attached',
#   'anyone',
#   'else',
#   'similar'],
#  ['bump', 'record'],
#  ['bump',
#   'anyone',
#   'else',
#   'experiencing',
#   'similar',
#   'sort',
#   'issue',
#   'want',
#   'get',
#   'look',
#   'dev',
#   'aliases',
#   'example'],
#  ['anyone',
#   'comment',
#   'docs',
#   'wrong',
#   'special',
#   'way',
#   'enable',
#   'dimension',
#   'cloudwatch'],
#  ['bump'],
#  ['update',
#   'contacted',
#   'support',
#   'apparently',
#   'docs',
#   'wrong',
#   'dimension'],
#  ['task',
#   'timed',
#   'first',
#   'invocations',
#   'works',
#   'got',
#   'collection',
#   'functions',
#   'serving',
#   'simple',
#   'crud',
#   'rest',
#   'api',
#   'via',
#   'gateway',
#   'leave',
#   'function',
#   'idle',
#   'awhile',
#   'deploy',
#   'timeout',
#   'return',
#   'internal',
#   'server',
#   'error',
#   'starts',
#   'working',
#   'fine',
#   'troubles',
#   'goes',
#   'logs',
#   'say',
#   'seconds',
#   'one',
#   'lambdas',
#   'exhibiting',
#   'behavior',
#   'getaccounts',
#   'async',
#   'event',
#   'context',
#   'callback',
#   'false',
#   'const',
#   'connection',
#   'dbconfig',
#   'try',
#   'results',
#   'await',
#   'executequery',
#   'accounts',
#   'statuscode',
#   '200',
#   'headers',
#   'responseheaders',
#   'body',
#   'catch',
#   'err',
#   '400',
#   'finally',
#   'conn',
#   'query',
#   'args',
#   'new',
#   'promise',
#   'resolve',
#   'reject',
#   'connerror',
#   'else',
#   'stackwalker',
#   '25',
#   '2019'],
#  ['using',
#   'extra',
#   'libaries',
#   'trying',
#   'use',
#   'libary',
#   'zbar',
#   'im',
#   'sure',
#   'would',
#   'go',
#   'packing',
#   'normally',
#   'install',
#   'yum',
#   'know',
#   'binaries',
#   'dont',
#   'see',
#   'get',
#   'repo',
#   'package'],
#  ['guidelines',
#   'building',
#   'packages',
#   'dependencies',
#   'likely',
#   'need',
#   'one',
#   'python',
#   'http',
#   'helps',
#   'vishal'],
#  ['trying',
#   'hard',
#   'get',
#   'zbar',
#   'working',
#   'function',
#   'error',
#   'getting',
#   'access',
#   'libzbar',
#   'libray',
#   'unable',
#   'import',
#   'module',
#   'openshared',
#   'object',
#   'file',
#   'directory',
#   'got',
#   'docker',
#   'image',
#   'placed',
#   'bin',
#   'included',
#   'zip',
#   'package',
#   'code',
#   'added',
#   'two',
#   'lines',
#   'let',
#   'know',
#   'look',
#   'still',
#   'anyone'],
#  ['ever', 'figure', 'also', 'interested'],
#  ['possible',
#   'add',
#   'shut',
#   'callback',
#   'got',
#   'reply',
#   'awssupport',
#   'twitter',
#   'saying',
#   'always',
#   'post',
#   'feedback',
#   'new',
#   'bear',
#   'already',
#   'asked',
#   'imagine',
#   'feature',
#   'describe',
#   'easy',
#   'implement',
#   'believe',
#   'might',
#   'good',
#   'reason',
#   'implemented',
#   'yet',
#   'still',
#   'hurt',
#   'ask',
#   'would',
#   'optionally',
#   'call',
#   'function',
#   'one',
#   'last',
#   'time',
#   'instance',
#   'eg',
#   'enable',
#   'us',
#   'resolve',
#   'known',
#   'issue',
#   'db',
#   'connection',
#   'management',
#   'talking',
#   'case',
#   'establish',
#   'documentdb',
#   'remains',
#   'open',
#   'even',
#   'though',
#   'close',
#   'active',
#   'thus',
#   'removing',
#   'possibility',
#   'max',
#   'number',
#   'connections',
#   'towards',
#   'separate',
#   'simple',
#   'param',
#   'context',
#   'argument',
#   'also',
#   'suffice',
#   'aware',
#   'alternative',
#   'approaches',
#   'like',
#   'setting',
#   'single',
#   'point',
#   'failure',
#   'manage',
#   'seems',
#   'bit',
#   'unnecessary',
#   'say',
#   'serverful',
#   'happy',
#   'hear',
#   'others',
#   'think',
#   'specific',
#   'situation',
#   'correct',
#   'wrong',
#   'anything',
#   'glad',
#   'learn'],
#  ['authorizer',
#   'function',
#   'logging',
#   'cloudwatch',
#   'greetings',
#   'full',
#   'disclosure',
#   'still',
#   'new',
#   'first',
#   'project',
#   'creating',
#   'websocket',
#   'connection',
#   'website',
#   'dynamodb',
#   'table',
#   'inasmuch',
#   'created',
#   'tables',
#   'api',
#   'supporting',
#   'functions',
#   'everything',
#   'working',
#   'great',
#   'added',
#   'js',
#   'lamba',
#   'node',
#   'peculiar',
#   'occurring',
#   'within',
#   'using',
#   'simple',
#   'statements',
#   'debug',
#   'unauthorized',
#   'condition',
#   'test',
#   'logs',
#   'appear',
#   'however',
#   'attempt',
#   'make',
#   'connect',
#   'disconnect',
#   'routing',
#   'work',
#   'normally',
#   'output',
#   'text',
#   'fails',
#   'send',
#   'yet',
#   'click',
#   'button',
#   'sent',
#   'thinking',
#   'might',
#   'log',
#   'settings',
#   'able',
#   'locate',
#   'anything',
#   'entry',
#   'developer',
#   'allow',
#   'createloggroup',
#   'createlogstream',
#   'describeloggroups',
#   'describelogstreams',
#   'putlogevents',
#   'getlogevents',
#   'filterlogevents',
#   'global',
#   'setting',
#   'figure',
#   'apis',
#   'except',
#   'anyone',
#   'run',
#   'like',
#   'fix',
#   'give',
#   'hint',
#   'look',
#   'issue'],
#  ['answer',
#   'question',
#   'problem',
#   'indeed',
#   'due',
#   'unauthorized',
#   'mentioned',
#   'thought',
#   'nothing',
#   'setup',
#   'authorizer',
#   'set',
#   'event',
#   'payload',
#   'custom',
#   'header',
#   'neglected',
#   'browser',
#   'session',
#   'according',
#   'documentation',
#   'https',
#   'section',
#   '9b',
#   'api',
#   'gateway',
#   'throw',
#   '401',
#   'error',
#   'without',
#   'even',
#   'executing',
#   'function',
#   'source']]

# %% [markdown]
# ### Write to the data.csv file

# %%
with open('C:\\Users\\Aruna\\Documents\\ACMS-IID\\Code\\Data Cleaning\\TestData.csv', 'a', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    # writer.writerow(['label', 'description'])
    for item in cleantext:
        if len(item) > 0:
            writer.writerow([title[7], item])

# %%
len(cleantext)
# Out:
# 91
