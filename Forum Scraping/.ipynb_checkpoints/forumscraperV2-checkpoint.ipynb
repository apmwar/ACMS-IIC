# %%
# import necessary libraries

import requests
from bs4 import BeautifulSoup
import csv
import time

# %%
# initialise global variables to store the scraped information

tid = []               # contains all the thread IDs 
messages = []          # stores all the message contents
subjects = []          # stores the subjects of the messages

# %%
# function to connect to the given forum ID, retrieve all the threads present within that forum and store it in tid

def connect(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36',
    }
    res = requests.get(url, headers=headers)
    res.raise_for_status()
    
    soup = BeautifulSoup(res.text, 'html.parser')
    soup.prettify()

    # all threadIDs have the following id
    
    hrefs = soup.find_all("a", {"id": "jive-thread-0"})

    for href in hrefs:
        href = str(href)
        href = href.split('href="')[1].split("&")[0]
        # href of form threads.jspa?threadID=xxx
        tid.append(href)
    return tid

# %%
# for each thread ID, fetches the messages present within thread

def fetch(url, fname):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36',
    }
    res = requests.get(url, headers=headers)
    res.raise_for_status()
    
    soup = BeautifulSoup(res.text, 'html.parser')
    soup.prettify()
    
    # all messages have the following subject class
    
    subs = soup.find_all("span", {"class": "jive-subject"})
    
    for line in subs:
        subjects.append(line.text.strip())
    
    # all messages have the following body class
    
    msgs = soup.find_all("div", {"class": "jive-message-body"})
    
    for line in msgs:
        msg = line.text.strip()
        messages.append(msg)
        
        with open(fname + '.tsv', 'w', encoding='utf-8') as tsvfile:
            writer = csv.writer(tsvfile, delimiter='\t')
            writer.writerow(["label", "description"])
            for i, j in zip(subjects, messages):
                writer.writerow([fname, i + "\n" + j])

# %%
# code snippet to fetch all the threadIDs for given service

id = 24                    # target forumID
limit = 16008                 # total number of threads
pname = "Amazon S31"              # target product name

i = 14300

while i <= limit:
    url = "https://forums.aws.amazon.com/forum.jspa?forumID="+str(id)+"&start="+str(i)
    tid = connect(url)
    i = i + 25
    print("Fetched " + str(i) + " threads")
# Out:
# Fetched 14325 threads
# Fetched 14350 threads
# Fetched 14375 threads
# Fetched 14400 threads
# Fetched 14425 threads
# Fetched 14450 threads
# Fetched 14475 threads
# Fetched 14500 threads
# Fetched 14525 threads
# Fetched 14550 threads
# Fetched 14575 threads
# Fetched 14600 threads
# Fetched 14625 threads
# Fetched 14650 threads
# Fetched 14675 threads
# Fetched 14700 threads
# Fetched 14725 threads
# Fetched 14750 threads
# Fetched 14775 threads
# Fetched 14800 threads
# Fetched 14825 threads
# Fetched 14850 threads
# Fetched 14875 threads
# Fetched 14900 threads
# Fetched 14925 threads
# Fetched 14950 threads
# Fetched 14975 threads
# Fetched 15000 threads
# Fetched 15025 threads
# Fetched 15050 threads
# Fetched 15075 threads
# Fetched 15100 threads
# Fetched 15125 threads
# Fetched 15150 threads
# Fetched 15175 threads
# Fetched 15200 threads
# Fetched 15225 threads
# Fetched 15250 threads
# Fetched 15275 threads
# Fetched 15300 threads
# Fetched 15325 threads
# Fetched 15350 threads
# Fetched 15375 threads
# Fetched 15400 threads
# Fetched 15425 threads
# Fetched 15450 threads
# Fetched 15475 threads
# Fetched 15500 threads
# Fetched 15525 threads
# Fetched 15550 threads
# Fetched 15575 threads
# Fetched 15600 threads
# Fetched 15625 threads
# Fetched 15650 threads
# Fetched 15675 threads
# Fetched 15700 threads
# Fetched 15725 threads
# Fetched 15750 threads
# Fetched 15775 threads
# Fetched 15800 threads
# Fetched 15825 threads
# Fetched 15850 threads
# Fetched 15875 threads
# Fetched 15900 threads
# Fetched 15925 threads
# Fetched 15950 threads
# Fetched 15975 threads
# Fetched 16000 threads
# Fetched 16025 threads

# %%
print(tid)
# Out:
# ['thread.jspa?threadID=18791', 'thread.jspa?threadID=18782', 'thread.jspa?threadID=18743', 'thread.jspa?threadID=18719', 'thread.jspa?threadID=17703', 'thread.jspa?threadID=18723', 'thread.jspa?threadID=18729', 'thread.jspa?threadID=10594', 'thread.jspa?threadID=18721', 'thread.jspa?threadID=18713', 'thread.jspa?threadID=18688', 'thread.jspa?threadID=18687', 'thread.jspa?threadID=18694', 'thread.jspa?threadID=18689', 'thread.jspa?threadID=18685', 'thread.jspa?threadID=18611', 'thread.jspa?threadID=18669', 'thread.jspa?threadID=18676', 'thread.jspa?threadID=18650', 'thread.jspa?threadID=18311', 'thread.jspa?threadID=14269', 'thread.jspa?threadID=18634', 'thread.jspa?threadID=18651', 'thread.jspa?threadID=13289', 'thread.jspa?threadID=18626', 'thread.jspa?threadID=18623', 'thread.jspa?threadID=18621', 'thread.jspa?threadID=18622', 'thread.jspa?threadID=18624', 'thread.jspa?threadID=18577', 'thread.jspa?threadID=15905', 'thread.jspa?threadID=18580', 'thread.jspa?threadID=18596', 'thread.jspa?threadID=18593', 'thread.jspa?threadID=18587', 'thread.jspa?threadID=18143', 'thread.jspa?threadID=18562', 'thread.jspa?threadID=18564', 'thread.jspa?threadID=18545', 'thread.jspa?threadID=18566', 'thread.jspa?threadID=18560', 'thread.jspa?threadID=14065', 'thread.jspa?threadID=18464', 'thread.jspa?threadID=18538', 'thread.jspa?threadID=18535', 'thread.jspa?threadID=18498', 'thread.jspa?threadID=18516', 'thread.jspa?threadID=18509', 'thread.jspa?threadID=16894', 'thread.jspa?threadID=18419', 'thread.jspa?threadID=18522', 'thread.jspa?threadID=18514', 'thread.jspa?threadID=18517', 'thread.jspa?threadID=18297', 'thread.jspa?threadID=18491', 'thread.jspa?threadID=18482', 'thread.jspa?threadID=18499', 'thread.jspa?threadID=18457', 'thread.jspa?threadID=18487', 'thread.jspa?threadID=18480', 'thread.jspa?threadID=18481', 'thread.jspa?threadID=18456', 'thread.jspa?threadID=18460', 'thread.jspa?threadID=18437', 'thread.jspa?threadID=18436', 'thread.jspa?threadID=18429', 'thread.jspa?threadID=18418', 'thread.jspa?threadID=18435', 'thread.jspa?threadID=18431', 'thread.jspa?threadID=18422', 'thread.jspa?threadID=18417', 'thread.jspa?threadID=18410', 'thread.jspa?threadID=18190', 'thread.jspa?threadID=18397', 'thread.jspa?threadID=17947', 'thread.jspa?threadID=17905', 'thread.jspa?threadID=17954', 'thread.jspa?threadID=18401', 'thread.jspa?threadID=18382', 'thread.jspa?threadID=18400', 'thread.jspa?threadID=18338', 'thread.jspa?threadID=18371', 'thread.jspa?threadID=18375', 'thread.jspa?threadID=17360', 'thread.jspa?threadID=18302', 'thread.jspa?threadID=18339', 'thread.jspa?threadID=18348', 'thread.jspa?threadID=17920', 'thread.jspa?threadID=18334', 'thread.jspa?threadID=18330', 'thread.jspa?threadID=14117', 'thread.jspa?threadID=18321', 'thread.jspa?threadID=18322', 'thread.jspa?threadID=18314', 'thread.jspa?threadID=18319', 'thread.jspa?threadID=18288', 'thread.jspa?threadID=18285', 'thread.jspa?threadID=18242', 'thread.jspa?threadID=18274', 'thread.jspa?threadID=18270', 'thread.jspa?threadID=17964', 'thread.jspa?threadID=18248', 'thread.jspa?threadID=18222', 'thread.jspa?threadID=18227', 'thread.jspa?threadID=18234', 'thread.jspa?threadID=17989', 'thread.jspa?threadID=18226', 'thread.jspa?threadID=18223', 'thread.jspa?threadID=18097', 'thread.jspa?threadID=18219', 'thread.jspa?threadID=18189', 'thread.jspa?threadID=18150', 'thread.jspa?threadID=18209', 'thread.jspa?threadID=18216', 'thread.jspa?threadID=18181', 'thread.jspa?threadID=10857', 'thread.jspa?threadID=18169', 'thread.jspa?threadID=18183', 'thread.jspa?threadID=18177', 'thread.jspa?threadID=18164', 'thread.jspa?threadID=18165', 'thread.jspa?threadID=18166', 'thread.jspa?threadID=18142', 'thread.jspa?threadID=18138', 'thread.jspa?threadID=18139', 'thread.jspa?threadID=18135', 'thread.jspa?threadID=10271', 'thread.jspa?threadID=18065', 'thread.jspa?threadID=18115', 'thread.jspa?threadID=18112', 'thread.jspa?threadID=9902', 'thread.jspa?threadID=17972', 'thread.jspa?threadID=12050', 'thread.js ...

# %%
# code snippet to fetch all the message for the corresponding threadID and store in tsv

i = 0

for i in range (0, len(tid)):
        try:
            print("Processing thread #" + str(i))
            fetch("https://forums.aws.amazon.com/" + tid[i], pname)
        except:
            time.sleep(5)
            i = i - 1
        i += 1
# Out:
# Processing thread #0
# Processing thread #1
# Processing thread #2
# Processing thread #3
# Processing thread #4
# Processing thread #5
# Processing thread #6
# Processing thread #7
# Processing thread #8
# Processing thread #9
# Processing thread #10
# Processing thread #11
# Processing thread #12
# Processing thread #13
# Processing thread #14
# Processing thread #15
# Processing thread #16
# Processing thread #17
# Processing thread #18
# Processing thread #19
# Processing thread #20
# Processing thread #21
# Processing thread #22
# Processing thread #23
# Processing thread #24
# Processing thread #25
# Processing thread #26
# Processing thread #27
# Processing thread #28
# Processing thread #29
# Processing thread #30
# Processing thread #31
# Processing thread #32
# Processing thread #33
# Processing thread #34
# Processing thread #35
# Processing thread #36
# Processing thread #37
# Processing thread #38
# Processing thread #39
# Processing thread #40
# Processing thread #41
# Processing thread #42
# Processing thread #43
# Processing thread #44
# Processing thread #45
# Processing thread #46
# Processing thread #47
# Processing thread #48
# Processing thread #49
# Processing thread #50
# Processing thread #51
# Processing thread #52
# Processing thread #53
# Processing thread #54
# Processing thread #55
# Processing thread #56
# Processing thread #57
# Processing thread #58
# Processing thread #59
# Processing thread #60
# Processing thread #61
# Processing thread #62
# Processing thread #63
# Processing thread #64
# Processing thread #65
# Processing thread #66
# Processing thread #67
# Processing thread #68
# Processing thread #69
# Processing thread #70
# Processing thread #71
# Processing thread #72
# Processing thread #73
# Processing thread #74
# Processing thread #75
# Processing thread #76
# Processing thread #77
# Processing thread #78
# Processing thread #79
# Processing thread #80
# Processing thread #81
# Processing thread #82
# Processing thread #83
# Processing thread #84
# Processing thread #85
# Processing thread #86
# Processing thread #87
# Processing thread #88
# Processing thread #89
# Processing thread #90
# Processing thread #91
# Processing thread #92
# Processing thread #93
# Processing thread #94
# Processing thread #95
# Processing thread #96
# Processing thread #97
# Processing thread #98
# Processing thread #99
# Processing thread #100
# Processing thread #101
# Processing thread #102
# Processing thread #103
# Processing thread #104
# Processing thread #105
# Processing thread #106
# Processing thread #107
# Processing thread #108
# Processing thread #109
# Processing thread #110
# Processing thread #111
# Processing thread #112
# Processing thread #113
# Processing thread #114
# Processing thread #115
# Processing thread #116
# Processing thread #117
# Processing thread #118
# Processing thread #119
# Processing thread #120
# Processing thread #121
# Processing thread #122
# Processing thread #123
# Processing thread #124
# Processing thread #125
# Processing thread #126
# Processing thread #127
# Processing thread #128
# Processing thread #129
# Processing thread #130
# Processing thread #131
# Processing thread #132
# Processing thread #133
# Processing thread #134
# Processing thread #135
# Processing thread #136
# Processing thread #137
# Processing thread #138
# Processing thread #139
# Processing thread #140
# Processing thread #141
# Processing thread #142
# Processing thread #143
# Processing thread #144
# Processing thread #145
# Processing thread #146
# Processing thread #147
# Processing thread #148
# Processing thread #149
# Processing thread #150
# Processing thread #151
# Processing thread #152
# Processing thread #153
# Processing thread #154
# Processing thread #155
# Processing thread #156
# Processing thread #157
# Processing thread #158
# Processing thread #159
# Processing thread #160
# Processing thread #161
# Processing thread #162
# Processing thread #163
# Processing thread #164
# Processing thread #165
# Processing thread #166
# Processing thread #167
# Processing thread #168
# Processing thread #169
# Processing thread #170
# Processing thread #171
# Processing thread #172
# Processing thread #173
# Processing thread #174
# Processing thread #175
# Processing thread #176
# Processing thread #177
# Processing thread #178
# Processing thread #179
# Processing thread #180
# Processing thread #181
# Processing thread #182
# Processing thread #183
# Processing thread #184
# Processing thread #185
# Processing thread #186
# Processing thread #187
# Processing thread #188
# Processing thread #189
# Processing thread #190
# Processing thread #191
# Processing thread #192
# Processing thread #193
# Processing thread #194
# Processing thread #195
# Processing thread #196
# Processing thread #197
# Processing thread #198
# Processing thread #199
# Processing thread #200
# Processing thread #201
# Processing thread #202
# Processing thread #203
# Processing thread #204
# Processing thread #205
# Processing thread #206
# Processing thread #207
# Processing thread #208
# Processing thread #209
# Processing thread #210
# Processing thread #211
# Processing thread #212
# Processing thread #213
# Processing thread #214
# Processing thread #215
# Processing thread #216
# Processing thread #217
# Processing thread #218
# Processing thread #219
# Processing thread #220
# Processing thread #221
# Processing thread #222
# Processing thread #223
# Processing thread #224
# Processing thread #225
# Processing thread #226
# Processing thread #227
# Processing thread #228
# Processing thread #229
# Processing thread #230
# Processing thread #231
# Processing thread #232
# Processing thread #233
# Processing thread #234
# Processing thread #235
# Processing thread #236
# Processing thread #237
# Processing thread #238
# Processing thread #239
# Processing thread #240
# Processing thread #241
# Processing thread #242
# Processing thread #243
# Processing thread #244
# Processing thread #245
# Processing thread #246
# Processing thread #247
# Processing thread #248
# Processing thread #249
# Processing thread #250
# Processing thread #251
# Processing thread #252
# Processing thread #253
# Processing thread #254
# Processing thread #255
# Processing thread #256
# Processing thread #257
# Processing thread #258
# Processing thread #259
# Processing thread #260
# Processing thread #261
# Processing thread #262
# Processing thread #263
# Processing thread #264
# Processing thread #265
# Processing thread #266
# Processing thread #267
# Processing thread #268
# Processing thread #269
# Processing thread #270
# Processing thread #271
# Processing thread #272
# Processing thread #273
# Processing thread #274
# Processing thread #275
# Processing thread #276
# Processing thread #277
# Processing thread #278
# Processing thread #279
# Processing thread #280
# Processing thread #281
# Processing thread #282
# Processing thread #283
# Processing thread #284
# Processing thread #285
# Processing thread #286
# Processing thread #287
# Processing thread #288
# Processing thread #289
# Processing thread #290
# Processing thread #291
# Processing thread #292
# Processing thread #293
# Processing thread #294
# Processing thread #295
# Processing thread #296
# Processing thread #297
# Processing thread #298
# Processing thread #299
# Processing thread #300
# Processing thread #301
# Processing thread #302
# Processing thread #303
# Processing thread #304
# Processing thread #305
# Processing thread #306
# Processing thread #307
# Processing thread #308
# Processing thread #309
# Processing thread #310
# Processing thread #311
# Processing thread #312
# Processing thread #313
# Processing thread #314
# Processing thread #315
# Processing thread #316
# Processing thread #317
# Processing thread #318
# Processing thread #319
# Processing thread #320
# Processing thread #321
# Processing thread #322
# Processing thread #323
# Processing thread #324
# Processing thread #325
# Processing thread #326
# Processing thread #327
# Processing thread #328
# Processing thread #329
# Processing thread #330
# Processing thread #331
# Processing thread #332
# Processing thread #333
# Processing thread #334
# Processing thread #335
# Processing thread #336
# Processing thread #337
# Processing thread #338
# Processing thread #339
# Processing thread #340
# Processing thread #341
# Processing thread #342
# Processing thread #343
# Processing thread #344
# Processing thread #345
# Processing thread #346
# Processing thread #347
# Processing thread #348
# Processing thread #349
# Processing thread #350
# Processing thread #351
# Processing thread #352
# Processing thread #353
# Processing thread #354
# Processing thread #355
# Processing thread #356
# Processing thread #357
# Processing thread #358
# Processing thread #359
# Processing thread #360
# Processing thread #361
# Processing thread #362
# Processing thread #363
# Processing thread #364
# Processing thread #365
# Processing thread #366
# Processing thread #367
# Processing thread #368
# Processing thread #369
# Processing thread #370
# Processing thread #371
# Processing thread #372
# Processing thread #373
# Processing thread #374
# Processing thread #375
# Processing thread #376
# Processing thread #377
# Processing thread #378
# Processing thread #379
# Processing thread #380
# Processing thread #381
# Processing thread #382
# Processing thread #383
# Processing thread #384
# Processing thread #385
# Processing thread #386
# Processing thread #387
# Processing thread #388
# Processing thread #389
# Processing thread #390
# Processing thread #391
# Processing thread #392
# Processing thread #393
# Processing thread #394
# Processing thread #395
# Processing thread #396
# Processing thread #397
# Processing thread #398
# Processing thread #399
# Processing thread #400
# Processing thread #401
# Processing thread #402
# Processing thread #403
# Processing thread #404
# Processing thread #405
# Processing thread #406
# Processing thread #407
# Processing thread #408
# Processing thread #409
# Processing thread #410
# Processing thread #411
# Processing thread #412
# Processing thread #413
# Processing thread #414
# Processing thread #415
# Processing thread #416
# Processing thread #417
# Processing thread #418
# Processing thread #419
# Processing thread #420
# Processing thread #421
# Processing thread #422
# Processing thread #423
# Processing thread #424
# Processing thread #425
# Processing thread #426
# Processing thread #427
# Processing thread #428
# Processing thread #429
# Processing thread #430
# Processing thread #431
# Processing thread #432
# Processing thread #433
# Processing thread #434
# Processing thread #435
# Processing thread #436
# Processing thread #437
# Processing thread #438
# Processing thread #439
# Processing thread #440
# Processing thread #441
# Processing thread #442
# Processing thread #443
# Processing thread #444
# Processing thread #445
# Processing thread #446
# Processing thread #447
# Processing thread #448
# Processing thread #449
# Processing thread #450
# Processing thread #451
# Processing thread #452
# Processing thread #453
# Processing thread #454
# Processing thread #455
# Processing thread #456
# Processing thread #457
# Processing thread #458
# Processing thread #459
# Processing thread #460
# Processing thread #461
# Processing thread #462
# Processing thread #463
# Processing thread #464
# Processing thread #465
# Processing thread #466
# Processing thread #467
# Processing thread #468
# Processing thread #469
# Processing thread #470
# Processing thread #471
# Processing thread #472
# Processing thread #473
# Processing thread #474
# Processing thread #475
# Processing thread #476
# Processing thread #477
# Processing thread #478
# Processing thread #479
# Processing thread #480
# Processing thread #481
# Processing thread #482
# Processing thread #483
# Processing thread #484
# Processing thread #485
# Processing thread #486
# Processing thread #487
# Processing thread #488
# Processing thread #489
# Processing thread #490
# Processing thread #491
# Processing thread #492
# Processing thread #493
# Processing thread #494
# Processing thread #495
# Processing thread #496
# Processing thread #497
# Processing thread #498
# Processing thread #499
# Processing thread #500
# Processing thread #501
# Processing thread #502
# Processing thread #503
# Processing thread #504
# Processing thread #505
# Processing thread #506
# Processing thread #507
# Processing thread #508
# Processing thread #509
# Processing thread #510
# Processing thread #511
# Processing thread #512
# Processing thread #513
# Processing thread #514
# Processing thread #515
# Processing thread #516
# Processing thread #517
# Processing thread #518
# Processing thread #519
# Processing thread #520
# Processing thread #521
# Processing thread #522
# Processing thread #523
# Processing thread #524
# Processing thread #525
# Processing thread #526
# Processing thread #527
# Processing thread #528
# Processing thread #529
# Processing thread #530
# Processing thread #531
# Processing thread #532
# Processing thread #533
# Processing thread #534
# Processing thread #535
# Processing thread #536
# Processing thread #537
# Processing thread #538
# Processing thread #539
# Processing thread #540
# Processing thread #541
# Processing thread #542
# Processing thread #543
# Processing thread #544
# Processing thread #545
# Processing thread #546
# Processing thread #547
# Processing thread #548
# Processing thread #549
# Processing thread #550
# Processing thread #551
# Processing thread #552
# Processing thread #553
# Processing thread #554
# Processing thread #555
# Processing thread #556
# Processing thread #557
# Processing thread #558
# Processing thread #559
# Processing thread #560
# Processing thread #561
# Processing thread #562
# Processing thread #563
# Processing thread #564
# Processing thread #565
# Processing thread #566
# Processing thread #567
# Processing thread #568
# Processing thread #569
# Processing thread #570
# Processing thread #571
# Processing thread #572
# Processing thread #573
# Processing thread #574
# Processing thread #575
# Processing thread #576
# Processing thread #577
# Processing thread #578
# Processing thread #579
# Processing thread #580
# Processing thread #581
# Processing thread #582
# Processing thread #583
# Processing thread #584
# Processing thread #585
# Processing thread #586
# Processing thread #587
# Processing thread #588
# Processing thread #589
# Processing thread #590
# Processing thread #591
# Processing thread #592
# Processing thread #593
# Processing thread #594
# Processing thread #595
# Processing thread #596
# Processing thread #597
# Processing thread #598
# Processing thread #599
# Processing thread #600
# Processing thread #601
# Processing thread #602
# Processing thread #603
# Processing thread #604
# Processing thread #605
# Processing thread #606
# Processing thread #607
# Processing thread #608
# Processing thread #609
# Processing thread #610
# Processing thread #611
# Processing thread #612
# Processing thread #613
# Processing thread #614
# Processing thread #615
# Processing thread #616
# Processing thread #617
# Processing thread #618
# Processing thread #619
# Processing thread #620
# Processing thread #621
# Processing thread #622
# Processing thread #623
# Processing thread #624
# Processing thread #625
# Processing thread #626
# Processing thread #627
# Processing thread #628
# Processing thread #629
# Processing thread #630
# Processing thread #631
# Processing thread #632
# Processing thread #633
# Processing thread #634
# Processing thread #635
# Processing thread #636
# Processing thread #637
# Processing thread #638
# Processing thread #639
# Processing thread #640
# Processing thread #641
# Processing thread #642
# Processing thread #643
# Processing thread #644
# Processing thread #645
# Processing thread #646
# Processing thread #647
# Processing thread #648
# Processing thread #649
# Processing thread #650
# Processing thread #651
# Processing thread #652
# Processing thread #653
# Processing thread #654
# Processing thread #655
# Processing thread #656
# Processing thread #657
# Processing thread #658
# Processing thread #659
# Processing thread #660
# Processing thread #661
# Processing thread #662
# Processing thread #663
# Processing thread #664
# Processing thread #665
# Processing thread #666
# Processing thread #667
# Processing thread #668
# Processing thread #669
# Processing thread #670
# Processing thread #671
# Processing thread #672
# Processing thread #673
# Processing thread #674
# Processing thread #675
# Processing thread #676
# Processing thread #677
# Processing thread #678
# Processing thread #679
# Processing thread #680
# Processing thread #681
# Processing thread #682
# Processing thread #683
# Processing thread #684
# Processing thread #685
# Processing thread #686
# Processing thread #687
# Processing thread #688
# Processing thread #689
# Processing thread #690
# Processing thread #691
# Processing thread #692
# Processing thread #693
# Processing thread #694
# Processing thread #695
# Processing thread #696
# Processing thread #697
# Processing thread #698
# Processing thread #699
# Processing thread #700
# Processing thread #701
# Processing thread #702
# Processing thread #703
# Processing thread #704
# Processing thread #705
# Processing thread #706
# Processing thread #707
# Processing thread #708
# Processing thread #709
# Processing thread #710
# Processing thread #711
# Processing thread #712
# Processing thread #713
# Processing thread #714
# Processing thread #715
# Processing thread #716
# Processing thread #717
# Processing thread #718
# Processing thread #719
# Processing thread #720
# Processing thread #721
# Processing thread #722
# Processing thread #723
# Processing thread #724
# Processing thread #725
# Processing thread #726
# Processing thread #727
# Processing thread #728
# Processing thread #729
# Processing thread #730
# Processing thread #731
# Processing thread #732
# Processing thread #733
# Processing thread #734
# Processing thread #735
# Processing thread #736
# Processing thread #737
# Processing thread #738
# Processing thread #739
# Processing thread #740
# Processing thread #741
# Processing thread #742
# Processing thread #743
# Processing thread #744
# Processing thread #745
# Processing thread #746
# Processing thread #747
# Processing thread #748
# Processing thread #749
# Processing thread #750
# Processing thread #751
# Processing thread #752
# Processing thread #753
# Processing thread #754
# Processing thread #755
# Processing thread #756
# Processing thread #757
# Processing thread #758
# Processing thread #759
# Processing thread #760
# Processing thread #761
# Processing thread #762
# Processing thread #763
# Processing thread #764
# Processing thread #765
# Processing thread #766
# Processing thread #767
# Processing thread #768
# Processing thread #769
# Processing thread #770
# Processing thread #771
# Processing thread #772
# Processing thread #773
# Processing thread #774
# Processing thread #775
# Processing thread #776
# Processing thread #777
# Processing thread #778
# Processing thread #779
# Processing thread #780
# Processing thread #781
# Processing thread #782
# Processing thread #783
# Processing thread #784
# Processing thread #785
# Processing thread #786
# Processing thread #787
# Processing thread #788
# Processing thread #789
# Processing thread #790
# Processing thread #791
# Processing thread #792
# Processing thread #793
# Processing thread #794
# Processing thread #795
# Processing thread #796
# Processing thread #797
# Processing thread #798
# Processing thread #799
# Processing thread #800
# Processing thread #801
# Processing thread #802
# Processing thread #803
# Processing thread #804
# Processing thread #805
# Processing thread #806
# Processing thread #807
# Processing thread #808
# Processing thread #809
# Processing thread #810
# Processing thread #811
# Processing thread #812
# Processing thread #813
# Processing thread #814
# Processing thread #815
# Processing thread #816
# Processing thread #817
# Processing thread #818
# Processing thread #819
# Processing thread #820
# Processing thread #821
# Processing thread #822
# Processing thread #823
# Processing thread #824
# Processing thread #825
# Processing thread #826
# Processing thread #827
# Processing thread #828
# Processing thread #829
# Processing thread #830
# Processing thread #831
# Processing thread #832
# Processing thread #833
# Processing thread #834
# Processing thread #835
# Processing thread #836
# Processing thread #837
# Processing thread #838
# Processing thread #839
# Processing thread #840
# Processing thread #841
# Processing thread #842
# Processing thread #843
# Processing thread #844
# Processing thread #845
# Processing thread #846
# Processing thread #847
# Processing thread #848
# Processing thread #849
# Processing thread #850
# Processing thread #851
# Processing thread #852
# Processing thread #853
# Processing thread #854
# Processing thread #855
# Processing thread #856
# Processing thread #857
# Processing thread #858
# Processing thread #859
# Processing thread #860
# Processing thread #861
# Processing thread #862
# Processing thread #863
# Processing thread #864
# Processing thread #865
# Processing thread #866
# Processing thread #867
# Processing thread #868
# Processing thread #869
# Processing thread #870
# Processing thread #871
# Processing thread #872
# Processing thread #873
# Processing thread #874
# Processing thread #875
# Processing thread #876
# Processing thread #877
# Processing thread #878
# Processing thread #879
# Processing thread #880
# Processing thread #881
# Processing thread #882
# Processing thread #883
# Processing thread #884
# Processing thread #885
# Processing thread #886
# Processing thread #887
# Processing thread #888
# Processing thread #889
# Processing thread #890
# Processing thread #891
# Processing thread #892
# Processing thread #893
# Processing thread #894
# Processing thread #895
# Processing thread #896
# Processing thread #897
# Processing thread #898
# Processing thread #899
# Processing thread #900
# Processing thread #901
# Processing thread #902
# Processing thread #903
# Processing thread #904
# Processing thread #905
# Processing thread #906
# Processing thread #907
# Processing thread #908
# Processing thread #909
# Processing thread #910
# Processing thread #911
# Processing thread #912
# Processing thread #913
# Processing thread #914
# Processing thread #915
# Processing thread #916
# Processing thread #917
# Processing thread #918
# Processing thread #919
# Processing thread #920
# Processing thread #921
# Processing thread #922
# Processing thread #923
# Processing thread #924
# Processing thread #925
# Processing thread #926
# Processing thread #927
# Processing thread #928
# Processing thread #929
# Processing thread #930
# Processing thread #931
# Processing thread #932
# Processing thread #933
# Processing thread #934
# Processing thread #935
# Processing thread #936
# Processing thread #937
# Processing thread #938
# Processing thread #939
# Processing thread #940
# Processing thread #941
# Processing thread #942
# Processing thread #943
# Processing thread #944
# Processing thread #945
# Processing thread #946
# Processing thread #947
# Processing thread #948

# %%
print(i)
